# %%
import csv
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import wordpunct_tokenize
from nltk.tokenize import RegexpTokenizer
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import word_tokenize
from nltk.tokenize import regexp_tokenize

# %% [markdown]
# #  Create documents

# %%
with open('Airbnb_Texas_Rentals.tsv', 'r', encoding = "utf8") as all_rev:
    csv_reader = csv.reader(all_rev)
    ind = -1
    for row in all_rev:
        ind += 1
        if ind == 0:
            continue
        else:
            if row == '\n':
                ind -= 1
            else:
                new_title = r'C:\Users\Daniele\fileAIR\doc_' + str(ind) + '.tsv'
                csv_writer = csv.writer(open(new_title, 'w', encoding = "utf8"), delimiter ='\t')
                row1 = row.split("\t")[1:]
                csv_writer.writerow(row1)

# %% [markdown]
# # Search Engine

# %%
def clean1(something):
    something=something.lower()
    something=something.replace('\\n',' ')
    tokenizer = regexp_tokenize(something,"[\w'\$]+")
    filtered = [w for w in tokenizer if not w in stopwords.words('english')]
    ps=PorterStemmer()
    filtered=[ps.stem(word) for word in filtered]
    return filtered

# %%
with open('doc_1.tsv', 'r') as csvfile:
    file1 = csv.reader(csvfile, delimiter='\t')
    columns = [i for i in file1]
    description = columns[0][4]
    description=clean1(description)

# %%
test={k:v for v, k in enumerate(description, 1)}

# %%
test.keys()
# Out:
# dict_keys(['welcom', 'stay', 'privat', 'room', 'queen', 'bed', 'detach', 'bathroom', 'second', 'floor', 'anoth', 'bedroom', 'sofa', 'avail', 'addit', 'guest', '10$', '10min', 'iah', 'airport', 'pick', 'drop', '$10', 'trip'])

# %%
for key in test.keys():
    print(test[key])
# Out:
# 1
# 2
# 13
# 4
# 5
# 16
# 7
# 9
# 10
# 11
# 12
# 14
# 15
# 29
# 21
# 22
# 20
# 23
# 24
# 26
# 27
# 28
# 30
# 31

# %%
test
# Out:
# {'$10': 30,
#  '10$': 20,
#  '10min': 23,
#  'addit': 21,
#  'airport': 26,
#  'anoth': 12,
#  'avail': 29,
#  'bathroom': 9,
#  'bed': 16,
#  'bedroom': 14,
#  'detach': 7,
#  'drop': 28,
#  'floor': 11,
#  'guest': 22,
#  'iah': 24,
#  'pick': 27,
#  'privat': 13,
#  'queen': 5,
#  'room': 4,
#  'second': 10,
#  'sofa': 15,
#  'stay': 2,
#  'trip': 31,
#  'welcom': 1}

# %%
import os,os.path

# %%
print(len([x for x in os.scandir(r'C:\Users\Daniele\airbnb')]))
# Out:
# 264

# %%
my_set=set()

# %%
for i in range(1,len([x for x in os.scandir(r'C:\Users\Daniele\airbnb')])):
    with open(r'C:\Users\Daniele\airbnb\doc_'+str(i)+'.tsv', 'r',encoding='utf8') as csvfile:
        file1 = csv.reader(csvfile, delimiter='\t')
        columns = [i for i in file1]
        description = columns[0][4]
        description=clean1(description)
        my_set.update(description)
        docs_set.append(my_set)
        my_set=set()

# %%
my_set
# Out:
# {'countri',
#  'southern',
#  '30',
#  'lyle',
#  'hour',
#  'arlington',
#  'neighbor',
#  'control',
#  'vintag',
#  'min',
#  'extend',
#  'ski',
#  "note'",
#  'within',
#  'mine',
#  'boy',
#  'kite',
#  'marvel',
#  'bask',
#  'amen',
#  'stockyard',
#  'atmospher',
#  'refriger',
#  'shenandoah',
#  '45',
#  'duck',
#  'lock',
#  'finish',
#  'veteran',
#  'maximum',
#  'medit',
#  'iah',
#  'pave',
#  'along',
#  '1600',
#  'without',
#  'montros',
#  'cano',
#  'friday',
#  'texan',
#  'rock',
#  'baybrook',
#  'doorman',
#  'expos',
#  '$5',
#  'surf',
#  'pillow',
#  'function',
#  'thai',
#  'complex',
#  'seren',
#  'wisteria',
#  'take',
#  'design',
#  'master',
#  'easili',
#  'color',
#  'satisfi',
#  'con',
#  'pharmaci',
#  'shore',
#  'nois',
#  'disappoint',
#  'televis',
#  'soul',
#  'record',
#  'chill',
#  'aristocrat',
#  '13',
#  'ad',
#  'plan',
#  'lazi',
#  'finest',
#  'juliett',
#  'store',
#  'schlitterbahn',
#  '50',
#  'décor',
#  'erg',
#  'european',
#  'made',
#  'casino',
#  'convert',
#  'sxsw',
#  'offer',
#  'dfw',
#  'elm',
#  'greet',
#  'phillip',
#  'includ',
#  'continent',
#  'satellit',
#  'tx',
#  'target',
#  'motor',
#  'wall',
#  'modern',
#  'coffeepot',
#  'unseen',
#  'month',
#  'cow',
#  'plumb',
#  'near',
#  'trampolin',
#  '$10',
#  'name',
#  'racquet',
#  'vet',
#  'hair',
#  'scott',
#  'post',
#  'rail',
#  'number',
#  'ship',
#  'far',
#  'padr',
#  '100',
#  'incred',
#  'chevron',
#  'fullsiz',
#  'fairway',
#  'inquiri',
#  'growth',
#  '75212',
#  'air',
#  'wide',
#  'allianc',
#  'jacinto',
#  'class',
#  'kiddi',
#  'cowboy',
#  'creativ',
#  'pace',
#  'workout',
#  'seen',
#  'thing',
#  'magazin',
#  'shampoo',
#  'tavern',
#  'chic',
#  'featherb',
#  'ceil',
#  'guesthous',
#  'complianc',
#  'simpl',
#  'starbuck',
#  'block',
#  'aesthet',
#  'jazz',
#  'life',
#  'perk',
#  'look',
#  'mirror',
#  'westmoreland',
#  'boardwalk',
#  'american',
#  'log',
#  'best',
#  'except',
#  'apt',
#  '75',
#  'visit',
#  'anchor',
#  'advanc',
#  'front',
#  'loung',
#  'bikeshar',
#  'profit',
#  'meet',
#  'roast',
#  'launch',
#  'field',
#  'hangout',
#  'line',
#  'contemporari',
#  'pad',
#  'muy',
#  'movi',
#  'bufalina',
#  'frequent',
#  'outdoor',
#  'move',
#  'aac',
#  'plant',
#  'oak',
#  '8',
#  'bayou',
#  'beauti',
#  'may',
#  'thanksgiv',
#  'deck',
#  'hyde',
#  'keyless',
#  'aug',
#  'wineri',
#  'maker',
#  'land',
#  'wind',
#  'termin',
#  'feast',
#  'formula',
#  'march',
#  'seven',
#  'boat',
#  'festiv',
#  'childbirth',
#  '20',
#  'loop',
#  'dalla',
#  'individu',
#  'amp',
#  'salado',
#  'pub',
#  'familia',
#  'charact',
#  'wraparound',
#  'espacio',
#  'kimbrough',
#  'cultur',
#  '1400',
#  'carriag',
#  'worker',
#  '66',
#  'top',
#  'comfort',
#  'bell',
#  'east',
#  'jog',
#  'frisco',
#  'aggieland',
#  'reveil',
#  'zilker',
#  'venu',
#  'add',
#  'lead',
#  'direct',
#  "tv'",
#  'quarri',
#  'rm',
#  'lavend',
#  'cream',
#  'independ',
#  'nightstand',
#  'prefer',
#  'mountain',
#  'earth',
#  'squar',
#  'boern',
#  'modular',
#  'even',
#  'join',
#  'fayett',
#  'boutiqu',
#  'suitabl',
#  'end',
#  'dallasmi',
#  'access',
#  'separ',
#  'tidi',
#  'electr',
#  'concept',
#  '26',
#  'barley',
#  'eado',
#  'world',
#  'backyard',
#  "'river",
#  'hospit',
#  'bridg',
#  'would',
#  '2300',
#  'bedrol',
#  'ellum',
#  'nocturna',
#  'gazz',
#  'help',
#  "there'",
#  'lowest',
#  'fed',
#  'ninja',
#  'lifestyl',
#  'sqft',
#  'popular',
#  'ih',
#  'minut',
#  'treadmil',
#  'sundeck',
#  'wine',
#  'outsid',
#  'kitchenett',
#  'four',
#  'pass',
#  'max',
#  'murphi',
#  '640',
#  'though',
#  'deliv',
#  'mini',
#  'rest',
#  'condominium',
#  'glad',
#  'exist',
#  'pick',
#  'casita',
#  'linen',
#  'enjoy',
#  'chico',
#  'pristin',
#  "we'r",
#  'forc',
#  'section',
#  'bottom',
#  'fee',
#  '290',
#  'fabul',
#  'sushi',
#  'baytown',
#  'ensuit',
#  'whole',
#  'train',
#  'honor',
#  'will',
#  'trader',
#  '19th',
#  'across',
#  "contractor'",
#  'regist',
#  'unlock',
#  'yacht',
#  '30am',
#  'lucki',
#  'fairi',
#  'cost',
#  'nrg',
#  'rug',
#  'pan',
#  'tanger',
#  'bowl',
#  'park',
#  'accommod',
#  'belton',
#  'charg',
#  'ranger',
#  'urban',
#  'classiest',
#  'detail',
#  'travel',
#  'pool',
#  '610',
#  'door',
#  'testament',
#  'bantam',
#  'welcom',
#  'six',
#  'el',
#  'small',
#  'touch',
#  'sac',
#  'area',
#  'mind',
#  '5',
#  'person',
#  '18',
#  'peopl',
#  'hint',
#  'head',
#  'pit',
#  '10$',
#  'round',
#  'chirp',
#  'basebal',
#  'shop',
#  'shoe',
#  'typic',
#  'suggest',
#  'intern',
#  'list',
#  'rental',
#  'remodel',
#  'meal',
#  'shot',
#  'wimberley',
#  'give',
#  'qti',
#  '$75',
#  'georg',
#  'tax',
#  'easi',
#  'airlin',
#  'brazo',
#  '1316',
#  'art',
#  'rocker',
#  'comput',
#  'villag',
#  'resort',
#  'globe',
#  'updat',
#  'secur',
#  'middl',
#  'school',
#  '30min',
#  'angel',
#  'let',
#  'babysit',
#  'roger',
#  'interest',
#  'spade',
#  'pure',
#  'style',
#  'instant',
#  'poodi',
#  'hr',
#  'upon',
#  'care',
#  'shotwel',
#  'granit',
#  'hang',
#  'apart',
#  'basketbal',
#  'shabbi',
#  'combo',
#  'lodg',
#  'card',
#  '2nd',
#  'kingwood',
#  'sola',
#  'group',
#  'tradit',
#  'crown',
#  'happi',
#  'magnolia',
#  'locat',
#  'hole',
#  'money',
#  'lakefront',
#  'stun',
#  'fluffi',
#  'club',
#  'premium',
#  'tabl',
#  'dell',
#  'explor',
#  'jet',
#  '1550',
#  'short',
#  'everi',
#  'riverwalk',
#  '6th',
#  'request',
#  '4342',
#  '1st',
#  'district',
#  'term',
#  'kerrvil',
#  'valu',
#  'sunset',
#  'mall',
#  'rainey',
#  'sing',
#  'dishwash',
#  'netflix',
#  'seclud',
#  'henc',
#  'often',
#  'corridor',
#  'discount',
#  'scent',
#  'airbnb',
#  'cul',
#  'stainless',
#  'spring',
#  'sea',
#  'never',
#  'pretti',
#  'klyde',
#  'acreag',
#  'qualiti',
#  'inflat',
#  '24hr',
#  'treehous',
#  '281',
#  'hotel',
#  'old',
#  'bad',
#  'discret',
#  'side',
#  'twin',
#  '$60',
#  'conveni',
#  'etc',
#  'thank',
#  'unit',
#  'throughout',
#  'dip',
#  'situat',
#  'para',
#  'classic',
#  'local',
#  'adult',
#  'topper',
#  'centr',
#  'creat',
#  'antonio',
#  'complet',
#  'concret',
#  'sunris',
#  'everyon',
#  'greenvil',
#  'paradis',
#  'dear',
#  'sink',
#  'poolsid',
#  'worth',
#  'alamo',
#  'cell',
#  '1940',
#  '7th',
#  'premier',
#  'keurig',
#  'better',
#  'lakewood',
#  'comfi',
#  'fast',
#  'bliss',
#  'coffe',
#  'farm',
#  'bar',
#  'night',
#  'describ',
#  'contain',
#  'lowergreenvil',
#  'waterloo',
#  'effic',
#  '2br',
#  'shadi',
#  'sleep',
#  'go',
#  'theater',
#  'mount',
#  'forget',
#  'grapevin',
#  'street',
#  'decompress',
#  'preserv',
#  'aventurero',
#  'prestigi',
#  'townhous',
#  'galleria',
#  'upscal',
#  'san',
#  'splashpad',
#  'del',
#  'tan',
#  'children',
#  'back',
#  'starfish',
#  'tenni',
#  'exactli',
#  "'countri",
#  'doubl',
#  'sentenc',
#  'util',
#  'ultim',
#  'smu',
#  'brand',
#  'templ',
#  'calm',
#  'game',
#  'immens',
#  'pictur',
#  'zoo',
#  'elum',
#  'check',
#  'convent',
#  'nearbi',
#  'pet',
#  'neighborhood',
#  'kroger',
#  'n',
#  'water',
#  'prestig',
#  'fellowship',
#  'hostil',
#  '121',
#  'spaciou',
#  'congress',
#  'mbp',
#  'yet',
#  'mold',
#  'unusu',
#  'euless',
#  'island',
#  'bluebonnet',
#  'deer',
#  'flyrit',
#  '37',
#  'tournament',
#  'nation',
#  'borrow',
#  'conro',
#  '42',
#  'turismo',
#  'exxon',
#  '99',
#  'winstar',
#  'cavern',
#  'among',
#  'bueno',
#  'caretak',
#  'pic',
#  'two',
#  'flag',
#  "women'",
#  'awar',
#  'southsid',
#  'storag',
#  'addit',
#  'starlight',
#  'stonebriar',
#  'standard',
#  'granburi',
#  'kyle',
#  'nelson',
#  'ac',
#  'carport',
#  'court',
#  '400',
#  'stadium',
#  'uber',
#  'rd',
#  'stargaz',
#  'attach',
#  'winni',
#  'rejuven',
#  'houston',
#  'hope',
#  'temporari',
#  'leav',
#  'livabl',
#  'marriott',
#  'jw',
#  'singl',
#  'vagabond',
#  'cat',
#  'perfect',
#  'stranger',
#  'partli',
#  'sweet',
#  'c',
#  'eleg',
#  'big',
#  'build',
#  '118',
#  'cc',
#  'descript',
#  'metroplex',
#  'cloth',
#  'mlk',
#  'case',
#  'lakesid',
#  'fort',
#  'friendli',
#  'king',
#  'use',
#  'french',
#  'current',
#  '1922',
#  'thursday',
#  'soap',
#  'i10',
#  "austin'",
#  'univ',
#  'forward',
#  'gulf',
#  'piec',
#  'know',
#  'drive',
#  'castleg',
#  'mucha',
#  'fan',
#  'moodi',
#  'attract',
#  "kya'",
#  'que',
#  'breweri',
#  'loft',
#  'contact',
#  'fish',
#  'acr',
#  'natur',
#  'stand',
#  'roku',
#  'servic',
#  'monday',
#  "guests'",
#  'lower',
#  'swine',
#  'pleas',
#  'pine',
#  "joe'",
#  'hassl',
#  'awesom',
#  '65',
#  '750',
#  'coupl',
#  'varieti',
#  "chic'",
#  'hanger',
#  'toy',
#  'code',
#  '12',
#  'toll',
#  'seat',
#  'truli',
#  'ambianc',
#  'sugarland',
#  'residenti',
#  'machin',
#  'flat',
#  'charmer',
#  'ut',
#  'open',
#  'hunt',
#  'burnet',
#  'cabl',
#  'cutleri',
#  'third',
#  'fabeuless',
#  'bungalow',
#  'heal',
#  'fall',
#  '10min',
#  'cozi',
#  'indian',
#  'tailor',
#  'tell',
#  'host',
#  'schlitterbaun',
#  'purchas',
#  'right',
#  'suit',
#  'state',
#  'travi',
#  'spot',
#  'grand',
#  'seamless',
#  'knox',
#  'connect',
#  'spartan',
#  'extra',
#  'cover',
#  'antiqu',
#  'twu',
#  'collect',
#  'password',
#  'full',
#  'subject',
#  'worri',
#  'bayview',
#  'cargo',
#  'plu',
#  'splendor',
#  'encuentra',
#  'marco',
#  'year',
#  'reserv',
#  'rent',
#  'samuel',
#  'marbl',
#  'entranc',
#  'reinvigor',
#  'effect',
#  'corpu',
#  'mckinney',
#  'focus',
#  'packag',
#  'beyond',
#  'weather',
#  'hidden',
#  'leisur',
#  'west',
#  'dresser',
#  'cool',
#  'medic',
#  'close',
#  'cafe',
#  'gold',
#  'protext',
#  'quaint',
#  'offic',
#  'austin',
#  'pm',
#  'way',
#  'fool',
#  'second',
#  'town',
#  'counter',
#  'wrap',
#  'half',
#  'driver',
#  'dominion',
#  '17mi',
#  'chicken',
#  'demand',
#  'kemah',
#  'restor',
#  'entir',
#  'ceram',
#  'nest',
#  'nautic',
#  'low',
#  'forth',
#  'holiday',
#  'botan',
#  'getaway',
#  'eye',
#  'greenway',
#  'kept',
#  'watter',
#  'regularli',
#  'pong',
#  'station',
#  'playset',
#  "1950'",
#  'hit',
#  '4k',
#  'tollway',
#  'ideal',
#  'stereo',
#  'commut',
#  '8am',
#  'five',
#  'oreo',
#  'wonder',
#  'lacentera',
#  'ton',
#  'galveston',
#  'microwav',
#  'kati',
#  'friend',
#  'cliff',
#  'butt',
#  'legal',
#  'phone',
#  '6100',
#  'provid',
#  'ampl',
#  'sight',
#  'tcc',
#  'crowd',
#  'downstair',
#  'mud',
#  'outskirt',
#  'pond',
#  'retir',
#  'distancia',
#  'bicker',
#  'insid',
#  'maintain',
#  'hot',
#  'total',
#  'empti',
#  'secret',
#  'plaza',
#  'encantar',
#  'texoma',
#  'either',
#  "what'",
#  "can't",
#  'leon',
#  'hau',
#  '$270',
#  'trim',
#  'sceneri',
#  'es',
#  '29',
#  'combin',
#  'major',
#  'dirt',
#  'st',
#  'ignor',
#  'green',
#  'high',
#  'fine',
#  'arriv',
#  'man',
#  'citi',
#  'rain',
#  'ga',
#  'slide',
#  'foot',
#  'cab',
#  'costco',
#  '410',
#  'saltwat',
#  'scene',
#  'inch',
#  'longhorn',
#  'beam',
#  'hook',
#  'wi',
#  'utensil',
#  '21',
#  'speed',
#  'goe',
#  'essenti',
#  'tourist',
#  'turn',
#  'contrari',
#  'kid',
#  'plenti',
#  'sunroom',
#  'reach',
#  'stop',
#  'more',
#  'detach',
#  'queen',
#  'lake',
#  'first',
#  'immedi',
#  'dryer',
#  'stori',
#  'pop',
#  'lux',
#  'window',
#  'part',
#  'wifi',
#  "kingwood'",
#  'tub',
#  'emerg',
#  'blue',
#  'oven',
#  'rang',
#  'beach',
#  'highway',
#  'driveway',
#  'walmart',
#  'byron',
#  'car',
#  'drug',
#  'anybodi',
#  'pasadena',
#  'stock',
#  'excel',
#  'leagu',
#  'recent',
#  'ambienc',
#  'baylor',
#  'allegro',
#  'mattress',
#  'extrem',
#  "lala'",
#  'i45',
#  'gruen',
#  'guest',
#  'escap',
#  'de',
#  'diamond',
#  'might',
#  'golf',
#  'space',
#  'soft',
#  'decor',
#  'warm',
#  'alway',
#  'ford',
#  'bigger',
#  'quarter',
#  'last',
#  'cours',
#  'larg',
#  'highest',
#  'quick',
#  'studio',
#  'ne',
#  'main',
#  'yard',
#  'allerg',
#  'book',
#  '40',
#  '1pm',
#  'rate',
#  'mexican',
#  'belt',
#  'known',
#  'kind',
#  'fasten',
#  'stylishli',
#  'roadhous',
#  'assur',
#  'testimoni',
#  'furnitur',
#  'board',
#  'manor',
#  'southtown',
#  'nasa',
#  'other',
#  'everyth',
#  'equip',
#  ...}

# %%
docs_set=[]

# %%
docs_set
# Out:
# [{'$10',
#   '10$',
#   '10min',
#   'addit',
#   'airport',
#   'anoth',
#   'avail',
#   'bathroom',
#   'bed',
#   'bedroom',
#   'detach',
#   'drop',
#   'floor',
#   'guest',
#   'iah',
#   'pick',
#   'privat',
#   'queen',
#   'room',
#   'second',
#   'sofa',
#   'stay',
#   'trip',
#   'welcom'},
#  {'2',
#   '281',
#   '3',
#   '4',
#   '410',
#   'airport',
#   'alamo',
#   'amaz',
#   'area',
#   'bathroom',
#   'beauti',
#   'bedroom',
#   'car',
#   'close',
#   'conveni',
#   'decor',
#   'driveway',
#   'european',
#   'featur',
#   'floor',
#   'full',
#   'fulli',
#   'garden',
#   'hardwood',
#   'height',
#   'home',
#   'hous',
#   'independ',
#   'inspir',
#   'kitchen',
#   'line',
#   'locat',
#   'loop',
#   'neighborhood',
#   'nw',
#   'open',
#   'origin',
#   'park',
#   'plan',
#   'prestigi',
#   'quiet',
#   'remodel',
#   'room',
#   'season',
#   'sleep',
#   'street',
#   'stylish',
#   'top',
#   'town',
#   'tree',
#   'tv',
#   'upscal'},
#  {"'river",
#   "city'",
#   'close',
#   'extra',
#   'hous',
#   'island',
#   'jacinto',
#   'maintain',
#   'river',
#   'room',
#   'san',
#   'temporari',
#   'visitor',
#   'well'},
#  {'access',
#   'acr',
#   'bathroom',
#   'bedroom',
#   'bryan',
#   'covet',
#   'cute',
#   'garden',
#   'home',
#   'littl',
#   'neighborhood',
#   'privat',
#   'situat'},
#  {"1920'",
#   '1922',
#   '5',
#   'across',
#   'built',
#   'charact',
#   'current',
#   'downtown',
#   'drive',
#   'fort',
#   'gateway',
#   'happi',
#   'home',
#   'mile',
#   'minut',
#   'offer',
#   'origin',
#   'outsid',
#   'park',
#   'purchas',
#   'recent',
#   'rejuven',
#   'restor',
#   'street',
#   'welcom',
#   'worth'},
#  {'activ',
#   'adventur',
#   'big',
#   'busi',
#   'close',
#   'conro',
#   'coupl',
#   'famili',
#   'friendli',
#   'good',
#   'group',
#   'kid',
#   'lake',
#   'love',
#   'neighborhood',
#   'nightlif',
#   'outdoor',
#   'place',
#   'solo',
#   'space',
#   'travel'},
#  {'15',
#   '8',
#   'acr',
#   'airport',
#   'amen',
#   'america',
#   'austin',
#   'avail',
#   'circuit',
#   'convert',
#   'cota',
#   'countri',
#   'experi',
#   'formula',
#   'home',
#   'less',
#   'mile',
#   'modular',
#   'need',
#   'offer',
#   'one',
#   'park',
#   'retreat',
#   'rustic',
#   'southeast',
#   'texa',
#   'trailer'},
#  {'alway',
#   'avail',
#   'bathroom',
#   'beauti',
#   'bed',
#   'bedroom',
#   'clean',
#   'closet',
#   'downtown',
#   'hous',
#   'mile',
#   'pet',
#   'queen',
#   'shampoo',
#   'share',
#   'size',
#   'stockyard',
#   'suppli',
#   'tcc',
#   'tcu',
#   'towel'},
#  {'away',
#   'bedroom',
#   'best',
#   'bottom',
#   'class',
#   'comfort',
#   'condo',
#   'deck',
#   'first',
#   'master',
#   'patio',
#   'pier',
#   'r',
#   'step',
#   'view'},
#  {'entranc', 'privat'},
#  {'2',
#   'access',
#   'apart',
#   'bedroom',
#   'central',
#   'comfort',
#   'cool',
#   'easi',
#   'enjoy',
#   'feel',
#   'fit',
#   'gourmet',
#   'highway',
#   'home',
#   'kitchen',
#   'like',
#   'locat',
#   'major',
#   'peopl',
#   'quiet',
#   'street'},
#  {'10',
#   '2',
#   '25',
#   '35',
#   '5',
#   '8',
#   'acr',
#   'airlin',
#   'airport',
#   'american',
#   'amp',
#   'away',
#   'beauti',
#   'center',
#   'check',
#   'dalla',
#   'deep',
#   'dfw',
#   'elum',
#   'estat',
#   'fabeuless',
#   'field',
#   'flag',
#   'fort',
#   'gate',
#   'gaylord',
#   'global',
#   'grapevin',
#   'great',
#   'heart',
#   'hideaway',
#   'home',
#   'life',
#   'list',
#   'locat',
#   'lodg',
#   'love',
#   'mall',
#   'metro',
#   'mill',
#   'min',
#   'minut',
#   'motor',
#   'museum',
#   'overlook',
#   'park',
#   'pond',
#   'set',
#   'six',
#   'speed',
#   'stadium',
#   'stock',
#   'texa',
#   'texan',
#   'way',
#   'wolf',
#   'wood',
#   'worth',
#   'yard'},
#  {'also',
#   'area',
#   'austin',
#   'bird',
#   'combin',
#   'come',
#   'conveni',
#   'crowd',
#   'die',
#   'far',
#   'galor',
#   'hum',
#   'madden',
#   'natur',
#   'offer',
#   'peac',
#   'place',
#   'quiet',
#   'see',
#   'spade',
#   'view',
#   'visit'},
#  {'2',
#   '3',
#   'also',
#   'amen',
#   'antonio',
#   'area',
#   'away',
#   'back',
#   'bathroom',
#   'belt',
#   'cabl',
#   'come',
#   'cours',
#   'enjoy',
#   'famili',
#   'golf',
#   'great',
#   'green',
#   'home',
#   'hope',
#   'hous',
#   'internet',
#   'jw',
#   'laundri',
#   'marriott',
#   'minut',
#   'natur',
#   'neighbor',
#   'north',
#   'place',
#   'resort',
#   'room',
#   'safe',
#   'san',
#   'side',
#   'spa',
#   'stay',
#   'stop',
#   'yard'},
#  {'2',
#   'also',
#   'appeal',
#   'avail',
#   'backyard',
#   'bad',
#   'base',
#   'beauti',
#   'car',
#   'carport',
#   'ceil',
#   'close',
#   'come',
#   'conveni',
#   'cottag',
#   'countri',
#   'cover',
#   'cozi',
#   'downtown',
#   'dryer',
#   'eclect',
#   'explor',
#   'fireplac',
#   'get',
#   'great',
#   "guest'",
#   'home',
#   'huge',
#   'includ',
#   'kerrvil',
#   'nearbi',
#   'neighborhood',
#   'park',
#   'pine',
#   'place',
#   'porch',
#   'price',
#   'protext',
#   'rain',
#   'rental',
#   'screen',
#   'space',
#   'texa',
#   'uniqu',
#   'use',
#   'washer',
#   'weather',
#   'wine'},
#  {'chic', 'countri', 'hint', 'hous', 'new', 'texa'},
#  {'austin',
#   'back',
#   'bedroom',
#   'coffe',
#   'cute',
#   'deck',
#   'downtown',
#   'easi',
#   'friendli',
#   'front',
#   'hyde',
#   'lot',
#   'near',
#   'neighborhood',
#   'park',
#   'porch',
#   'restaur',
#   'shop',
#   'sunni',
#   'two',
#   'ut',
#   'walk',
#   'window'},
#  {'activ',
#   'adventur',
#   'beach',
#   'busi',
#   'close',
#   'coupl',
#   'dine',
#   'famili',
#   'friendli',
#   'good',
#   'great',
#   'place',
#   'restaur',
#   'solo',
#   'travel',
#   'view'},
#  {'2',
#   '4',
#   '59',
#   '8',
#   'bathroom',
#   'bedroom',
#   'beltway',
#   'conveni',
#   'entertain',
#   'floor',
#   'great',
#   'home',
#   'locat',
#   'neighborhood',
#   'open',
#   'plan',
#   'quiet'},
#  {'5',
#   'area',
#   'atmospher',
#   'citi',
#   'cozi',
#   'creat',
#   'entertain',
#   'famili',
#   'friend',
#   'frisco',
#   'lakefront',
#   'less',
#   'locat',
#   'memori',
#   'minut',
#   'outsid',
#   'perfect',
#   'relax',
#   'right',
#   'shop',
#   'uniqu',
#   'wonder',
#   'yet'},
#  {'10',
#   '12',
#   '3',
#   '4',
#   'bath',
#   'bedroom',
#   'car',
#   'luxuri',
#   'plu',
#   'room',
#   'sleep',
#   'theater'},
#  {'2',
#   '3',
#   '5',
#   '50',
#   'ampl',
#   'bathroom',
#   'beauti',
#   'bed',
#   'bedroom',
#   'castleg',
#   'clean',
#   'comfort',
#   'flat',
#   'garag',
#   'home',
#   'host',
#   'inch',
#   'live',
#   'main',
#   'neighborhood',
#   'nice',
#   'peopl',
#   'ping',
#   'pong',
#   'request',
#   'room',
#   'screen',
#   'set',
#   'tabl'},
#  {'also',
#   'apart',
#   'equip',
#   'everyon',
#   'famili',
#   'full',
#   'garag',
#   'group',
#   'home',
#   'leisur',
#   'nice',
#   'offer',
#   'park',
#   'place',
#   'pool',
#   'relax',
#   'size',
#   'stay',
#   'time',
#   'two',
#   'use',
#   'vehicl',
#   'welcom',
#   'workout'},
#  {'bed',
#   'busi',
#   'close',
#   'comfi',
#   'coupl',
#   'famili',
#   'good',
#   'grand',
#   'kati',
#   'kid',
#   'kitchen',
#   'lacentera',
#   'light',
#   'love',
#   'mall',
#   'mill',
#   'movi',
#   'neighborhood',
#   'nightlif',
#   'outdoor',
#   'parkway',
#   'place',
#   'restaur',
#   'shop',
#   'space',
#   'theater',
#   'travel'},
#  {'across',
#   'air',
#   'away',
#   'bed',
#   'bu',
#   'campu',
#   'carriag',
#   'caution',
#   'coffe',
#   'convert',
#   'dcta',
#   'denton',
#   'distanc',
#   'downstair',
#   'downtown',
#   'freezer',
#   'hous',
#   'kitchenett',
#   'ladder',
#   'locat',
#   'loft',
#   'mattress',
#   'microwav',
#   'mile',
#   'murphi',
#   'north',
#   'pleas',
#   'pot',
#   'refriger',
#   'space',
#   'stair',
#   'station',
#   'stop',
#   'street',
#   'texa',
#   'train',
#   'univers',
#   'use',
#   'walk'},
#  {'15',
#   '18',
#   '2',
#   '20',
#   '25',
#   '4',
#   '6',
#   '8',
#   'antonio',
#   'avail',
#   'babysit',
#   'bed',
#   'bedroom',
#   'braunfel',
#   'car',
#   'central',
#   'chalet',
#   'concierg',
#   'discount',
#   'fiesta',
#   'gruen',
#   'home',
#   'hottub',
#   'massag',
#   'medicin',
#   'min',
#   'new',
#   'onsit',
#   'pool',
#   'price',
#   'rental',
#   'river',
#   'san',
#   'sea',
#   'sleep',
#   'texa',
#   'town',
#   'walk',
#   'world'},
#  {'also',
#   'bathroom',
#   'busi',
#   'childbirth',
#   'extend',
#   'famili',
#   'home',
#   'perfect',
#   'place',
#   'privat',
#   'room',
#   'share',
#   'stay',
#   'tourist',
#   'town',
#   'trip',
#   'vacat',
#   'warm'},
#  {'busi',
#   'coupl',
#   'cozi',
#   'english',
#   'french',
#   'room',
#   'spanish',
#   'special',
#   'talk',
#   'trip'},
#  {'1',
#   '4',
#   'accommod',
#   'acl',
#   'amaz',
#   'amp',
#   'bar',
#   'bed',
#   'cabl',
#   'coffe',
#   'comfort',
#   'doubl',
#   'downtown',
#   'drive',
#   'eateri',
#   'free',
#   'furnitur',
#   'interior',
#   'larg',
#   'locat',
#   'minut',
#   'park',
#   'queen',
#   'reserv',
#   'soco',
#   'sofa',
#   'sola',
#   'sxsw',
#   'tradit',
#   'tv',
#   'walk',
#   'wifi'},
#  {'2',
#   'amp',
#   'bed',
#   'bowl',
#   'commun',
#   'gate',
#   'great',
#   'includ',
#   'inquiri',
#   'seriou',
#   'stair',
#   'stay',
#   'super',
#   'upstair'},
#  {'200',
#   '55',
#   'area',
#   'around',
#   'beauti',
#   'best',
#   'big',
#   'book',
#   'brand',
#   'busi',
#   'channel',
#   'commun',
#   'conveni',
#   'coupl',
#   'doubl',
#   'etc',
#   'everyth',
#   'famili',
#   'fast',
#   'find',
#   'garag',
#   'good',
#   'grill',
#   'group',
#   'high',
#   'home',
#   'hotel',
#   'inch',
#   'kid',
#   'local',
#   'locat',
#   'mbp',
#   'mind',
#   'much',
#   'netflix',
#   'new',
#   'nice',
#   'north',
#   'outdoor',
#   'peac',
#   'plano',
#   'prepar',
#   'provid',
#   'school',
#   'smart',
#   'speed',
#   'stay',
#   'studi',
#   'travel',
#   'tv',
#   'ultim',
#   'wifi'},
#  {'10',
#   '15',
#   '6',
#   'avail',
#   'bar',
#   'bowl',
#   'couch',
#   'downtown',
#   'drive',
#   'goe',
#   'great',
#   'green',
#   'line',
#   'live',
#   'lot',
#   'metro',
#   'min',
#   'minut',
#   'peopl',
#   'rail',
#   'room',
#   'space',
#   'super',
#   'surf',
#   'walk'},
#  {'activ',
#   'adventur',
#   'amp',
#   'arlington',
#   'ballpark',
#   'bed',
#   'busi',
#   'close',
#   'comfi',
#   'coupl',
#   'dine',
#   'directli',
#   'famili',
#   'five',
#   'flag',
#   'friendli',
#   'good',
#   'harbor',
#   'hurrican',
#   'love',
#   'minut',
#   'near',
#   'neighborhood',
#   'nightlif',
#   'north',
#   'outdoor',
#   'park',
#   'place',
#   'restaur',
#   'seven',
#   'six',
#   'solo',
#   'space',
#   'stadium',
#   'trail',
#   'travel',
#   'treed'},
#  {'15',
#   '1940',
#   '400',
#   'apart',
#   'attach',
#   'attract',
#   'austin',
#   "austin'",
#   'bath',
#   'bedroom',
#   'citi',
#   'desir',
#   'entir',
#   'ft',
#   'hotel',
#   'includ',
#   'licens',
#   'live',
#   'main',
#   'minut',
#   'neighborhood',
#   'note',
#   'occup',
#   'oper',
#   'price',
#   'rental',
#   'room',
#   'short',
#   'sq',
#   'tarrytown',
#   'tax',
#   'term'},
#  {'30',
#   'acr',
#   'beauti',
#   'bedrol',
#   'book',
#   'bunkhous',
#   'come',
#   'coyot',
#   'enjoy',
#   'famili',
#   'friend',
#   'gazz',
#   'hors',
#   'landscap',
#   'listen',
#   'nestl',
#   'pit',
#   'privat',
#   'ranch',
#   'read',
#   'set',
#   'shoe',
#   'sing',
#   'sit',
#   'star'},
#  {'beach',
#   'beauti',
#   'better',
#   'come',
#   'even',
#   'home',
#   'hous',
#   'love',
#   'relax',
#   'river',
#   'shiplap',
#   'style',
#   'view',
#   'wall',
#   'water'},
#  {'adventur',
#   'ambianc',
#   'api',
#   'bend',
#   'boat',
#   'busi',
#   'canyon',
#   'cat',
#   'close',
#   'countri',
#   'coupl',
#   'dog',
#   'fall',
#   'good',
#   'hike',
#   'hill',
#   'launch',
#   'locat',
#   'love',
#   'marbl',
#   'neighborhood',
#   'outdoor',
#   'pace',
#   'park',
#   'pedernal',
#   'peopl',
#   'place',
#   'play',
#   'poodi',
#   'pool',
#   'privat',
#   'properti',
#   'relax',
#   'restaur',
#   'river',
#   'roadhous',
#   'solo',
#   'space',
#   'sxsw',
#   'texa',
#   'travel',
#   'venu'},
#  {'larg', 'lot', 'modern', 'remodel', 'shade', 'spartan'},
#  {'2',
#   '20',
#   'access',
#   'ampl',
#   'avail',
#   'back',
#   'big',
#   'caretak',
#   'chair',
#   'clean',
#   'comfort',
#   'cozi',
#   'excel',
#   'famili',
#   'goal',
#   'group',
#   'guest',
#   'handicap',
#   'home',
#   'laid',
#   'main',
#   'park',
#   'place',
#   'plenti',
#   'properti',
#   'quiet',
#   'safeti',
#   'shower',
#   'sleep',
#   'space',
#   'time',
#   'wheel'},
#  {'100',
#   '1pm',
#   '2',
#   '24',
#   '7',
#   '75212',
#   'airbnb',
#   'amp',
#   'anytim',
#   'arriv',
#   'bathroom',
#   'bicker',
#   'code',
#   'come',
#   'confirm',
#   'cost',
#   'dalla',
#   'day',
#   'detail',
#   'door',
#   'email',
#   'entri',
#   'everyth',
#   'free',
#   'full',
#   'greet',
#   'hassl',
#   'home',
#   'independ',
#   'info',
#   'key',
#   'keyless',
#   'know',
#   'locat',
#   'lock',
#   'low',
#   'may',
#   'motel',
#   'n',
#   'need',
#   'park',
#   'plenti',
#   'privat',
#   'rd',
#   'reserv',
#   'room',
#   'schedul',
#   'st',
#   'stay',
#   'style',
#   'westmoreland',
#   'wifi'},
#  {'airport', 'center', 'citi', 'close', 'place'},
#  {'across',
#   'advantag',
#   'along',
#   'away',
#   'comal',
#   'commun',
#   'directli',
#   'fulli',
#   'furnish',
#   'grill',
#   'hideaway',
#   'hideway',
#   'home',
#   'insid',
#   'locat',
#   'make',
#   'nestl',
#   'next',
#   'one',
#   'relax',
#   'rememb',
#   'right',
#   'river',
#   'schlitterbahn',
#   'spectacular',
#   'take',
#   'unit',
#   'vacat',
#   'view'},
#  {'4k',
#   'access',
#   'bed',
#   'big',
#   'bigger',
#   'close',
#   'comfi',
#   'complet',
#   'couch',
#   'enjoy',
#   "everything'",
#   'featur',
#   'feel',
#   'fire',
#   'ft',
#   'full',
#   'home',
#   'kitchen',
#   'outdoor',
#   'patio',
#   'perfect',
#   'pit',
#   'readi',
#   'relax',
#   'renov',
#   'rest',
#   'right',
#   'shower',
#   'space',
#   'sq',
#   'texa',
#   'two',
#   'water'},
#  {'2',
#   '500',
#   'amp',
#   'backyard',
#   'bed',
#   'big',
#   'brick',
#   'case',
#   'channel',
#   'clean',
#   'comfort',
#   'cozi',
#   'direct',
#   'dryer',
#   'guest',
#   'home',
#   'larg',
#   'night',
#   'per',
#   'pillow',
#   'rent',
#   'room',
#   'shade',
#   'sheet',
#   'tree',
#   'tv',
#   'washer',
#   'watch'},
#  {'3',
#   'abilen',
#   'across',
#   'airport',
#   'amp',
#   'bedroom',
#   'cattl',
#   'center',
#   'conveni',
#   'counti',
#   'expo',
#   'hous',
#   'land',
#   'locat',
#   'lyle',
#   'minut',
#   'shotwel',
#   'stadium',
#   'street',
#   'stylishli',
#   'taylor',
#   'updat',
#   'zoo'},
#  {'apart',
#   'finish',
#   'furnish',
#   'high',
#   'move',
#   'peopl',
#   'prestig',
#   'readi',
#   'standard',
#   'valu'},
#  {'20',
#   '5',
#   '7th',
#   '8',
#   'ad',
#   'ambient',
#   'atmospher',
#   'ave',
#   'bikeshar',
#   'concept',
#   'connect',
#   'countri',
#   'district',
#   'downtown',
#   'feel',
#   'hous',
#   'includ',
#   'like',
#   'live',
#   'love',
#   'magnolia',
#   'minut',
#   'modern',
#   'museum',
#   'near',
#   'nois',
#   'open',
#   'point',
#   'provid',
#   'renov',
#   'ride',
#   'samuel',
#   'station',
#   'stay',
#   'track',
#   'trail',
#   'train',
#   'triniti',
#   'uniqu',
#   'walk',
#   'west',
#   'year'},
#  {'8',
#   'area',
#   'bed',
#   'bedroom',
#   'descript',
#   'detail',
#   'full',
#   'king',
#   'live',
#   'master',
#   'maximum',
#   'occup',
#   'second',
#   'see',
#   'sleeper',
#   'sofa',
#   'two'},
#  {'2',
#   '21',
#   '25',
#   'access',
#   'addit',
#   'allow',
#   'bed',
#   'bedroom',
#   'bowl',
#   'complet',
#   'famili',
#   'full',
#   'home',
#   'king',
#   'larg',
#   'master',
#   'mile',
#   'minut',
#   'nrg',
#   'pasadena',
#   'readi',
#   'renov',
#   'singl',
#   'size',
#   'stadium',
#   'suit',
#   'super'},
#  {'accommod',
#   "apartment'",
#   'bush',
#   'close',
#   'coupl',
#   'eat',
#   'field',
#   'georg',
#   'great',
#   'kyle',
#   'librari',
#   'love',
#   'mani',
#   'northgat',
#   'person',
#   'place',
#   'price',
#   'reason',
#   'tidi'},
#  {'eleg', 'morn', 'star'},
#  {'10',
#   '121',
#   '2',
#   '20',
#   '4',
#   '45',
#   '75',
#   'access',
#   'adventur',
#   'airport',
#   'amaz',
#   'busi',
#   'coupl',
#   'creek',
#   'dalla',
#   'dfw',
#   'downtown',
#   'enjoy',
#   'famili',
#   'great',
#   'highway',
#   'home',
#   'kid',
#   'love',
#   'major',
#   'mall',
#   'mile',
#   'minut',
#   'neighborhood',
#   'orient',
#   'outlet',
#   'parti',
#   'premium',
#   'rang',
#   'shop',
#   'solo',
#   'stonebriar',
#   'travel',
#   'watter',
#   'within'},
#  {'2',
#   '6',
#   'ac',
#   'accommod',
#   'bandera',
#   'bed',
#   'bedroom',
#   'cat',
#   'closet',
#   'coffeepot',
#   'cookwar',
#   'dish',
#   'downtown',
#   'electr',
#   'fed',
#   'ferral',
#   'fire',
#   'first',
#   'full',
#   'futon',
#   'heat',
#   'hous',
#   'icemak',
#   'insid',
#   'king',
#   'kitchen',
#   'linen',
#   'live',
#   'microwav',
#   'pet',
#   'place',
#   'plate',
#   'properti',
#   'provid',
#   'queen',
#   'refrigeratior',
#   'room',
#   'second',
#   'shower',
#   'size',
#   'sleep',
#   'sleeper',
#   'smoke',
#   'stove',
#   'toaster',
#   'total',
#   'towel',
#   'tv',
#   'twin',
#   'tx',
#   'utensil',
#   'walk',
#   'window'},
#  {'15',
#   '1st',
#   '2016',
#   '24',
#   '2br',
#   '30',
#   '5',
#   '70',
#   'airport',
#   'amen',
#   'away',
#   'backyard',
#   'bathroom',
#   'bed',
#   'built',
#   'couch',
#   'crate',
#   'downtown',
#   'emerg',
#   'entir',
#   'erg',
#   'floor',
#   'full',
#   'german',
#   'groceri',
#   'gym',
#   'home',
#   'hr',
#   'includ',
#   'inflat',
#   'limit',
#   'machin',
#   'mall',
#   'master',
#   'mattress',
#   'min',
#   'minut',
#   'neighborhood',
#   'nrg',
#   'queen',
#   'quiet',
#   'restaur',
#   'room',
#   'second',
#   'shepherd',
#   'store',
#   'stori',
#   'train',
#   'treadmil',
#   'tv',
#   'w'},
#  {'airport',
#   'alamodom',
#   'also',
#   'ampl',
#   'antonio',
#   'apart',
#   'array',
#   'bar',
#   'basebal',
#   'bike',
#   'center',
#   'close',
#   'convent',
#   'cozi',
#   'distanc',
#   'district',
#   'downtown',
#   'drop',
#   'enjoy',
#   'featur',
#   'field',
#   'free',
#   'guest',
#   'hemisfair',
#   'intern',
#   'larg',
#   'locat',
#   'near',
#   'offer',
#   'park',
#   'pick',
#   'picnic',
#   'playground',
#   'public',
#   'rack',
#   'restaur',
#   'san',
#   'share',
#   'shop',
#   'southtown',
#   'space',
#   'street',
#   'tabl',
#   'use',
#   'walk',
#   'within'},
#  {'2',
#   '3',
#   '5',
#   '59',
#   '6',
#   'activ',
#   'adventur',
#   'area',
#   'bath',
#   'bedroom',
#   'block',
#   'book',
#   'busi',
#   'center',
#   'commun',
#   'coupl',
#   'driveway',
#   'entir',
#   'except',
#   'extend',
#   'famili',
#   'full',
#   'furnish',
#   'great',
#   'home',
#   'iah',
#   'kingwood',
#   'larg',
#   'make',
#   'medic',
#   'mile',
#   'monday',
#   'ne',
#   'neighborhood',
#   'night',
#   'note',
#   'offic',
#   'often',
#   'park',
#   'privat',
#   'quiet',
#   'restaur',
#   'rv',
#   'solo',
#   'space',
#   'stay',
#   'third',
#   'thursday',
#   'travel',
#   'us',
#   'vehicl',
#   'work'},
#  {'15',
#   '5',
#   'allianc',
#   'allow',
#   'center',
#   'close',
#   'conveni',
#   'cozi',
#   'downtown',
#   'drive',
#   'environ',
#   'famili',
#   'fort',
#   'friendli',
#   'hous',
#   'i35',
#   'locat',
#   'long',
#   'look',
#   'minut',
#   'north',
#   'pet',
#   'profession',
#   'renter',
#   'restaur',
#   'safe',
#   'shop',
#   'singl',
#   'smoke',
#   'student',
#   'term',
#   'town',
#   'warm',
#   'worth'},
#  {'2',
#   '3',
#   'area',
#   'bathroom',
#   'bed',
#   'bedroom',
#   'bienvenido',
#   'car',
#   'close',
#   'corridor',
#   'dear',
#   'eleg',
#   'energi',
#   'equip',
#   'featur',
#   'garag',
#   'gorgeou',
#   'great',
#   'home',
#   'hope',
#   'hospit',
#   'houston',
#   'includ',
#   'kati',
#   'kitchen',
#   'live',
#   'locat',
#   'mall',
#   'mill',
#   'netflix',
#   'new',
#   'offer',
#   'one',
#   'outlet',
#   'park',
#   'plan',
#   'premium',
#   'profit',
#   'proxim',
#   'room',
#   'shop',
#   'sincer',
#   'sofa',
#   'space',
#   'stay',
#   'stori',
#   'studi',
#   'tailor',
#   'town',
#   'tv',
#   'tx',
#   'typhoon',
#   'water',
#   'wonder'},
#  {'2min',
#   'access',
#   'accompani',
#   'area',
#   'avail',
#   'away',
#   'background',
#   'bath',
#   'bedroom',
#   'closet',
#   'colina',
#   'complimentari',
#   'furnish',
#   'good',
#   'great',
#   'guest',
#   'happi',
#   'heart',
#   'highway',
#   'la',
#   'lake',
#   'lit',
#   'locat',
#   'neighborhood',
#   'newli',
#   'park',
#   'place',
#   'privat',
#   'quiet',
#   'renov',
#   'shower',
#   'surround',
#   'tub',
#   'welcom',
#   'well'},
#  {'10',
#   'austin',
#   'center',
#   'conveni',
#   'cozi',
#   'downtown',
#   'mile',
#   'place',
#   'restaur',
#   'shop'},
#  {'adventur',
#   'busi',
#   'coupl',
#   'famili',
#   'good',
#   'kid',
#   'place',
#   'solo',
#   'travel'},
#  {'3',
#   '40',
#   '5',
#   'adventur',
#   'back',
#   'boat',
#   'bring',
#   'busi',
#   'ceil',
#   'clear',
#   'coupl',
#   'cozi',
#   'day',
#   'deck',
#   'everi',
#   'famili',
#   'ft',
#   'great',
#   'group',
#   'high',
#   'jet',
#   'kayak',
#   'kid',
#   'kitchen',
#   'lake',
#   'lodg',
#   'love',
#   'overlook',
#   'place',
#   'pool',
#   "ski'",
#   'slip',
#   'solo',
#   'sunset',
#   'travel',
#   'use',
#   'view',
#   'w',
#   'water',
#   'window'},
#  {'15',
#   '2',
#   '3',
#   'away',
#   'bath',
#   'bed',
#   'bu',
#   'cabl',
#   'center',
#   'condo',
#   'cours',
#   'district',
#   'hermann',
#   'houston',
#   "houston'",
#   'includ',
#   'light',
#   'list',
#   'medic',
#   'minut',
#   'nearest',
#   'nrg',
#   'park',
#   'rail',
#   'rice',
#   'room',
#   'spare',
#   'stadium',
#   'station',
#   'stop',
#   'toiletri',
#   'univers',
#   'walk',
#   'wifi',
#   'within',
#   'zoo'},
#  {'acr',
#   'amp',
#   'area',
#   'back',
#   'bar',
#   'boast',
#   'borderlin',
#   'breakfast',
#   'bryan',
#   'central',
#   'close',
#   'colleg',
#   'counter',
#   'culdasec',
#   'dine',
#   'eat',
#   'either',
#   'enjoy',
#   'enough',
#   'even',
#   'fulli',
#   'furnish',
#   'garden',
#   'home',
#   'kitchen',
#   'larg',
#   'live',
#   'locat',
#   'much',
#   'open',
#   'park',
#   'porch',
#   'quick',
#   'quiet',
#   'remodel',
#   'restaur',
#   'room',
#   'second',
#   'shop',
#   'space',
#   'spaciou',
#   'splashpad',
#   'station',
#   'take',
#   'tanglewood',
#   'tile',
#   'top',
#   'walk'},
#  {'2',
#   'afford',
#   'anoth',
#   'apart',
#   'applianc',
#   'basic',
#   'bathroom',
#   'bedroom',
#   'bowl',
#   'comfort',
#   'condo',
#   'conveni',
#   'cook',
#   'cost',
#   'effect',
#   'etc',
#   'furnish',
#   'glass',
#   'guest',
#   'hous',
#   'kitchen',
#   'lock',
#   'love',
#   'medic',
#   'modern',
#   'one',
#   'plate',
#   'privat',
#   'safeti',
#   'share',
#   'short',
#   'silverwar',
#   'suit',
#   'term',
#   'updat',
#   'ware'},
#  {'10',
#   '45',
#   'across',
#   'away',
#   'beauti',
#   'cours',
#   'dine',
#   'golf',
#   'minut',
#   'neighborhood',
#   'nrg',
#   'park',
#   'perfect',
#   'place',
#   'privat',
#   'quiet',
#   'relax',
#   'restaur',
#   'right',
#   'stadium',
#   'street',
#   'take',
#   'ton',
#   'unwind'},
#  {'10',
#   '15',
#   '20',
#   '3',
#   '35',
#   'airport',
#   'antonio',
#   'bedroom',
#   'doubl',
#   'downtown',
#   'entranc',
#   'flag',
#   'home',
#   'make',
#   'min',
#   'privat',
#   'san',
#   'sea',
#   'six',
#   'size',
#   'suit',
#   'world'},
#  {'10',
#   '8',
#   'activ',
#   'along',
#   'area',
#   "area'",
#   'attract',
#   'backyard',
#   'basketbal',
#   'day',
#   'enjoy',
#   'entir',
#   'fill',
#   'friendli',
#   'game',
#   'guest',
#   'healthi',
#   'heat',
#   'jacuzzi',
#   'jog',
#   'larg',
#   'lifestyl',
#   'mani',
#   'neighborhood',
#   'one',
#   'outsid',
#   'pier',
#   'pm',
#   'pool',
#   'privat',
#   'properti',
#   'regist',
#   'rent',
#   'room',
#   'saltwat',
#   'start',
#   'tenni',
#   'tourist',
#   'walk'},
#  {'18',
#   '28',
#   '4',
#   '4342',
#   'also',
#   'bathroom',
#   'beauti',
#   'bedroom',
#   'blanco',
#   'concan',
#   'cours',
#   'ft',
#   'golf',
#   'gorgeou',
#   'guest',
#   'highest',
#   'hole',
#   'home',
#   'hous',
#   'level',
#   'littl',
#   'livabl',
#   'locat',
#   'one',
#   'peopl',
#   'point',
#   'rental',
#   'singl',
#   'sleep',
#   'space',
#   'sq',
#   'texa',
#   'vacat'},
#  {'60',
#   'access',
#   'also',
#   'bed',
#   'bedroom',
#   'chest',
#   'chiffarob',
#   'closet',
#   'drawer',
#   'full',
#   'hanger',
#   'pictur',
#   'privat',
#   'room',
#   'shelv',
#   'tv',
#   'w'},
#  {'1',
#   '2nd',
#   'actual',
#   'anytim',
#   'apart',
#   'arriv',
#   'bed',
#   'bedroom',
#   'check',
#   'comfort',
#   'conveni',
#   'fireplac',
#   'floor',
#   'great',
#   'hardwood',
#   'huge',
#   'lamin',
#   'locat',
#   'offer',
#   'perk',
#   'queen',
#   'self',
#   'size',
#   'space',
#   'spaciou',
#   "that'",
#   'time',
#   'treehous',
#   'welcom',
#   'wifi',
#   'window',
#   'work'},
#  {'10',
#   '15',
#   '281',
#   '35',
#   '410',
#   '5',
#   'access',
#   'adventur',
#   'airport',
#   'anyon',
#   'bamc',
#   'bed',
#   'close',
#   'establish',
#   'front',
#   'good',
#   'hous',
#   'ih',
#   'kitchen',
#   'locat',
#   'loop',
#   'love',
#   'minut',
#   'neighborhood',
#   'peopl',
#   'perfect',
#   'place',
#   'privat',
#   'quick',
#   'rent',
#   'rest',
#   'room',
#   'short',
#   'solo',
#   'stay',
#   'traffic',
#   'us',
#   'uthscsa',
#   'visit'},
#  {'4',
#   'among',
#   'area',
#   'away',
#   'back',
#   'blanco',
#   'call',
#   'canyon',
#   'cc',
#   'cedar',
#   'clear',
#   'creek',
#   'crystal',
#   'decompress',
#   'five',
#   'fredericksburg',
#   'get',
#   'green',
#   'growth',
#   'hill',
#   'hour',
#   'import',
#   'includ',
#   'lake',
#   'less',
#   'life',
#   'local',
#   'locat',
#   'minut',
#   'name',
#   'nestl',
#   'north',
#   'oak',
#   'offer',
#   'old',
#   'pedernal',
#   'perfect',
#   "potter'",
#   'reinvigor',
#   'retreat',
#   'river',
#   'scent',
#   'spot',
#   'strateg',
#   'tax',
#   'unwind',
#   'weekend',
#   "what'",
#   'wimberley',
#   'wood',
#   'word'},
#  {'adventur',
#   'austin',
#   'bed',
#   'busi',
#   'close',
#   'comfi',
#   'coupl',
#   'good',
#   'love',
#   'neighborhood',
#   'offer',
#   'outdoor',
#   'place',
#   'solo',
#   'space',
#   'travel'},
#  {'1',
#   '3',
#   'amp',
#   'anoth',
#   'area',
#   'bath',
#   'bedroom',
#   'beverag',
#   'deck',
#   'enjoy',
#   'feel',
#   'fellowship',
#   'longer',
#   'master',
#   'one',
#   'other',
#   'perfect',
#   'privat',
#   'share',
#   'smoke',
#   'stay',
#   'week'},
#  {'airport',
#   'bar',
#   'bath',
#   'bedroom',
#   'central',
#   'colina',
#   'condominium',
#   'dfw',
#   'everyth',
#   'floor',
#   'fulli',
#   'furnish',
#   'groceri',
#   'highway',
#   'includ',
#   'la',
#   'love',
#   'major',
#   'might',
#   'need',
#   'overlook',
#   'privat',
#   'restaur',
#   'shop',
#   'stay',
#   'store',
#   'top'},
#  {'1',
#   '3',
#   'access',
#   'addit',
#   'amp',
#   'area',
#   'avail',
#   'away',
#   'bath',
#   'bed',
#   'bedroom',
#   'beverag',
#   'center',
#   'deck',
#   'delight',
#   'design',
#   'distanc',
#   'district',
#   'downtown',
#   'ensuit',
#   'histor',
#   'home',
#   'keurig',
#   'known',
#   'live',
#   'magazin',
#   'mckinney',
#   'money',
#   'outdoor',
#   'pc',
#   'person',
#   'place',
#   'pool',
#   'privat',
#   'rate',
#   'refriger',
#   'roll',
#   'room',
#   'space',
#   'squar',
#   'stock',
#   'testament',
#   'town',
#   'tv',
#   'twin',
#   'vibrant',
#   'walk'},
#  {'1200',
#   '2',
#   '6',
#   'also',
#   'amp',
#   'anybodi',
#   'apart',
#   'applianc',
#   'bath',
#   'bed',
#   'built',
#   'ceil',
#   'ceram',
#   'closet',
#   'comfort',
#   'comput',
#   'cook',
#   'crown',
#   'custom',
#   'delici',
#   'desk',
#   'dramat',
#   'dryer',
#   'entri',
#   'equip',
#   'everyth',
#   'execut',
#   'expans',
#   'famili',
#   'fan',
#   'featur',
#   'foot',
#   'ft',
#   'full',
#   'fulli',
#   'furnish',
#   'garden',
#   'includ',
#   'kitchen',
#   'meal',
#   'modern',
#   'mold',
#   'need',
#   'nine',
#   'overs',
#   'peopl',
#   'pool',
#   'room',
#   'size',
#   'sleep',
#   'spaciou',
#   'sq',
#   'tile',
#   'trim',
#   'tub',
#   'view',
#   'walk',
#   'washer',
#   'would'},
#  {'busi',
#   'campu',
#   'ceil',
#   'close',
#   'coupl',
#   'famili',
#   'good',
#   'high',
#   'kid',
#   'kitchen',
#   'locat',
#   'love',
#   'place',
#   'tamu',
#   'travel'},
#  {'20',
#   'air',
#   'airport',
#   'avail',
#   'center',
#   'chair',
#   'coupl',
#   'cover',
#   'distanc',
#   'downtown',
#   'famili',
#   'great',
#   'groceri',
#   'hobbi',
#   'hous',
#   'kid',
#   'locat',
#   'mattress',
#   'minut',
#   'multipl',
#   'need',
#   'patio',
#   'restaur',
#   'shop',
#   'store',
#   'tabl',
#   'two',
#   'walk',
#   'walmart',
#   'within'},
#  {'adventur',
#   'big',
#   'busi',
#   'close',
#   'coupl',
#   'famili',
#   'field',
#   'friend',
#   'furri',
#   'good',
#   'group',
#   'kid',
#   'kyle',
#   'locat',
#   'love',
#   'outdoor',
#   'park',
#   'pet',
#   'place',
#   'restaur',
#   'solo',
#   'space',
#   'travel'},
#  {'femal', 'list'},
#  {'decor', 'home', 'modern', 'nice'},
#  {'$10',
#   '$60',
#   '6',
#   'airlin',
#   'airport',
#   'also',
#   'american',
#   'attract',
#   'center',
#   'charg',
#   'close',
#   'cowboy',
#   'dalla',
#   'day',
#   'dfw',
#   'euless',
#   'fee',
#   'flag',
#   'friendli',
#   'ft',
#   'golf',
#   'home',
#   'like',
#   'mile',
#   'near',
#   'per',
#   'pet',
#   'ranger',
#   'six',
#   'stadium',
#   'train',
#   'week',
#   'worth'},
#  {'adventur',
#   'aristocrat',
#   'austin',
#   'bar',
#   'barley',
#   'bbq',
#   'brentwood',
#   'bufalina',
#   'burnet',
#   'charact',
#   'christma',
#   'comfort',
#   'district',
#   'downtown',
#   'due',
#   'famou',
#   'flyrit',
#   'found',
#   'great',
#   'hous',
#   'includ',
#   "lala'",
#   'launch',
#   'lick',
#   'locat',
#   'look',
#   'notch',
#   'pad',
#   'place',
#   'pour',
#   'public',
#   'quick',
#   'restaur',
#   'right',
#   'sever',
#   'stone',
#   "stubb'",
#   'swine',
#   'throw',
#   'top',
#   'transit',
#   'walk',
#   'yard'},
#  {'20',
#   'access',
#   'air',
#   'airport',
#   'avail',
#   'away',
#   'bath',
#   'bedroom',
#   'busi',
#   'cul',
#   'de',
#   'dog',
#   'downstair',
#   'drive',
#   'easi',
#   'end',
#   'famili',
#   'full',
#   'great',
#   'greenbelt',
#   'hi',
#   'hous',
#   'houston',
#   'intercontinent',
#   'kid',
#   "kingwood'",
#   'larger',
#   'mattress',
#   'minut',
#   'parti',
#   'privat',
#   'quiet',
#   'run',
#   'sac',
#   'second',
#   'stay',
#   'three',
#   'tuck',
#   'two',
#   'upstair',
#   'us',
#   'walk',
#   'wonder'},
#  {'5',
#   'area',
#   'bathroom',
#   'cantera',
#   'clear',
#   'coffe',
#   'feel',
#   'game',
#   'home',
#   'host',
#   'la',
#   'like',
#   'make',
#   'minut',
#   'mountain',
#   'neighborhood',
#   'provid',
#   'rent',
#   'room',
#   'shampoo',
#   'soap',
#   'space',
#   'towel',
#   'view',
#   'wonder'},
#  {'2',
#   '3',
#   'airport',
#   'away',
#   'back',
#   'byron',
#   'clean',
#   'colina',
#   'dfw',
#   'enjoy',
#   'famili',
#   'floorplan',
#   'golf',
#   'group',
#   'home',
#   'la',
#   'larg',
#   'mile',
#   'modern',
#   'nelson',
#   'open',
#   'patio',
#   'perfect',
#   'relax',
#   'stori',
#   'tournament',
#   'townhous'},
#  {'99',
#   'arriv',
#   'bathroom',
#   'centerra',
#   'close',
#   'corridor',
#   'cours',
#   'driver',
#   'drug',
#   'due',
#   'energi',
#   'full',
#   'golf',
#   'heart',
#   'i10',
#   'kati',
#   'la',
#   'licens',
#   'mill',
#   'one',
#   'park',
#   'person',
#   'pet',
#   'pool',
#   'proxim',
#   'room',
#   'smoke',
#   'thank',
#   'toll',
#   'valid',
#   'way'},
#  {'await',
#   'brand',
#   'charm',
#   'creek',
#   'downtown',
#   'histor',
#   'lodg',
#   'luxuri',
#   'meet',
#   'minut',
#   'modern',
#   'new',
#   'tctx',
#   'town',
#   'urban'},
#  {'allow',
#   'boat',
#   'countri',
#   'disturb',
#   'dock',
#   'experi',
#   'famili',
#   'float',
#   'fun',
#   'great',
#   'hill',
#   'irreplac',
#   'kind',
#   'locat',
#   'memori',
#   'one',
#   'privat',
#   'ramp',
#   'refresh',
#   'repres',
#   'sceneri',
#   'seclud',
#   'sun',
#   'swim',
#   'valu',
#   'water',
#   'without'},
#  {'1',
#   '10',
#   '15',
#   '3',
#   '4',
#   'amp',
#   'backyard',
#   'bathroom',
#   'bedroom',
#   'close',
#   'etc',
#   'full',
#   'game',
#   'half',
#   'houston',
#   'jacuzzi',
#   'live',
#   'locat',
#   'mall',
#   'master',
#   'min',
#   'movi',
#   'neighborhood',
#   'patio',
#   'quiet',
#   'restroom',
#   'room',
#   'shade',
#   'studi',
#   'tabl',
#   'upstair',
#   'w',
#   'walmart'},
#  {'42',
#   'apart',
#   'bed',
#   'cutleri',
#   'detach',
#   'dish',
#   'entranc',
#   'equip',
#   'full',
#   'fulli',
#   'furnish',
#   'garag',
#   'includ',
#   'keurig',
#   'kitchen',
#   'one',
#   'pan',
#   'pop',
#   'privat',
#   'queen',
#   'size',
#   'sofa',
#   'studio'},
#  {'cottag', 'lakesid', 'oak', 'perfect'},
#  {'adventur',
#   'busi',
#   'come',
#   'coupl',
#   'cultur',
#   'famili',
#   'four',
#   'friendli',
#   'good',
#   'group',
#   'lgbt',
#   'list',
#   'place',
#   'refriger',
#   'religion',
#   'room',
#   'solo',
#   'travel',
#   'tv',
#   'two',
#   'welcom'},
#  {'aggieland',
#   'amp',
#   'close',
#   'dog',
#   'friendli',
#   'great',
#   'locat',
#   'love',
#   'place',
#   'quiet',
#   'research',
#   'school',
#   'student',
#   'texa',
#   'vet',
#   'visit'},
#  {'2',
#   '45',
#   '610',
#   '9',
#   'access',
#   'airport',
#   'amp',
#   'away',
#   'cab',
#   'cabl',
#   'center',
#   'climat',
#   'commun',
#   'control',
#   'cultur',
#   'dine',
#   'district',
#   'downtown',
#   'enjoy',
#   'floor',
#   'freeway',
#   'h',
#   'heart',
#   'high',
#   'hobbi',
#   'immedi',
#   'individu',
#   'loop',
#   'medic',
#   'midtown',
#   'min',
#   'museum',
#   'nightlif',
#   'nrg',
#   'offer',
#   'park',
#   'perfectli',
#   'premium',
#   'ride',
#   'safe',
#   'secur',
#   'separ',
#   'short',
#   'situat',
#   'speed',
#   'stadium',
#   'town',
#   'townhous',
#   'via',
#   'w',
#   'wifi'},
#  {'12',
#   '3',
#   '4',
#   'bathroom',
#   'bedroom',
#   'cedar',
#   'comfort',
#   'creek',
#   'except',
#   'getaway',
#   'guest',
#   'home',
#   'hous',
#   'immens',
#   'lake',
#   'lakefront',
#   'locat',
#   'next',
#   'outstand',
#   'provid',
#   'room',
#   'terrif',
#   'texa',
#   'ultim',
#   'vacat'},
#  {'10',
#   '2',
#   '2015',
#   '2300',
#   '4',
#   'bath',
#   'beauti',
#   'bedroom',
#   'built',
#   'conro',
#   'corner',
#   'drive',
#   'ft',
#   'half',
#   'home',
#   'hous',
#   'interest',
#   'know',
#   'lake',
#   'let',
#   'locat',
#   'look',
#   'lot',
#   'minut',
#   'new',
#   'one',
#   'pleas',
#   'rent',
#   'section',
#   'sq',
#   'stori',
#   'subdivis',
#   'thank',
#   'total',
#   'tx',
#   'woodland'},
#  {'50',
#   'amen',
#   'bed',
#   'guest',
#   'home',
#   'love',
#   'number',
#   'queen',
#   'sleep',
#   'suit'},
#  {'cedar',
#   'countrysid',
#   'creek',
#   'get',
#   'lake',
#   'look',
#   'need',
#   'room',
#   'short',
#   'stay',
#   'stroll',
#   'travel',
#   'way',
#   'weekend',
#   'whether'},
#  {'adventur',
#   'big',
#   'busi',
#   'coupl',
#   'famili',
#   'friend',
#   'furri',
#   'good',
#   'group',
#   'kid',
#   'pet',
#   'place',
#   'solo',
#   'travel'},
#  {'adventur',
#   'close',
#   'coupl',
#   'day',
#   'deer',
#   'establish',
#   'everi',
#   'famili',
#   'friendli',
#   'good',
#   'hous',
#   'kid',
#   'love',
#   'mani',
#   'neighborhood',
#   'often',
#   'open',
#   'park',
#   'place',
#   'river',
#   'schlitterbahn',
#   'seen',
#   'solo',
#   'space',
#   'street',
#   'tree',
#   'well',
#   'wide',
#   'yard'},
#  {'3',
#   '35',
#   '99',
#   'amp',
#   'area',
#   'avail',
#   'away',
#   'bath',
#   'bed',
#   'boat',
#   'book',
#   'boutiqu',
#   'cabin',
#   'comfi',
#   'couch',
#   'cozi',
#   'dine',
#   'excel',
#   'fairfield',
#   'fish',
#   'get',
#   'lake',
#   'launch',
#   'local',
#   'lux',
#   'metroplex',
#   'mexia',
#   'mile',
#   'nice',
#   'overs',
#   'peac',
#   'perfect',
#   'price',
#   'qualiti',
#   'queen',
#   'quiet',
#   'shower',
#   'size',
#   'sleep',
#   'spot',
#   'stay',
#   'today',
#   'tub',
#   'view',
#   'waco'},
#  {'anyth',
#   'bed',
#   'car',
#   'comfi',
#   'cute',
#   'demand',
#   'direct',
#   'enjoy',
#   'fur',
#   'help',
#   'hous',
#   'kid',
#   'know',
#   'let',
#   'locat',
#   'make',
#   'need',
#   'neighborhood',
#   'quiet',
#   'recommend',
#   'reserv',
#   'room',
#   'servic',
#   'sleep',
#   'stay',
#   "there'",
#   'two',
#   'us',
#   "we'r",
#   'welcom'},
#  {'activ',
#   'adventur',
#   'beach',
#   'bed',
#   'close',
#   'comfi',
#   'coupl',
#   'dine',
#   'famili',
#   'friendli',
#   'good',
#   'great',
#   'love',
#   'neighborhood',
#   'nightlif',
#   'place',
#   'restaur',
#   'solo',
#   'view'},
#  {'10',
#   '121',
#   '20',
#   '635',
#   '75',
#   'activ',
#   'allow',
#   'also',
#   'area',
#   'avail',
#   'away',
#   'board',
#   'card',
#   'ceil',
#   'close',
#   'come',
#   'comfort',
#   'cover',
#   'dalla',
#   'day',
#   'dice',
#   'fan',
#   'game',
#   'home',
#   'hot',
#   'hwi',
#   'larg',
#   'light',
#   'locat',
#   'min',
#   'multipl',
#   'near',
#   'neighborhood',
#   'outdoor',
#   'pool',
#   'porch',
#   'privat',
#   'quiet',
#   'relax',
#   'restaur',
#   'seat',
#   'seclud',
#   'soak',
#   'star',
#   'stress',
#   'sun',
#   'swim',
#   'ton',
#   'tub',
#   'unwind'},
#  {'access',
#   'adventur',
#   'antonio',
#   'bandera',
#   'beauti',
#   'boern',
#   'busi',
#   'close',
#   'countri',
#   'coupl',
#   'creek',
#   'famili',
#   'fiesta',
#   'great',
#   'hill',
#   'kid',
#   'locat',
#   'love',
#   'part',
#   'quarter',
#   'river',
#   'san',
#   'sea',
#   'solo',
#   'texa',
#   'travel',
#   'view',
#   'wonder',
#   'world'},
#  {'1',
#   '12',
#   '13',
#   '20',
#   '7',
#   'acr',
#   'airpot',
#   'apt',
#   'bathtub',
#   'beauti',
#   'bed',
#   'bowl',
#   'complet',
#   'deal',
#   'decor',
#   'detach',
#   'downtown',
#   'effic',
#   'galleria',
#   'garag',
#   'hobbi',
#   'landscap',
#   'lot',
#   'mall',
#   'mile',
#   'min',
#   'nrg',
#   'privat',
#   'queen',
#   'quiet',
#   'rain',
#   'roko',
#   'shower',
#   'small',
#   'stadium',
#   'super',
#   'sweet',
#   'tv',
#   'wifi'},
#  {'1',
#   '2',
#   'aggieland',
#   'also',
#   'apart',
#   'applianc',
#   'bath',
#   'bathroom',
#   'beauti',
#   'bed',
#   'bedroom',
#   'bottom',
#   'clean',
#   'comfort',
#   'complet',
#   'cotton',
#   'count',
#   'counter',
#   'crisp',
#   'featur',
#   'floor',
#   'fluffi',
#   'fulli',
#   'furnish',
#   'granit',
#   'great',
#   'hardwood',
#   'high',
#   'interior',
#   'kitchen',
#   'like',
#   'linen',
#   'locat',
#   'new',
#   'newli',
#   'next',
#   'perfectli',
#   'provid',
#   'queen',
#   'renov',
#   'size',
#   'spa',
#   'stainless',
#   'stay',
#   'steel',
#   'thread',
#   'top',
#   'towel',
#   'visit'},
#  {'access',
#   'avail',
#   'bike',
#   'center',
#   'commun',
#   'deck',
#   'distanc',
#   'downtown',
#   'eado',
#   'easi',
#   'gate',
#   'medic',
#   'midtown',
#   'new',
#   'park',
#   'privat',
#   'public',
#   'rail',
#   'rice',
#   'rooftop',
#   'room',
#   'townhom',
#   'trail',
#   'univers',
#   'walk',
#   'within'},
#  {'abod',
#   'austin',
#   'back',
#   'bike',
#   'built',
#   'downtown',
#   'enjoy',
#   'famili',
#   'friendli',
#   'garden',
#   'hike',
#   'home',
#   'host',
#   'less',
#   'mile',
#   'modern',
#   'newli',
#   'nightlif',
#   'peac',
#   'properti',
#   'quiet',
#   'rainey',
#   'right',
#   'spaciou',
#   'street',
#   'trail',
#   'yet'},
#  {'couch', 'great', 'sleep'},
#  {'10',
#   '25',
#   '35',
#   'acogedor',
#   'aeropuerto',
#   'alojamiento',
#   'alto',
#   'ambient',
#   'autobus',
#   'bueno',
#   'casa',
#   'centro',
#   'ciudad',
#   'de',
#   'debido',
#   'distancia',
#   'el',
#   'en',
#   'encantar',
#   'encuentra',
#   'es',
#   'espacio',
#   'hay',
#   'interé',
#   'la',
#   'lo',
#   'lugar',
#   'mi',
#   'min',
#   'minuto',
#   'mucha',
#   'muy',
#   'negocio',
#   'nocturna',
#   'para',
#   'público',
#   'que',
#   'se',
#   'te',
#   'techo',
#   'tien',
#   'tranquilidad',
#   'transport',
#   'turismo',
#   'un',
#   'va',
#   'van',
#   'viajero',
#   'vida'},
#  {'3',
#   'accommod',
#   'aliv',
#   'area',
#   'attend',
#   'bar',
#   'basin',
#   'bath',
#   'bedroom',
#   'closet',
#   'commun',
#   'dalla',
#   'desk',
#   'door',
#   'dual',
#   'first',
#   'floor',
#   'food',
#   'full',
#   'gate',
#   'greenvil',
#   'groceri',
#   'internet',
#   'jet',
#   "joe'",
#   'larg',
#   'leav',
#   'length',
#   'light',
#   'locat',
#   'lowest',
#   'master',
#   'minut',
#   'mirror',
#   'natur',
#   'neighborhood',
#   'peopl',
#   'privat',
#   'restaur',
#   'room',
#   'safari',
#   'shop',
#   'shower',
#   'special',
#   'store',
#   'superb',
#   'theme',
#   'toilet',
#   'ton',
#   'trader',
#   'tub',
#   'within'},
#  {'away',
#   'bed',
#   'bliss',
#   'calm',
#   'care',
#   'closet',
#   'color',
#   'come',
#   'complet',
#   'design',
#   'décor',
#   'eleg',
#   'feel',
#   'intent',
#   'make',
#   'nightstand',
#   'peac',
#   'pillow',
#   'pure',
#   'queen',
#   'relax',
#   'room',
#   'simpl',
#   'size',
#   'soft',
#   'soul',
#   'take',
#   'tranquil',
#   'transport',
#   'walk',
#   'wall',
#   'white'},
#  {'bathroom',
#   'bed',
#   'cabl',
#   'closet',
#   'coffe',
#   'downstair',
#   'dryer',
#   'ensuit',
#   'free',
#   'fridg',
#   'hair',
#   "kya'",
#   'larg',
#   'luxuri',
#   'maker',
#   'mattress',
#   'mini',
#   'qualiti',
#   'queen',
#   'room',
#   'spa',
#   'televis',
#   'toiletri',
#   'towel',
#   'walk',
#   'wifi'},
#  {'1',
#   '2',
#   '3',
#   '5',
#   '6',
#   'accommod',
#   'amp',
#   'beauti',
#   'couch',
#   'easili',
#   'field',
#   'give',
#   'hous',
#   'kyle',
#   'locat',
#   'minut',
#   'perfect',
#   'place',
#   'rental',
#   'road',
#   'shot',
#   'sleep',
#   'straight',
#   'texa',
#   'wellborn',
#   'will'},
#  {"'em",
#   '2',
#   '4',
#   'also',
#   'amp',
#   'bathroom',
#   'bedroom',
#   'block',
#   'campu',
#   'floor',
#   'gig',
#   'home',
#   'hous',
#   'howdi',
#   'individu',
#   'list',
#   'need',
#   'one',
#   'quaint',
#   'queen',
#   'reveil',
#   'rm',
#   'room',
#   'share',
#   'texa',
#   'three',
#   'throughout',
#   'twin',
#   'wood'},
#  {'aquariu',
#   'away',
#   'bath',
#   'bay',
#   'bedroom',
#   'bound',
#   'condo',
#   'condominium',
#   'contemporari',
#   'din',
#   'fall',
#   'famili',
#   'four',
#   'front',
#   'full',
#   'kitchen',
#   'live',
#   'love',
#   'ocean',
#   'one',
#   'perfect',
#   'properti',
#   'room',
#   'sand',
#   'side',
#   'spectacular',
#   'step',
#   'unit',
#   'view'},
#  {'20',
#   'art',
#   'avail',
#   'bicycl',
#   'bishop',
#   'ceil',
#   'cliff',
#   'cultur',
#   'desir',
#   'district',
#   'dryer',
#   'fill',
#   'fish',
#   'garden',
#   'gold',
#   'guesthous',
#   'hair',
#   'hot',
#   'includ',
#   'keurig',
#   'light',
#   'massag',
#   'medit',
#   'microwav',
#   'natur',
#   'north',
#   'oak',
#   'offer',
#   'onto',
#   'open',
#   'oven',
#   'pond',
#   'refriger',
#   'rest',
#   'servic',
#   'shiplap',
#   'small',
#   'space',
#   'studio',
#   'toaster',
#   'tour',
#   'towel',
#   'tub',
#   'vault',
#   'view',
#   'warm',
#   'warmer',
#   'year',
#   'yoga'},
#  {'airport',
#   'alojamiento',
#   'aventurero',
#   'bueno',
#   'con',
#   'de',
#   'encantar',
#   'es',
#   'espacio',
#   'extrem',
#   'familia',
#   'hijo',
#   'hobbi',
#   'interé',
#   'lugar',
#   'mi',
#   'para',
#   'por',
#   'relax',
#   'te',
#   'va'},
#  {"'other",
#   '640',
#   'bed',
#   'breez',
#   'combo',
#   'condo',
#   'dine',
#   'distanc',
#   'entri',
#   'foot',
#   'full',
#   'island',
#   'king',
#   'kitchen',
#   'lazi',
#   'new',
#   'newli',
#   'north',
#   "note'",
#   'padr',
#   'pleas',
#   'pull',
#   'read',
#   'renov',
#   'restaur',
#   'retreat',
#   'schlitterbahn',
#   'section',
#   'secur',
#   'shower',
#   'size',
#   'sofa',
#   'squar',
#   'tabl',
#   'thank',
#   'thing',
#   'tub',
#   'walk'},
#  {'away',
#   'beach',
#   'commun',
#   'contrari',
#   'cottag',
#   'creek',
#   'cul',
#   'de',
#   'downtown',
#   'gate',
#   'get',
#   'granburi',
#   'hous',
#   'lakesid',
#   'minut',
#   'quiet',
#   'sac',
#   'seclud',
#   'stori',
#   'surround',
#   'ten',
#   'tree',
#   'two'},
#  {'1',
#   '10',
#   '15',
#   '45',
#   'apart',
#   'bathroom',
#   'coffe',
#   'come',
#   'day',
#   'dish',
#   'downtown',
#   'drive',
#   'kitchen',
#   'locat',
#   'lot',
#   'maker',
#   'minut',
#   'need',
#   'neighborhood',
#   'nrg',
#   'oven',
#   'person',
#   'place',
#   'quiet',
#   'refriger',
#   'roku',
#   'space',
#   'stadium',
#   'storag',
#   'studio',
#   'toaster',
#   'tv'},
#  {'antonio',
#   'area',
#   'citi',
#   'come',
#   'feel',
#   'friendli',
#   'home',
#   'host',
#   'invit',
#   'littl',
#   'maison',
#   'middl',
#   'pool',
#   'relax',
#   'right',
#   'san',
#   'tranquil',
#   'welcom',
#   'whether',
#   'work'},
#  {'amp',
#   'area',
#   'bedroom',
#   'close',
#   'dalla',
#   'explor',
#   'famili',
#   'flag',
#   'forth',
#   'friendli',
#   'great',
#   'harbor',
#   'home',
#   'hurrican',
#   'individu',
#   'price',
#   'privat',
#   'ranger',
#   'six',
#   'spaciou',
#   'stadium',
#   'texa',
#   'two',
#   'worth'},
#  {'3',
#   'bar',
#   'bath',
#   'bed',
#   'bu',
#   'c',
#   'cedar',
#   'close',
#   'comfort',
#   'concret',
#   'downtown',
#   'first',
#   'floor',
#   'garden',
#   'heat',
#   'highway',
#   'line',
#   'locat',
#   'major',
#   'metal',
#   'one',
#   'patio',
#   'restaur',
#   'room',
#   'separ',
#   'spring',
#   'stori',
#   'tollway',
#   'townhous'},
#  {'5', 'beach', 'clean', 'fee', 'garag', 'includ', 'min', 'park', 'walk'},
#  {'1',
#   '2',
#   '25',
#   '3',
#   '4',
#   '5',
#   '8',
#   'access',
#   'airi',
#   'airport',
#   'approx',
#   'austin',
#   'avail',
#   'bath',
#   'bedroom',
#   'beelin',
#   'clean',
#   'comfort',
#   'corpor',
#   'cottag',
#   'dell',
#   'diamond',
#   'domain',
#   'downtown',
#   'easi',
#   'entir',
#   'express',
#   'food',
#   'great',
#   'home',
#   'hospit',
#   'host',
#   'light',
#   'locat',
#   'major',
#   'mile',
#   'minut',
#   'road',
#   'rock',
#   'round',
#   'texa',
#   'tx',
#   'whole',
#   'within'},
#  {'1',
#   '35',
#   '66',
#   'across',
#   'bar',
#   'bbq',
#   'clean',
#   'comfort',
#   "contractor'",
#   'conveni',
#   'corner',
#   'cpchem',
#   'deliv',
#   'distanc',
#   'entranc',
#   'fire',
#   'ga',
#   'hous',
#   'local',
#   'locat',
#   'mile',
#   'ocean',
#   'old',
#   'phillip',
#   'pit',
#   'recent',
#   'relax',
#   'restaur',
#   'room',
#   'sever',
#   'short',
#   'southbound',
#   'station',
#   'store',
#   'street',
#   'time',
#   'tx',
#   'updat',
#   'want',
#   'well'},
#  {'10',
#   '15',
#   '19th',
#   'adventur',
#   'airport',
#   'amp',
#   'arlington',
#   'aug',
#   'avail',
#   'book',
#   'busi',
#   'cours',
#   'dalla',
#   'dfw',
#   'discount',
#   'even',
#   'fort',
#   'golf',
#   'great',
#   'groceri',
#   'henc',
#   'highway',
#   'hous',
#   'intern',
#   'locat',
#   'long',
#   'major',
#   'min',
#   'modern',
#   'near',
#   'park',
#   'privat',
#   'restaur',
#   'room',
#   'short',
#   'space',
#   'stadium',
#   'star',
#   'store',
#   'stori',
#   'student',
#   'term',
#   'texa',
#   'travel',
#   'two',
#   'ut',
#   'worker',
#   'worth'},
#  {'apart',
#   'area',
#   'attach',
#   'complex',
#   'garag',
#   'look',
#   'pool',
#   'privat',
#   'quiet',
#   'staircas'},
#  {'cabin', 'comfort', 'home', 'style', 'top', 'tree', 'uniqu'},
#  {'$75',
#   '15',
#   '15th',
#   '18',
#   '2',
#   '21',
#   '3',
#   '5',
#   '59',
#   'access',
#   'advanc',
#   'airbnb',
#   'airport',
#   'amp',
#   'avail',
#   'back',
#   'bathroom',
#   'bbq',
#   'bedroom',
#   'builder',
#   'bush',
#   'collect',
#   'cours',
#   'custom',
#   'discount',
#   'downtown',
#   'easi',
#   'eastex',
#   'fairway',
#   'fee',
#   'fenc',
#   'freeway',
#   'georg',
#   'golf',
#   'grill',
#   'groceri',
#   'hole',
#   'home',
#   'houston',
#   'iah',
#   'intern',
#   'kid',
#   'kroger',
#   'locat',
#   'luxuri',
#   'mani',
#   'mile',
#   'minut',
#   'nearbi',
#   'onlin',
#   'pet',
#   'play',
#   'prime',
#   'public',
#   'qti',
#   'restaur',
#   'separ',
#   'store',
#   'tee',
#   'time',
#   'tour',
#   'within',
#   'yard'},
#  {'10',
#   '2017',
#   '59',
#   'away',
#   'countri',
#   'hauler',
#   'highway',
#   'i45',
#   'line',
#   'minut',
#   'new',
#   'top',
#   'toy'},
#  {'access',
#   'activ',
#   'adventur',
#   'amp',
#   'beauti',
#   'board',
#   'busi',
#   'cano',
#   'contact',
#   'coupl',
#   'dalla',
#   'detail',
#   'enjoy',
#   'flat',
#   'friend',
#   'furri',
#   'home',
#   'host',
#   'kayak',
#   'lake',
#   'lewisvil',
#   'love',
#   'perfect',
#   'pet',
#   'place',
#   'solo',
#   'travel',
#   'view',
#   'water'},
#  {'antiqu',
#   'bed',
#   'bright',
#   'closet',
#   'cloth',
#   'dresser',
#   'full',
#   'furnitur',
#   'hang',
#   'hook',
#   'light',
#   'room',
#   'vaniti'},
#  {'3',
#   '3160',
#   '8',
#   'air',
#   'base',
#   'beauti',
#   'bed',
#   'bedroom',
#   'big',
#   'comfort',
#   'day',
#   'doubl',
#   'enjoy',
#   'entir',
#   'famili',
#   'flag',
#   'forc',
#   'fresh',
#   'ft',
#   'full',
#   'fulli',
#   'furnish',
#   'groceri',
#   'group',
#   'hous',
#   'king',
#   'kitchen',
#   'larg',
#   'laundri',
#   'linen',
#   'live',
#   'loft',
#   'mi',
#   'near',
#   'nearbi',
#   'neighborhood',
#   'one',
#   'patio',
#   'plenti',
#   'pool',
#   'queen',
#   'quiet',
#   'rent',
#   'restaur',
#   'riverwalk',
#   'room',
#   'safe',
#   'sea',
#   'shop',
#   'six',
#   'size',
#   'sleep',
#   'sq',
#   'store',
#   'tabl',
#   'three',
#   'towel',
#   'twin',
#   'two',
#   'world'},
#  {"1920'",
#   '2',
#   '7th',
#   'aesthet',
#   'bungalow',
#   'cultur',
#   'distanc',
#   'district',
#   'downtown',
#   'famili',
#   'friendli',
#   'mile',
#   'modern',
#   'neighborhood',
#   'recent',
#   'renov',
#   'roger',
#   'safe',
#   'walk',
#   'west'},
#  {'block',
#   'curtain',
#   'get',
#   'light',
#   'mattress',
#   'morn',
#   'peac',
#   'pillow',
#   'room',
#   'soft',
#   "that'",
#   'top'},
#  {'adventur',
#   'atmospher',
#   'busi',
#   'close',
#   'coupl',
#   'famili',
#   'good',
#   'kid',
#   'locat',
#   'love',
#   'mall',
#   'oak',
#   'park',
#   'peac',
#   'place',
#   'post',
#   'solo',
#   'travel',
#   'veteran'},
#  {'2',
#   '3',
#   '610',
#   '8',
#   'base',
#   'bath',
#   'bedroom',
#   'bellair',
#   'border',
#   'bowl',
#   'car',
#   'center',
#   'close',
#   'cozi',
#   'downtown',
#   'enjoy',
#   'even',
#   'freeway',
#   'fulli',
#   'galleria',
#   'home',
#   'keurig',
#   'kirbi',
#   'kitchen',
#   'list',
#   'locat',
#   'loop',
#   'medic',
#   'mile',
#   'montros',
#   'need',
#   'neighborhood',
#   'ninja',
#   'peac',
#   'recommend',
#   'relax',
#   'right',
#   'secret',
#   'set',
#   'shot',
#   'space',
#   'spread',
#   'stadium',
#   'stock',
#   'straight',
#   'sugarland',
#   'super',
#   'texa',
#   'upper',
#   'urban',
#   'westburi'},
#  {'15',
#   '23',
#   '24',
#   '25',
#   '35',
#   '40',
#   '45',
#   '60',
#   'airport',
#   'antonio',
#   'austin',
#   'braunfel',
#   'canyon',
#   'cool',
#   'downtown',
#   'flag',
#   'gruen',
#   'intern',
#   'lake',
#   'marco',
#   'mile',
#   'min',
#   'new',
#   'outlet',
#   'san',
#   'schlitterbaun',
#   'seaworld',
#   'six',
#   'super'},
#  {'beauti',
#   'comfort',
#   'conveni',
#   'divers',
#   'due',
#   'décor',
#   'experi',
#   'famili',
#   'feel',
#   'getaway',
#   'guest',
#   'home',
#   'hous',
#   'locat',
#   'longer',
#   'look',
#   'mani',
#   'may',
#   'modern',
#   'outsid',
#   'outskirt',
#   'perfect',
#   'person',
#   'relat',
#   'retreat',
#   'shenandoah',
#   'small',
#   'stay',
#   'toward',
#   'uniqu',
#   'vacat',
#   'weekend',
#   'woodland',
#   'work'},
#  {'2',
#   '30',
#   'air',
#   'amp',
#   'antiqu',
#   'bath',
#   'beauti',
#   'bed',
#   'bedroom',
#   'bell',
#   'blue',
#   'brazo',
#   'campu',
#   'charm',
#   'close',
#   'complet',
#   'contain',
#   'cottag',
#   'countri',
#   'cream',
#   'decor',
#   'doubl',
#   'enjoy',
#   'fair',
#   'fresh',
#   'front',
#   'full',
#   'fulli',
#   'getaway',
#   'gorgeou',
#   'histor',
#   'home',
#   'ice',
#   'independ',
#   'kitchen',
#   'littl',
#   'locat',
#   'minut',
#   'park',
#   'perfect',
#   'porch',
#   'restaur',
#   'retreat',
#   'rocker',
#   'round',
#   'self',
#   'shop',
#   'state',
#   'sunset',
#   'superb',
#   'top',
#   'trail',
#   'univers',
#   'washington'},
#  {'1',
#   '10',
#   '15',
#   '3',
#   '35',
#   '4',
#   '5',
#   '7',
#   'activ',
#   'airport',
#   'antonio',
#   'austin',
#   'comfort',
#   'conveni',
#   'discount',
#   'downtown',
#   'famili',
#   'fort',
#   'guest',
#   'honor',
#   'houston',
#   'hr',
#   'king',
#   'long',
#   'mile',
#   'militari',
#   'min',
#   'need',
#   'reserv',
#   'sam',
#   'san',
#   'satisfi',
#   'serv',
#   'size',
#   'spaciou',
#   'stay',
#   'suit',
#   'term',
#   'tx',
#   'welcom'},
#  {'23',
#   '25',
#   '26',
#   '30',
#   'airport',
#   'antonio',
#   'beauti',
#   'braunfel',
#   'bridg',
#   'cavern',
#   'chao',
#   'clean',
#   'close',
#   'commun',
#   'famili',
#   'great',
#   'group',
#   'home',
#   'locat',
#   'minut',
#   'natur',
#   'new',
#   'nicest',
#   'offer',
#   'perfect',
#   'place',
#   'quiet',
#   'remodel',
#   'river',
#   'safe',
#   'san',
#   'schertz',
#   'stay',
#   'uniqu',
#   'walk',
#   'without'},
#  {'20',
#   'addison',
#   'adventur',
#   'airport',
#   'area',
#   'away',
#   'beauti',
#   'busi',
#   'close',
#   'coupl',
#   'cours',
#   'cultur',
#   'dallasmi',
#   'enjoy',
#   'field',
#   'golf',
#   'good',
#   'great',
#   'love',
#   'minut',
#   'place',
#   'restaur',
#   'solo',
#   'sunset',
#   'travel',
#   'view',
#   'walk'},
#  {'59',
#   'acr',
#   'air',
#   'bantam',
#   'bluebonnet',
#   'boy',
#   'cabin',
#   'chicken',
#   'curli',
#   'donkey',
#   'earth',
#   'essenti',
#   'explor',
#   'focus',
#   'funni',
#   'greet',
#   'heal',
#   'hors',
#   'longhorn',
#   'miniatur',
#   'natur',
#   'oreo',
#   'perfect',
#   'place',
#   'q',
#   'ranch',
#   'refug',
#   'trail',
#   'transform',
#   'water',
#   'wood'},
#  {'2',
#   '3',
#   '4x4',
#   'activ',
#   'around',
#   'bath',
#   'bedroom',
#   'best',
#   'clearest',
#   'concert',
#   'counti',
#   'countri',
#   'dessert',
#   'enjoy',
#   'event',
#   'fair',
#   'famou',
#   'favorit',
#   'fire',
#   'full',
#   'ga',
#   'gather',
#   'getaway',
# ...
#   'regularli',
#   'rest',
#   'return',
#   'room',
#   'rub',
#   'school',
#   'scout',
#   'shave',
#   'show',
#   'sit',
#   'size',
#   'small',
#   'soon',
#   'stand',
#   'stockyard',
#   'stranger',
#   'street',
#   'trail',
#   'transport',
#   'tv',
#   'typic',
#   'uber',
#   'upon',
#   'volleybal',
#   'walk',
#   'washer',
#   'wifi',
#   'willow',
#   'work',
#   'world',
#   'worth',
#   'would'},
#  {'add',
#   'carpet',
#   'clean',
#   'extra',
#   'fee',
#   'hidden',
#   'like',
#   'list',
#   'lqqk',
#   'master',
#   'other',
#   'review',
#   'room',
#   'w'},
#  {'ador',
#   'apart',
#   'bar',
#   'beauti',
#   'distanc',
#   'garag',
#   'great',
#   'histor',
#   'home',
#   'local',
#   'montros',
#   'neighborhood',
#   'park',
#   'restaur',
#   'street',
#   'walk',
#   'welcom',
#   'within'},
#  {'2',
#   '3',
#   '4',
#   'adult',
#   'attent',
#   'bath',
#   'bedroom',
#   'cabl',
#   'coupl',
#   'decor',
#   'detail',
#   'fire',
#   'full',
#   'great',
#   'grill',
#   'group',
#   "hdtv'",
#   'hot',
#   'huge',
#   'king',
#   'master',
#   'new',
#   'outdoor',
#   'packag',
#   'pit',
#   'queen',
#   'space',
#   'throughout',
#   'tub',
#   'tv',
#   'updat',
#   'w'},
#  {'15',
#   '150',
#   '3',
#   '30',
#   '65',
#   'activ',
#   'amp',
#   'close',
#   'dine',
#   'famili',
#   'flag',
#   'friendli',
#   'great',
#   'home',
#   'locat',
#   'lodg',
#   'lot',
#   'love',
#   'mile',
#   'nightlif',
#   'open',
#   'place',
#   'restaur',
#   'room',
#   'sf',
#   'six',
#   'space',
#   'stadium',
#   'wolf'},
#  {'2',
#   '20',
#   'activ',
#   'adventur',
#   'busi',
#   'close',
#   'corridor',
#   'coupl',
#   'dine',
#   'distanc',
#   'energi',
#   'famili',
#   'friendli',
#   'good',
#   'green',
#   'houston',
#   'kati',
#   'kid',
#   'lake',
#   'locat',
#   'lot',
#   'love',
#   'mall',
#   'mill',
#   'minut',
#   'neighborhood',
#   'path',
#   'place',
#   'quiet',
#   'restaur',
#   'safe',
#   'solo',
#   'store',
#   'texa',
#   'travel',
#   'typhoon',
#   'view',
#   'walk',
#   'west',
#   'zone'},
#  {'6th',
#   'austin',
#   "austin'",
#   'bar',
#   'bird',
#   'book',
#   'ceil',
#   'center',
#   'citi',
#   'condo',
#   'convent',
#   'downtown',
#   'east',
#   'eclect',
#   'enjoy',
#   'everyth',
#   'explor',
#   'favorit',
#   'featur',
#   'floor',
#   'ladi',
#   'lake',
#   'locat',
#   'middl',
#   'panoram',
#   'perfect',
#   'pleas',
#   'rainey',
#   'read',
#   'restaur',
#   'shop',
#   'short',
#   'sit',
#   'spot',
#   'street',
#   'view',
#   'walk',
#   'walkabl',
#   'window'},
#  {'adventur',
#   'busi',
#   'close',
#   'coupl',
#   'cozi',
#   'good',
#   'love',
#   'neighborhood',
#   'nightlif',
#   'park',
#   'place',
#   'restaur',
#   'solo',
#   'travel'},
#  {'11th',
#   '9',
#   'bandera',
#   'bar',
#   'block',
#   'cowboy',
#   'downtown',
#   'great',
#   'guesthous',
#   'includ',
#   'local',
#   'locat',
#   'look',
#   'main',
#   'occup',
#   'one',
#   'quaint',
#   'rate',
#   'street',
#   'tax',
#   'two'},
#  {'10',
#   '13',
#   '3',
#   '4',
#   '5',
#   '6',
#   '7',
#   '8',
#   'adventur',
#   'advic',
#   'area',
#   'cation',
#   'cozi',
#   'day',
#   'district',
#   'downtown',
#   'escape',
#   'galleria',
#   'heart',
#   'home',
#   'host',
#   'houston',
#   'know',
#   'let',
#   'mile',
#   'museum',
#   'need',
#   'nestl',
#   'nrg',
#   'open',
#   'place',
#   'rest',
#   'stay',
#   'suggest',
#   'travel',
#   'wander',
#   'weekend',
#   'world'},
#  {'2016',
#   'away',
#   'bathroom',
#   'bed',
#   'buffalo',
#   'bunk',
#   'chic',
#   'countri',
#   'decor',
#   'direct',
#   'electr',
#   'etc',
#   'featur',
#   'fenc',
#   'four',
#   'full',
#   'home',
#   'improv',
#   'includ',
#   'internet',
#   'kimbrough',
#   'king',
#   'kitchen',
#   'less',
#   'manor',
#   'mile',
#   'new',
#   'offer',
#   'one',
#   'plumb',
#   'queen',
#   'remodel',
#   'satellit',
#   'scenic',
#   'shabbi',
#   'shower',
#   'stadium',
#   'stud',
#   'style',
#   'three',
#   'total',
#   'tub',
#   'tv',
#   'twin',
#   'two',
#   'valley',
#   'view',
#   'white',
#   'wood'},
#  {'20',
#   '3',
#   '7',
#   '9',
#   'activ',
#   'adventur',
#   'ambianc',
#   'amp',
#   'away',
#   'bed',
#   'bedroom',
#   'belton',
#   'big',
#   'busi',
#   'close',
#   'comfi',
#   'coupl',
#   'dine',
#   'famili',
#   'friendli',
#   'full',
#   'futon',
#   'good',
#   'great',
#   'group',
#   'hospit',
#   'kid',
#   'lake',
#   'light',
#   'locat',
#   'love',
#   'minut',
#   'neighborhood',
#   'outdoor',
#   'peopl',
#   'place',
#   'plu',
#   'restaur',
#   'roll',
#   'scott',
#   'size',
#   'sleep',
#   'solo',
#   'space',
#   'travel',
#   'twin',
#   'view',
#   'white'},
#  {'bed',
#   'bedroom',
#   'citi',
#   'close',
#   'comfort',
#   'couch',
#   'full',
#   'hous',
#   'larg',
#   'love',
#   'nine',
#   'plu',
#   'pull',
#   'queen',
#   'seat',
#   'sleep',
#   'stori',
#   'three',
#   'two',
#   'well'},
#  {'4555',
#   '6100',
#   'addit',
#   'bath',
#   'bedroom',
#   'distanc',
#   'execut',
#   'exquisit',
#   'finish',
#   'foot',
#   'guest',
#   'home',
#   'interior',
#   'lake',
#   'lewisvil',
#   'live',
#   'plu',
#   'privat',
#   'quarter',
#   'room',
#   'space',
#   'squar',
#   'suit',
#   'throughout',
#   'walk'},
#  {'1550',
#   '2',
#   '25',
#   'activ',
#   'along',
#   'ambianc',
#   'area',
#   'attach',
#   'busi',
#   'close',
#   'coupl',
#   'dine',
#   'driver',
#   'famili',
#   'friendli',
#   'ft',
#   'good',
#   'groceri',
#   'kid',
#   'love',
#   'mile',
#   'neighbor',
#   'nrg',
#   'outdoor',
#   'patio',
#   'place',
#   'quaint',
#   'quiet',
#   'restaur',
#   'retail',
#   'rural',
#   'set',
#   'small',
#   'space',
#   'sq',
#   'stadium',
#   'store',
#   'travel',
#   'uber',
#   'wind'},
#  {'1600',
#   '24',
#   '29',
#   '3',
#   'amen',
#   'attract',
#   'beach',
#   'boardwalk',
#   'citi',
#   'downtown',
#   'etc',
#   'fish',
#   'ft',
#   'galveston',
#   'great',
#   'hous',
#   'houston',
#   'island',
#   'kemah',
#   'leagu',
#   'local',
#   'locat',
#   'mile',
#   'ping',
#   'pong',
#   'pool',
#   'southern',
#   'sq',
#   'suburb',
#   'tabl',
#   'trampolin',
#   'tx'},
#  {"artist'",
#   'atmospher',
#   'bar',
#   'beach',
#   'book',
#   'cafe',
#   'conveni',
#   'cute',
#   'district',
#   'downtown',
#   'eclect',
#   'enjoy',
#   'entertain',
#   'far',
#   'forewarn',
#   'galleri',
#   'game',
#   'guitar',
#   'happili',
#   'histor',
#   'home',
#   'hous',
#   'invit',
#   'kitchen',
#   'littl',
#   'love',
#   'near',
#   'need',
#   'neighborhood',
#   'never',
#   'piano',
#   'play',
#   'quiet',
#   'relax',
#   'restaur',
#   'spaciou',
#   'stereo',
#   'strand',
#   'tv',
#   'warm',
#   'welcom',
#   'winni',
#   'without',
#   'wonder',
#   'yard'},
#  {'$200',
#   '3',
#   '4',
#   'addit',
#   'also',
#   'area',
#   'bath',
#   'beauti',
#   'bed',
#   'bedroom',
#   'classiest',
#   'clean',
#   'coastal',
#   'comfort',
#   'day',
#   'decor',
#   'disappoint',
#   'door',
#   'except',
#   'fee',
#   'fish',
#   'full',
#   'fulli',
#   'gorgeou',
#   'home',
#   'kitchen',
#   'next',
#   'offer',
#   'plu',
#   'pool',
#   'premier',
#   'privat',
#   'stock',
#   'tax',
#   'use',
#   'waterfront'},
#  {'activ', 'block', 'bowl', 'li', 'metro', 'minut', 'super'},
#  {'1',
#   '1316',
#   '2016',
#   '3',
#   '4',
#   '6',
#   'adult',
#   'along',
#   'area',
#   'away',
#   'awesom',
#   'balconi',
#   'bar',
#   'bath',
#   'bbq',
#   'beach',
#   'beauti',
#   'bed',
#   'bedroom',
#   'boast',
#   'bunkb',
#   'certainli',
#   'chair',
#   'charm',
#   'children',
#   'christi',
#   'class',
#   'coast',
#   'come',
#   'comfort',
#   'commun',
#   'companion',
#   'condo',
#   'condominium',
#   'cook',
#   'cooler',
#   'corpu',
#   'cover',
#   'cozi',
#   'day',
#   'del',
#   'design',
#   'enjoy',
#   'excel',
#   'find',
#   'fish',
#   'flat',
#   'foam',
#   'full',
#   'fulli',
#   'furnitur',
#   'gulf',
#   'has1',
#   'heat',
#   'height',
#   'home',
#   'includ',
#   'kept',
#   'kiddi',
#   'kitchen',
#   'kite',
#   'last',
#   'least',
#   'live',
#   'locat',
#   'luxuri',
#   'make',
#   'march',
#   'marvel',
#   'max',
#   'maximum',
#   'may',
#   'meal',
#   'memori',
#   'month',
#   'mount',
#   'new',
#   'newli',
#   'north',
#   'ocean',
#   'offer',
#   'one',
#   'oven',
#   'overlook',
#   'park',
#   'person',
#   'place',
#   'plenti',
#   'pool',
#   'qualiti',
#   'refriger',
#   'relax',
#   'requir',
#   'restaur',
#   'retreat',
#   'right',
#   'road',
#   'room',
#   'rug',
#   'screen',
#   'shop',
#   'short',
#   'sit',
#   'size',
#   'sleep',
#   'slelep',
#   'sofa',
#   'sol',
#   'splendor',
#   'stay',
#   'stock',
#   'stove',
#   'stun',
#   'suitabl',
#   'sun',
#   'surf',
#   'swim',
#   'texa',
#   'tool',
#   'topper',
#   'towel',
#   'travel',
#   'true',
#   "tv'",
#   'two',
#   'updat',
#   'vacat',
#   'view',
#   'villa',
#   'walk',
#   'wall',
#   'well',
#   'winter',
#   'wish',
#   'world',
#   'would'},
#  {'access',
#   'also',
#   'amp',
#   'area',
#   'bath',
#   'bathroom',
#   'bed',
#   'bedroom',
#   'closet',
#   'cozi',
#   'dine',
#   'dresser',
#   'empti',
#   'feel',
#   'free',
#   'full',
#   'guest',
#   'home',
#   'kitchen',
#   'live',
#   'privat',
#   'queen',
#   'right',
#   'shower',
#   'size',
#   'two',
#   'use'},
#  {'abound',
#   'away',
#   'cabin',
#   'come',
#   'cover',
#   'cozi',
#   'dock',
#   'expans',
#   'experi',
#   'eye',
#   'famili',
#   'far',
#   'forget',
#   'get',
#   'larg',
#   'opportun',
#   'patio',
#   'peac',
#   'quiet',
#   'room',
#   'see',
#   'sundeck',
#   'two',
#   'view',
#   'water'},
#  {'adventur',
#   'atmospher',
#   'beachfront',
#   'beauti',
#   'bird',
#   'blue',
#   'busi',
#   'center',
#   'chirp',
#   'club',
#   'condo',
#   'coupl',
#   'crystal',
#   'distanc',
#   'drink',
#   'enjoy',
#   'famili',
#   'friend',
#   'friendli',
#   'furri',
#   'go',
#   'good',
#   'great',
#   'groceri',
#   'kid',
#   'love',
#   'night',
#   'pallapa',
#   'paradis',
#   'pet',
#   'place',
#   'pool',
#   'refresh',
#   'restaur',
#   'shadi',
#   'shop',
#   'sit',
#   'solo',
#   'store',
#   'sunris',
#   'swim',
#   'travel',
#   'tropic',
#   'wake',
#   'walk'},
#  {'$5',
#   'aac',
#   'amp',
#   'art',
#   'ave',
#   'bar',
#   'deep',
#   'design',
#   'distanc',
#   'district',
#   'downtown',
#   'driveway',
#   'ellum',
#   'free',
#   'great',
#   'greenvil',
#   'henderson',
#   'home',
#   'kati',
#   'klyde',
#   'knox',
#   'lot',
#   'park',
#   'privat',
#   'restaur',
#   'ride',
#   'safe',
#   'trail',
#   'uber',
#   'uptown',
#   'walk',
#   'warren'},
#  {'access',
#   'beauti',
#   'comfort',
#   'costco',
#   'easili',
#   'even',
#   'free',
#   'fulli',
#   'furnish',
#   'gym',
#   'heb',
#   'lake',
#   'live',
#   'morn',
#   'nearbi',
#   'park',
#   'pharmaci',
#   'pool',
#   'space',
#   'stroll',
#   'walmart'},
#  {'2ba',
#   '2br',
#   '6',
#   'allegro',
#   'beach',
#   'breezi',
#   'bright',
#   'close',
#   'deck',
#   'dip',
#   'fabul',
#   'fish',
#   'home',
#   'interior',
#   'key',
#   'lone',
#   'nautic',
#   'newli',
#   'pool',
#   'relax',
#   'renov',
#   'restaur',
#   'share',
#   'sleep',
#   'starfish',
#   'take',
#   'touch',
#   'unwind'},
#  {'adventur',
#   'airport',
#   'antonio',
#   'belfast',
#   'bike',
#   'borrow',
#   'busi',
#   'coffe',
#   'coupl',
#   'cozi',
#   'cup',
#   'downtown',
#   'drive',
#   'enjoy',
#   'good',
#   'home',
#   'ideal',
#   'locat',
#   'love',
#   'midtown',
#   'place',
#   'quiet',
#   'relax',
#   'sa',
#   'san',
#   'short',
#   'solo',
#   'spot',
#   'travel'},
#  {'$270',
#   '2nd',
#   '37',
#   'antiqu',
#   'band',
#   'bar',
#   'blue',
#   'bq',
#   'cajun',
#   'casino',
#   'chines',
#   'citi',
#   'cours',
#   'court',
#   'cv',
#   'elm',
#   'etc',
#   'fish',
#   'fork',
#   'golf',
#   'great',
#   'home',
#   'jazz',
#   'lake',
#   'largest',
#   'light',
#   'littl',
#   'live',
#   'lodg',
#   'mall',
#   'mart',
#   'mexican',
#   'minut',
#   'movi',
#   'near',
#   'night',
#   'ntsu',
#   'park',
#   'rate',
#   'restaur',
#   'robert',
#   'safe',
#   'shop',
#   'starbuck',
#   'start',
#   'state',
#   'super',
#   'sushi',
#   'tavern',
#   'tenni',
#   'texa',
#   'texoma',
#   'thai',
#   'two',
#   'twu',
#   'unit',
#   'univers',
#   'winstar',
#   "women'"},
#  set(),
#  {'1',
#   '2',
#   '2nd',
#   'alway',
#   'bath',
#   'beach',
#   'bedroom',
#   'breez',
#   'call',
#   'coastal',
#   'cute',
#   'deck',
#   'front',
#   'gulf',
#   'home',
#   'live',
#   'next',
#   'porch',
#   'queen',
#   'right',
#   'room',
#   'see',
#   'size',
#   'sleeper',
#   'sofa',
#   'stori',
#   'view',
#   'window'},
#  {'15',
#   '23',
#   '3',
#   'access',
#   'away',
#   'bayport',
#   'baytown',
#   'beach',
#   'boardwalk',
#   'breezi',
#   'car',
#   'chevron',
#   'close',
#   'commut',
#   'descript',
#   'detail',
#   'dryer',
#   'easi',
#   'equip',
#   'even',
#   'exxon',
#   'fish',
#   'full',
#   'kemah',
#   'kitchen',
#   'littl',
#   'mile',
#   'minut',
#   'multipl',
#   'nearbi',
#   'option',
#   'plant',
#   'pleas',
#   'plenti',
#   'privat',
#   'pub',
#   'read',
#   'rent',
#   'restaur',
#   'schedul',
#   'shower',
#   'soak',
#   'termin',
#   'traffic',
#   'tub',
#   'washer',
#   'welcom',
#   'well',
#   'work'},
#  {'12',
#   '1400',
#   '2',
#   '20',
#   'acr',
#   'approx',
#   'approxim',
#   'away',
#   'bathroom',
#   'bedroom',
#   'belton',
#   'busi',
#   'charm',
#   'cottag',
#   'countri',
#   'finest',
#   'foot',
#   'getaway',
#   'home',
#   'hous',
#   'land',
#   'line',
#   'littl',
#   'live',
#   'locat',
#   'mile',
#   'peac',
#   'perfect',
#   'picturesqu',
#   'privaci',
#   'privat',
#   'properti',
#   'quiet',
#   'retreat',
#   'salado',
#   'seren',
#   'situat',
#   'squar',
#   'templ',
#   'travel',
#   'tree',
#   'truli'},
#  {'3',
#   '300',
#   '4',
#   'bath',
#   'bay',
#   'bedroom',
#   'copano',
#   'fish',
#   'ft',
#   'great',
#   'home',
#   'light',
#   'pier',
#   'privat',
#   'view'},
#  {'1',
#   '5',
#   'amp',
#   'applianc',
#   'bath',
#   'bedroom',
#   'bike',
#   'ceil',
#   'closet',
#   'counter',
#   'district',
#   'downtown',
#   'dryer',
#   'electr',
#   'eleg',
#   'entertain',
#   'floor',
#   'foot',
#   'four',
#   'full',
#   'fullsiz',
#   'gate',
#   'granit',
#   'hammock',
#   'hardwood',
#   'height',
#   'home',
#   'houston',
#   "houston'",
#   'larg',
#   'less',
#   'locat',
#   'mile',
#   'moodi',
#   'multipl',
#   'museum',
#   'nearbi',
#   'outsid',
#   'park',
#   'patio',
#   'prime',
#   'secur',
#   'stainless',
#   'steel',
#   'system',
#   'ten',
#   'throughout',
#   'top',
#   'trail',
#   'w',
#   'walk',
#   'washer',
#   'yard'},
#  {'2',
#   'bright',
#   'close',
#   'comfort',
#   'cottag',
#   'cozi',
#   'cultur',
#   'cute',
#   'descript',
#   'district',
#   'everyth',
#   'ft',
#   'guest',
#   'ideal',
#   'line',
#   'locat',
#   'pleas',
#   'pretti',
#   'read',
#   'residenti',
#   'street',
#   'studio',
#   'tree',
#   'want',
#   "worth'"},
#  {'3',
#   'apart',
#   'back',
#   'best',
#   'come',
#   'comfort',
#   'dishwash',
#   'downstair',
#   'dryer',
#   'fi',
#   'fort',
#   'free',
#   'full',
#   'fulli',
#   'furnish',
#   'groceri',
#   'hood',
#   'host',
#   'kitchen',
#   'lake',
#   'minut',
#   'n',
#   'near',
#   'patio',
#   'peopl',
#   'restaur',
#   'stillhous',
#   'store',
#   'sunset',
#   'target',
#   'town',
#   'tv',
#   'washer',
#   'watch',
#   'wi'},
#  {'3',
#   'art',
#   'austin',
#   'breweri',
#   'center',
#   'citi',
#   'coffe',
#   'easi',
#   'east',
#   'enjoy',
#   'explor',
#   'galleri',
#   'loung',
#   'mile',
#   'morn',
#   'nearbi',
#   'patio',
#   'privat',
#   'reach',
#   'restaur',
#   'shadi',
#   'studio',
#   'within'},
#  {'area',
#   'beauti',
#   'bend',
#   'big',
#   'describ',
#   'earth',
#   'gem',
#   'hidden',
#   'imposs',
#   'know',
#   'like',
#   'one',
#   'peopl',
#   'place',
#   'rental',
#   'sentenc',
#   'texa',
#   'thing',
#   'tri',
#   'vacat',
#   'way',
#   'west',
#   'word'},
#  {'1',
#   '1400',
#   '2',
#   '6th',
#   'acl',
#   'along',
#   'area',
#   'awesom',
#   'back',
#   'bath',
#   'bedroom',
#   'big',
#   'bunch',
#   'busi',
#   'charmer',
#   'close',
#   'congress',
#   'cool',
#   'din',
#   'distanc',
#   'downtown',
#   'driveway',
#   'etc',
#   'exactli',
#   'festiv',
#   'front',
#   'great',
#   'huge',
#   'liquor',
#   'live',
#   'middl',
#   'mile',
#   'newli',
#   'park',
#   'pave',
#   'place',
#   'porch',
#   'record',
#   'remodel',
#   'restaur',
#   'room',
#   'sit',
#   'sqft',
#   'store',
#   'view',
#   'walk',
#   'waterloo',
#   'way',
#   'yard',
#   'zilker'},
#  {'20',
#   '30',
#   '5',
#   'bathroom',
#   'bed',
#   'bedroom',
#   'center',
#   'day',
#   'discount',
#   'downtown',
#   'en',
#   'galleria',
#   'guest',
#   'insid',
#   'long',
#   'medic',
#   'next',
#   'nrg',
#   'prefer',
#   'privat',
#   'queen',
#   'size',
#   'suit',
#   'term'},
#  {'15',
#   '2',
#   '25',
#   '5',
#   'abod',
#   'airport',
#   'also',
#   'amp',
#   'arlington',
#   'ballpark',
#   'bath',
#   'bdrm',
#   'center',
#   'convent',
#   'dalla',
#   'dfw',
#   'distanc',
#   'flag',
#   'ftworth',
#   'harbor',
#   'heart',
#   'hurrican',
#   'min',
#   'restaur',
#   'six',
#   'south',
#   'stadium',
#   'sweet',
#   'walk',
#   'within'},
#  {'35',
#   'access',
#   'backyard',
#   'bbq',
#   'big',
#   'children',
#   'countri',
#   'creek',
#   'deck',
#   'entertain',
#   'feel',
#   'fire',
#   'fish',
#   'food',
#   'give',
#   'greenbelt',
#   'hors',
#   'lake',
#   'lewisvil',
#   'minut',
#   'park',
#   'pastur',
#   'pit',
#   'playset',
#   'quick',
#   'seat',
#   'shop',
#   'small',
#   'state',
#   'suitabl',
#   'surround',
#   'theater',
#   'tree',
#   'venu'},
#  {'17mi',
#   'airport',
#   'amp',
#   'april2017',
#   'ask',
#   'attend',
#   'busi',
#   'clean',
#   'close',
#   'comfort',
#   'concert',
#   'cowboy',
#   'dfw',
#   'discount',
#   'enjoy',
#   'event',
#   'excel',
#   'game',
#   'gaylord',
#   'getaway',
#   'grapevin',
#   'histor',
#   'home',
#   'kept',
#   'lake',
#   'longer',
#   'love',
#   'main',
#   'mani',
#   'mattress',
#   'mile',
#   'new',
#   'nightlif',
#   'perfect',
#   'place',
#   'public',
#   'queen',
#   'restaur',
#   'shop',
#   'spot',
#   'st',
#   'stadium',
#   'stay',
#   'train',
#   'transport',
#   'within'}]

# %%
Vocabulary={k:v for v, k in enumerate(my_set, 0)} #vocabulary without duplicate with term_id

# %%
Vocabulary
# Out:
# {'countri': 0,
#  'southern': 1,
#  '30': 2,
#  'lyle': 3,
#  'hour': 4,
#  'arlington': 5,
#  'neighbor': 6,
#  'control': 7,
#  'vintag': 8,
#  'min': 9,
#  'extend': 10,
#  'ski': 11,
#  "note'": 12,
#  'within': 13,
#  'mine': 14,
#  'boy': 15,
#  'kite': 16,
#  'marvel': 17,
#  'bask': 18,
#  'amen': 19,
#  'stockyard': 20,
#  'atmospher': 21,
#  'refriger': 22,
#  'shenandoah': 23,
#  '45': 24,
#  'duck': 25,
#  'lock': 26,
#  'finish': 27,
#  'veteran': 28,
#  'maximum': 29,
#  'medit': 30,
#  'iah': 31,
#  'pave': 32,
#  'along': 33,
#  '1600': 34,
#  'without': 35,
#  'montros': 36,
#  'cano': 37,
#  'friday': 38,
#  'texan': 39,
#  'rock': 40,
#  'baybrook': 41,
#  'doorman': 42,
#  'expos': 43,
#  '$5': 44,
#  'surf': 45,
#  'pillow': 46,
#  'function': 47,
#  'thai': 48,
#  'complex': 49,
#  'seren': 50,
#  'wisteria': 51,
#  'take': 52,
#  'design': 53,
#  'master': 54,
#  'easili': 55,
#  'color': 56,
#  'satisfi': 57,
#  'con': 58,
#  'pharmaci': 59,
#  'shore': 60,
#  'nois': 61,
#  'disappoint': 62,
#  'televis': 63,
#  'soul': 64,
#  'record': 65,
#  'chill': 66,
#  'aristocrat': 67,
#  '13': 68,
#  'ad': 69,
#  'plan': 70,
#  'lazi': 71,
#  'finest': 72,
#  'juliett': 73,
#  'store': 74,
#  'schlitterbahn': 75,
#  '50': 76,
#  'décor': 77,
#  'erg': 78,
#  'european': 79,
#  'made': 80,
#  'casino': 81,
#  'convert': 82,
#  'sxsw': 83,
#  'offer': 84,
#  'dfw': 85,
#  'elm': 86,
#  'greet': 87,
#  'phillip': 88,
#  'includ': 89,
#  'continent': 90,
#  'satellit': 91,
#  'tx': 92,
#  'target': 93,
#  'motor': 94,
#  'wall': 95,
#  'modern': 96,
#  'coffeepot': 97,
#  'unseen': 98,
#  'month': 99,
#  'cow': 100,
#  'plumb': 101,
#  'near': 102,
#  'trampolin': 103,
#  '$10': 104,
#  'name': 105,
#  'racquet': 106,
#  'vet': 107,
#  'hair': 108,
#  'scott': 109,
#  'post': 110,
#  'rail': 111,
#  'number': 112,
#  'ship': 113,
#  'far': 114,
#  'padr': 115,
#  '100': 116,
#  'incred': 117,
#  'chevron': 118,
#  'fullsiz': 119,
#  'fairway': 120,
#  'inquiri': 121,
#  'growth': 122,
#  '75212': 123,
#  'air': 124,
#  'wide': 125,
#  'allianc': 126,
#  'jacinto': 127,
#  'class': 128,
#  'kiddi': 129,
#  'cowboy': 130,
#  'creativ': 131,
#  'pace': 132,
#  'workout': 133,
#  'seen': 134,
#  'thing': 135,
#  'magazin': 136,
#  'shampoo': 137,
#  'tavern': 138,
#  'chic': 139,
#  'featherb': 140,
#  'ceil': 141,
#  'guesthous': 142,
#  'complianc': 143,
#  'simpl': 144,
#  'starbuck': 145,
#  'block': 146,
#  'aesthet': 147,
#  'jazz': 148,
#  'life': 149,
#  'perk': 150,
#  'look': 151,
#  'mirror': 152,
#  'westmoreland': 153,
#  'boardwalk': 154,
#  'american': 155,
#  'log': 156,
#  'best': 157,
#  'except': 158,
#  'apt': 159,
#  '75': 160,
#  'visit': 161,
#  'anchor': 162,
#  'advanc': 163,
#  'front': 164,
#  'loung': 165,
#  'bikeshar': 166,
#  'profit': 167,
#  'meet': 168,
#  'roast': 169,
#  'launch': 170,
#  'field': 171,
#  'hangout': 172,
#  'line': 173,
#  'contemporari': 174,
#  'pad': 175,
#  'muy': 176,
#  'movi': 177,
#  'bufalina': 178,
#  'frequent': 179,
#  'outdoor': 180,
#  'move': 181,
#  'aac': 182,
#  'plant': 183,
#  'oak': 184,
#  '8': 185,
#  'bayou': 186,
#  'beauti': 187,
#  'may': 188,
#  'thanksgiv': 189,
#  'deck': 190,
#  'hyde': 191,
#  'keyless': 192,
#  'aug': 193,
#  'wineri': 194,
#  'maker': 195,
#  'land': 196,
#  'wind': 197,
#  'termin': 198,
#  'feast': 199,
#  'formula': 200,
#  'march': 201,
#  'seven': 202,
#  'boat': 203,
#  'festiv': 204,
#  'childbirth': 205,
#  '20': 206,
#  'loop': 207,
#  'dalla': 208,
#  'individu': 209,
#  'amp': 210,
#  'salado': 211,
#  'pub': 212,
#  'familia': 213,
#  'charact': 214,
#  'wraparound': 215,
#  'espacio': 216,
#  'kimbrough': 217,
#  'cultur': 218,
#  '1400': 219,
#  'carriag': 220,
#  'worker': 221,
#  '66': 222,
#  'top': 223,
#  'comfort': 224,
#  'bell': 225,
#  'east': 226,
#  'jog': 227,
#  'frisco': 228,
#  'aggieland': 229,
#  'reveil': 230,
#  'zilker': 231,
#  'venu': 232,
#  'add': 233,
#  'lead': 234,
#  'direct': 235,
#  "tv'": 236,
#  'quarri': 237,
#  'rm': 238,
#  'lavend': 239,
#  'cream': 240,
#  'independ': 241,
#  'nightstand': 242,
#  'prefer': 243,
#  'mountain': 244,
#  'earth': 245,
#  'squar': 246,
#  'boern': 247,
#  'modular': 248,
#  'even': 249,
#  'join': 250,
#  'fayett': 251,
#  'boutiqu': 252,
#  'suitabl': 253,
#  'end': 254,
#  'dallasmi': 255,
#  'access': 256,
#  'separ': 257,
#  'tidi': 258,
#  'electr': 259,
#  'concept': 260,
#  '26': 261,
#  'barley': 262,
#  'eado': 263,
#  'world': 264,
#  'backyard': 265,
#  "'river": 266,
#  'hospit': 267,
#  'bridg': 268,
#  'would': 269,
#  '2300': 270,
#  'bedrol': 271,
#  'ellum': 272,
#  'nocturna': 273,
#  'gazz': 274,
#  'help': 275,
#  "there'": 276,
#  'lowest': 277,
#  'fed': 278,
#  'ninja': 279,
#  'lifestyl': 280,
#  'sqft': 281,
#  'popular': 282,
#  'ih': 283,
#  'minut': 284,
#  'treadmil': 285,
#  'sundeck': 286,
#  'wine': 287,
#  'outsid': 288,
#  'kitchenett': 289,
#  'four': 290,
#  'pass': 291,
#  'max': 292,
#  'murphi': 293,
#  '640': 294,
#  'though': 295,
#  'deliv': 296,
#  'mini': 297,
#  'rest': 298,
#  'condominium': 299,
#  'glad': 300,
#  'exist': 301,
#  'pick': 302,
#  'casita': 303,
#  'linen': 304,
#  'enjoy': 305,
#  'chico': 306,
#  'pristin': 307,
#  "we'r": 308,
#  'forc': 309,
#  'section': 310,
#  'bottom': 311,
#  'fee': 312,
#  '290': 313,
#  'fabul': 314,
#  'sushi': 315,
#  'baytown': 316,
#  'ensuit': 317,
#  'whole': 318,
#  'train': 319,
#  'honor': 320,
#  'will': 321,
#  'trader': 322,
#  '19th': 323,
#  'across': 324,
#  "contractor'": 325,
#  'regist': 326,
#  'unlock': 327,
#  'yacht': 328,
#  '30am': 329,
#  'lucki': 330,
#  'fairi': 331,
#  'cost': 332,
#  'nrg': 333,
#  'rug': 334,
#  'pan': 335,
#  'tanger': 336,
#  'bowl': 337,
#  'park': 338,
#  'accommod': 339,
#  'belton': 340,
#  'charg': 341,
#  'ranger': 342,
#  'urban': 343,
#  'classiest': 344,
#  'detail': 345,
#  'travel': 346,
#  'pool': 347,
#  '610': 348,
#  'door': 349,
#  'testament': 350,
#  'bantam': 351,
#  'welcom': 352,
#  'six': 353,
#  'el': 354,
#  'small': 355,
#  'touch': 356,
#  'sac': 357,
#  'area': 358,
#  'mind': 359,
#  '5': 360,
#  'person': 361,
#  '18': 362,
#  'peopl': 363,
#  'hint': 364,
#  'head': 365,
#  'pit': 366,
#  '10$': 367,
#  'round': 368,
#  'chirp': 369,
#  'basebal': 370,
#  'shop': 371,
#  'shoe': 372,
#  'typic': 373,
#  'suggest': 374,
#  'intern': 375,
#  'list': 376,
#  'rental': 377,
#  'remodel': 378,
#  'meal': 379,
#  'shot': 380,
#  'wimberley': 381,
#  'give': 382,
#  'qti': 383,
#  '$75': 384,
#  'georg': 385,
#  'tax': 386,
#  'easi': 387,
#  'airlin': 388,
#  'brazo': 389,
#  '1316': 390,
#  'art': 391,
#  'rocker': 392,
#  'comput': 393,
#  'villag': 394,
#  'resort': 395,
#  'globe': 396,
#  'updat': 397,
#  'secur': 398,
#  'middl': 399,
#  'school': 400,
#  '30min': 401,
#  'angel': 402,
#  'let': 403,
#  'babysit': 404,
#  'roger': 405,
#  'interest': 406,
#  'spade': 407,
#  'pure': 408,
#  'style': 409,
#  'instant': 410,
#  'poodi': 411,
#  'hr': 412,
#  'upon': 413,
#  'care': 414,
#  'shotwel': 415,
#  'granit': 416,
#  'hang': 417,
#  'apart': 418,
#  'basketbal': 419,
#  'shabbi': 420,
#  'combo': 421,
#  'lodg': 422,
#  'card': 423,
#  '2nd': 424,
#  'kingwood': 425,
#  'sola': 426,
#  'group': 427,
#  'tradit': 428,
#  'crown': 429,
#  'happi': 430,
#  'magnolia': 431,
#  'locat': 432,
#  'hole': 433,
#  'money': 434,
#  'lakefront': 435,
#  'stun': 436,
#  'fluffi': 437,
#  'club': 438,
#  'premium': 439,
#  'tabl': 440,
#  'dell': 441,
#  'explor': 442,
#  'jet': 443,
#  '1550': 444,
#  'short': 445,
#  'everi': 446,
#  'riverwalk': 447,
#  '6th': 448,
#  'request': 449,
#  '4342': 450,
#  '1st': 451,
#  'district': 452,
#  'term': 453,
#  'kerrvil': 454,
#  'valu': 455,
#  'sunset': 456,
#  'mall': 457,
#  'rainey': 458,
#  'sing': 459,
#  'dishwash': 460,
#  'netflix': 461,
#  'seclud': 462,
#  'henc': 463,
#  'often': 464,
#  'corridor': 465,
#  'discount': 466,
#  'scent': 467,
#  'airbnb': 468,
#  'cul': 469,
#  'stainless': 470,
#  'spring': 471,
#  'sea': 472,
#  'never': 473,
#  'pretti': 474,
#  'klyde': 475,
#  'acreag': 476,
#  'qualiti': 477,
#  'inflat': 478,
#  '24hr': 479,
#  'treehous': 480,
#  '281': 481,
#  'hotel': 482,
#  'old': 483,
#  'bad': 484,
#  'discret': 485,
#  'side': 486,
#  'twin': 487,
#  '$60': 488,
#  'conveni': 489,
#  'etc': 490,
#  'thank': 491,
#  'unit': 492,
#  'throughout': 493,
#  'dip': 494,
#  'situat': 495,
#  'para': 496,
#  'classic': 497,
#  'local': 498,
#  'adult': 499,
#  'topper': 500,
#  'centr': 501,
#  'creat': 502,
#  'antonio': 503,
#  'complet': 504,
#  'concret': 505,
#  'sunris': 506,
#  'everyon': 507,
#  'greenvil': 508,
#  'paradis': 509,
#  'dear': 510,
#  'sink': 511,
#  'poolsid': 512,
#  'worth': 513,
#  'alamo': 514,
#  'cell': 515,
#  '1940': 516,
#  '7th': 517,
#  'premier': 518,
#  'keurig': 519,
#  'better': 520,
#  'lakewood': 521,
#  'comfi': 522,
#  'fast': 523,
#  'bliss': 524,
#  'coffe': 525,
#  'farm': 526,
#  'bar': 527,
#  'night': 528,
#  'describ': 529,
#  'contain': 530,
#  'lowergreenvil': 531,
#  'waterloo': 532,
#  'effic': 533,
#  '2br': 534,
#  'shadi': 535,
#  'sleep': 536,
#  'go': 537,
#  'theater': 538,
#  'mount': 539,
#  'forget': 540,
#  'grapevin': 541,
#  'street': 542,
#  'decompress': 543,
#  'preserv': 544,
#  'aventurero': 545,
#  'prestigi': 546,
#  'townhous': 547,
#  'galleria': 548,
#  'upscal': 549,
#  'san': 550,
#  'splashpad': 551,
#  'del': 552,
#  'tan': 553,
#  'children': 554,
#  'back': 555,
#  'starfish': 556,
#  'tenni': 557,
#  'exactli': 558,
#  "'countri": 559,
#  'doubl': 560,
#  'sentenc': 561,
#  'util': 562,
#  'ultim': 563,
#  'smu': 564,
#  'brand': 565,
#  'templ': 566,
#  'calm': 567,
#  'game': 568,
#  'immens': 569,
#  'pictur': 570,
#  'zoo': 571,
#  'elum': 572,
#  'check': 573,
#  'convent': 574,
#  'nearbi': 575,
#  'pet': 576,
#  'neighborhood': 577,
#  'kroger': 578,
#  'n': 579,
#  'water': 580,
#  'prestig': 581,
#  'fellowship': 582,
#  'hostil': 583,
#  '121': 584,
#  'spaciou': 585,
#  'congress': 586,
#  'mbp': 587,
#  'yet': 588,
#  'mold': 589,
#  'unusu': 590,
#  'euless': 591,
#  'island': 592,
#  'bluebonnet': 593,
#  'deer': 594,
#  'flyrit': 595,
#  '37': 596,
#  'tournament': 597,
#  'nation': 598,
#  'borrow': 599,
#  'conro': 600,
#  '42': 601,
#  'turismo': 602,
#  'exxon': 603,
#  '99': 604,
#  'winstar': 605,
#  'cavern': 606,
#  'among': 607,
#  'bueno': 608,
#  'caretak': 609,
#  'pic': 610,
#  'two': 611,
#  'flag': 612,
#  "women'": 613,
#  'awar': 614,
#  'southsid': 615,
#  'storag': 616,
#  'addit': 617,
#  'starlight': 618,
#  'stonebriar': 619,
#  'standard': 620,
#  'granburi': 621,
#  'kyle': 622,
#  'nelson': 623,
#  'ac': 624,
#  'carport': 625,
#  'court': 626,
#  '400': 627,
#  'stadium': 628,
#  'uber': 629,
#  'rd': 630,
#  'stargaz': 631,
#  'attach': 632,
#  'winni': 633,
#  'rejuven': 634,
#  'houston': 635,
#  'hope': 636,
#  'temporari': 637,
#  'leav': 638,
#  'livabl': 639,
#  'marriott': 640,
#  'jw': 641,
#  'singl': 642,
#  'vagabond': 643,
#  'cat': 644,
#  'perfect': 645,
#  'stranger': 646,
#  'partli': 647,
#  'sweet': 648,
#  'c': 649,
#  'eleg': 650,
#  'big': 651,
#  'build': 652,
#  '118': 653,
#  'cc': 654,
#  'descript': 655,
#  'metroplex': 656,
#  'cloth': 657,
#  'mlk': 658,
#  'case': 659,
#  'lakesid': 660,
#  'fort': 661,
#  'friendli': 662,
#  'king': 663,
#  'use': 664,
#  'french': 665,
#  'current': 666,
#  '1922': 667,
#  'thursday': 668,
#  'soap': 669,
#  'i10': 670,
#  "austin'": 671,
#  'univ': 672,
#  'forward': 673,
#  'gulf': 674,
#  'piec': 675,
#  'know': 676,
#  'drive': 677,
#  'castleg': 678,
#  'mucha': 679,
#  'fan': 680,
#  'moodi': 681,
#  'attract': 682,
#  "kya'": 683,
#  'que': 684,
#  'breweri': 685,
#  'loft': 686,
#  'contact': 687,
#  'fish': 688,
#  'acr': 689,
#  'natur': 690,
#  'stand': 691,
#  'roku': 692,
#  'servic': 693,
#  'monday': 694,
#  "guests'": 695,
#  'lower': 696,
#  'swine': 697,
#  'pleas': 698,
#  'pine': 699,
#  "joe'": 700,
#  'hassl': 701,
#  'awesom': 702,
#  '65': 703,
#  '750': 704,
#  'coupl': 705,
#  'varieti': 706,
#  "chic'": 707,
#  'hanger': 708,
#  'toy': 709,
#  'code': 710,
#  '12': 711,
#  'toll': 712,
#  'seat': 713,
#  'truli': 714,
#  'ambianc': 715,
#  'sugarland': 716,
#  'residenti': 717,
#  'machin': 718,
#  'flat': 719,
#  'charmer': 720,
#  'ut': 721,
#  'open': 722,
#  'hunt': 723,
#  'burnet': 724,
#  'cabl': 725,
#  'cutleri': 726,
#  'third': 727,
#  'fabeuless': 728,
#  'bungalow': 729,
#  'heal': 730,
#  'fall': 731,
#  '10min': 732,
#  'cozi': 733,
#  'indian': 734,
#  'tailor': 735,
#  'tell': 736,
#  'host': 737,
#  'schlitterbaun': 738,
#  'purchas': 739,
#  'right': 740,
#  'suit': 741,
#  'state': 742,
#  'travi': 743,
#  'spot': 744,
#  'grand': 745,
#  'seamless': 746,
#  'knox': 747,
#  'connect': 748,
#  'spartan': 749,
#  'extra': 750,
#  'cover': 751,
#  'antiqu': 752,
#  'twu': 753,
#  'collect': 754,
#  'password': 755,
#  'full': 756,
#  'subject': 757,
#  'worri': 758,
#  'bayview': 759,
#  'cargo': 760,
#  'plu': 761,
#  'splendor': 762,
#  'encuentra': 763,
#  'marco': 764,
#  'year': 765,
#  'reserv': 766,
#  'rent': 767,
#  'samuel': 768,
#  'marbl': 769,
#  'entranc': 770,
#  'reinvigor': 771,
#  'effect': 772,
#  'corpu': 773,
#  'mckinney': 774,
#  'focus': 775,
#  'packag': 776,
#  'beyond': 777,
#  'weather': 778,
#  'hidden': 779,
#  'leisur': 780,
#  'west': 781,
#  'dresser': 782,
#  'cool': 783,
#  'medic': 784,
#  'close': 785,
#  'cafe': 786,
#  'gold': 787,
#  'protext': 788,
#  'quaint': 789,
#  'offic': 790,
#  'austin': 791,
#  'pm': 792,
#  'way': 793,
#  'fool': 794,
#  'second': 795,
#  'town': 796,
#  'counter': 797,
#  'wrap': 798,
#  'half': 799,
#  'driver': 800,
#  'dominion': 801,
#  '17mi': 802,
#  'chicken': 803,
#  'demand': 804,
#  'kemah': 805,
#  'restor': 806,
#  'entir': 807,
#  'ceram': 808,
#  'nest': 809,
#  'nautic': 810,
#  'low': 811,
#  'forth': 812,
#  'holiday': 813,
#  'botan': 814,
#  'getaway': 815,
#  'eye': 816,
#  'greenway': 817,
#  'kept': 818,
#  'watter': 819,
#  'regularli': 820,
#  'pong': 821,
#  'station': 822,
#  'playset': 823,
#  "1950'": 824,
#  'hit': 825,
#  '4k': 826,
#  'tollway': 827,
#  'ideal': 828,
#  'stereo': 829,
#  'commut': 830,
#  '8am': 831,
#  'five': 832,
#  'oreo': 833,
#  'wonder': 834,
#  'lacentera': 835,
#  'ton': 836,
#  'galveston': 837,
#  'microwav': 838,
#  'kati': 839,
#  'friend': 840,
#  'cliff': 841,
#  'butt': 842,
#  'legal': 843,
#  'phone': 844,
#  '6100': 845,
#  'provid': 846,
#  'ampl': 847,
#  'sight': 848,
#  'tcc': 849,
#  'crowd': 850,
#  'downstair': 851,
#  'mud': 852,
#  'outskirt': 853,
#  'pond': 854,
#  'retir': 855,
#  'distancia': 856,
#  'bicker': 857,
#  'insid': 858,
#  'maintain': 859,
#  'hot': 860,
#  'total': 861,
#  'empti': 862,
#  'secret': 863,
#  'plaza': 864,
#  'encantar': 865,
#  'texoma': 866,
#  'either': 867,
#  "what'": 868,
#  "can't": 869,
#  'leon': 870,
#  'hau': 871,
#  '$270': 872,
#  'trim': 873,
#  'sceneri': 874,
#  'es': 875,
#  '29': 876,
#  'combin': 877,
#  'major': 878,
#  'dirt': 879,
#  'st': 880,
#  'ignor': 881,
#  'green': 882,
#  'high': 883,
#  'fine': 884,
#  'arriv': 885,
#  'man': 886,
#  'citi': 887,
#  'rain': 888,
#  'ga': 889,
#  'slide': 890,
#  'foot': 891,
#  'cab': 892,
#  'costco': 893,
#  '410': 894,
#  'saltwat': 895,
#  'scene': 896,
#  'inch': 897,
#  'longhorn': 898,
#  'beam': 899,
#  'hook': 900,
#  'wi': 901,
#  'utensil': 902,
#  '21': 903,
#  'speed': 904,
#  'goe': 905,
#  'essenti': 906,
#  'tourist': 907,
#  'turn': 908,
#  'contrari': 909,
#  'kid': 910,
#  'plenti': 911,
#  'sunroom': 912,
#  'reach': 913,
#  'stop': 914,
#  'more': 915,
#  'detach': 916,
#  'queen': 917,
#  'lake': 918,
#  'first': 919,
#  'immedi': 920,
#  'dryer': 921,
#  'stori': 922,
#  'pop': 923,
#  'lux': 924,
#  'window': 925,
#  'part': 926,
#  'wifi': 927,
#  "kingwood'": 928,
#  'tub': 929,
#  'emerg': 930,
#  'blue': 931,
#  'oven': 932,
#  'rang': 933,
#  'beach': 934,
#  'highway': 935,
#  'driveway': 936,
#  'walmart': 937,
#  'byron': 938,
#  'car': 939,
#  'drug': 940,
#  'anybodi': 941,
#  'pasadena': 942,
#  'stock': 943,
#  'excel': 944,
#  'leagu': 945,
#  'recent': 946,
#  'ambienc': 947,
#  'baylor': 948,
#  'allegro': 949,
#  'mattress': 950,
#  'extrem': 951,
#  "lala'": 952,
#  'i45': 953,
#  'gruen': 954,
#  'guest': 955,
#  'escap': 956,
#  'de': 957,
#  'diamond': 958,
#  'might': 959,
#  'golf': 960,
#  'space': 961,
#  'soft': 962,
#  'decor': 963,
#  'warm': 964,
#  'alway': 965,
#  'ford': 966,
#  'bigger': 967,
#  'quarter': 968,
#  'last': 969,
#  'cours': 970,
#  'larg': 971,
#  'highest': 972,
#  'quick': 973,
#  'studio': 974,
#  'ne': 975,
#  'main': 976,
#  'yard': 977,
#  'allerg': 978,
#  'book': 979,
#  '40': 980,
#  '1pm': 981,
#  'rate': 982,
#  'mexican': 983,
#  'belt': 984,
#  'known': 985,
#  'kind': 986,
#  'fasten': 987,
#  'stylishli': 988,
#  'roadhous': 989,
#  'assur': 990,
#  'testimoni': 991,
#  'furnitur': 992,
#  'board': 993,
#  'manor': 994,
#  'southtown': 995,
#  'nasa': 996,
#  'other': 997,
#  'everyth': 998,
#  'equip': 999,
#  ...}

# %%
from collections import defaultdict

inv_indx = defaultdict(list)
for idx, text in enumerate(docs_set):
    for word in text:
        inv_indx[word].append(idx)

# %%
inv_indx
# Out:
# defaultdict(list,
#             {'iah': [0, 55, 134],
#              'anoth': [0, 64, 74],
#              'sofa': [0, 28, 47, 57, 92, 122, 210, 213, 239, 249],
#              'bathroom': [0,
#               1,
#               3,
#               7,
#               13,
#               18,
#               21,
#               26,
#               39,
#               53,
#               57,
#               64,
#               68,
#               86,
#               88,
#               91,
#               97,
#               109,
#               116,
#               118,
#               124,
#               134,
#               159,
#               163,
#               170,
#               175,
#               179,
#               185,
#               188,
#               190,
#               200,
#               211,
#               217,
#               220,
#               230,
#               240,
#               251,
#               259],
#              'avail': [0,
#               6,
#               7,
#               14,
#               25,
#               31,
#               38,
#               58,
#               76,
#               79,
#               85,
#               103,
#               106,
#               110,
#               120,
#               129,
#               131,
#               134,
#               179,
#               188,
#               220],
#              'second': [0, 47, 52, 53, 63, 85, 170, 175, 210],
#              'bedroom': [0,
#               1,
#               3,
#               7,
#               8,
#               10,
#               16,
#               18,
#               20,
#               21,
#               25,
#               33,
#               44,
#               47,
#               48,
#               52,
#               55,
#               57,
#               58,
#               64,
#               66,
#               68,
#               69,
#               70,
#               74,
#               75,
#               76,
#               85,
#               91,
#               97,
#               98,
#               109,
#               114,
#               118,
#               119,
#               126,
#               129,
#               134,
#               138,
#               142,
#               145,
#               150,
#               151,
#               153,
#               159,
#               160,
#               163,
#               164,
#               168,
#               169,
#               172,
#               173,
#               175,
#               176,
#               178,
#               179,
#               182,
#               184,
#               187,
#               190,
#               194,
#               195,
#               200,
#               206,
#               209,
#               211,
#               213,
#               220,
#               223,
#               231,
#               232,
#               233,
#               237,
#               239,
#               240,
#               249,
#               251,
#               252,
#               253,
#               258,
#               259],
#              'guest': [0,
#               38,
#               43,
#               54,
#               58,
#               64,
#               67,
#               68,
#               97,
#               99,
#               144,
#               146,
#               151,
#               160,
#               167,
#               169,
#               172,
#               187,
#               209,
#               210,
#               213,
#               220,
#               233,
#               240,
#               254,
#               259],
#              'room': [0,
#               1,
#               2,
#               13,
#               20,
#               21,
#               26,
#               27,
#               31,
#               33,
#               39,
#               43,
#               52,
#               53,
#               57,
#               62,
#               63,
#               67,
#               69,
#               71,
#               76,
#               77,
#               86,
#               88,
#               91,
#               94,
#               97,
#               100,
#               104,
#               110,
#               114,
#               115,
#               116,
#               118,
#               119,
#               127,
#               130,
#               131,
#               137,
#               138,
#               140,
#               151,
#               152,
#               159,
#               169,
#               172,
#               173,
#               175,
#               178,
#               184,
#               185,
#               201,
#               206,
#               209,
#               211,
#               219,
#               220,
#               221,
#               224,
#               233,
#               239,
#               241,
#               249,
#               258],
#              '10min': [0, 219],
#              '$10': [0, 83],
#              'trip': [0, 26, 27],
#              'airport': [0,
#               1,
#               6,
#               11,
#               40,
#               44,
#               51,
#               53,
#               54,
#               66,
#               71,
#               75,
#               79,
#               83,
#               85,
#               87,
#               96,
#               121,
#               129,
#               131,
#               134,
#               143,
#               146,
#               147,
#               148,
#               155,
#               160,
#               175,
#               180,
#               185,
#               200,
#               211,
#               214,
#               246,
#               260,
#               262],
#              'bed': [0,
#               7,
#               21,
#               23,
#               24,
#               25,
#               28,
#               29,
#               32,
#               42,
#               43,
#               47,
#               48,
#               52,
#               53,
#               57,
#               62,
#               69,
#               70,
#               71,
#               73,
#               76,
#               77,
#               92,
#               99,
#               103,
#               104,
#               105,
#               108,
#               109,
#               115,
#               116,
#               122,
#               127,
#               137,
#               138,
#               145,
#               152,
#               155,
#               159,
#               164,
#               169,
#               173,
#               175,
#               183,
#               188,
#               200,
#               201,
#               209,
#               210,
#               213,
#               217,
#               220,
#               230,
#               231,
#               232,
#               237,
#               239,
#               240,
#               259],
#              'privat': [0,
#               3,
#               9,
#               26,
#               34,
#               36,
#               39,
#               55,
#               58,
#               64,
#               65,
#               66,
#               67,
#               69,
#               71,
#               74,
#               75,
#               76,
#               85,
#               90,
#               92,
#               106,
#               108,
#               110,
#               114,
#               126,
#               131,
#               132,
#               159,
#               160,
#               169,
#               170,
#               174,
#               175,
#               179,
#               181,
#               184,
#               185,
#               192,
#               194,
#               200,
#               201,
#               208,
#               216,
#               217,
#               220,
#               233,
#               237,
#               240,
#               243,
#               250,
#               251,
#               252,
#               256,
#               259],
#              'welcom': [0,
#               4,
#               22,
#               58,
#               70,
#               94,
#               104,
#               125,
#               146,
#               150,
#               196,
#               199,
#               200,
#               222,
#               236,
#               250],
#              'drop': [0, 54],
#              'stay': [0,
#               13,
#               22,
#               26,
#               29,
#               30,
#               39,
#               46,
#               55,
#               57,
#               71,
#               74,
#               75,
#               85,
#               100,
#               103,
#               104,
#               109,
#               144,
#               146,
#               147,
#               156,
#               160,
#               170,
#               187,
#               197,
#               201,
#               205,
#               229,
#               239,
#               262],
#              'detach': [0, 92, 108],
#              'queen': [0,
#               7,
#               28,
#               52,
#               53,
#               70,
#               92,
#               99,
#               103,
#               108,
#               109,
#               115,
#               116,
#               118,
#               138,
#               151,
#               155,
#               169,
#               175,
#               200,
#               209,
#               210,
#               220,
#               223,
#               230,
#               232,
#               240,
#               249,
#               259,
#               262],
#              'addit': [0, 48, 76, 233, 237],
#              'pick': [0, 54],
#              'floor': [0,
#               1,
#               18,
#               53,
#               70,
#               75,
#               96,
#               109,
#               114,
#               118,
#               127,
#               163,
#               168,
#               170,
#               175,
#               182,
#               206,
#               210,
#               218,
#               226,
#               253],
#              '10$': [0],
#              'locat': [1,
#               10,
#               11,
#               18,
#               19,
#               24,
#               28,
#               30,
#               36,
#               39,
#               41,
#               44,
#               54,
#               56,
#               57,
#               58,
#               63,
#               68,
#               70,
#               71,
#               72,
#               78,
#               79,
#               80,
#               84,
#               90,
#               91,
#               95,
#               97,
#               98,
#               104,
#               106,
#               107,
#               109,
#               114,
#               117,
#               124,
#               127,
#               129,
#               130,
#               131,
#               134,
#               141,
#               142,
#               144,
#               145,
#               147,
#               150,
#               155,
#               158,
#               160,
#               162,
#               167,
#               169,
#               172,
#               188,
#               189,
#               192,
#               196,
#               197,
#               198,
#               199,
#               200,
#               201,
#               204,
#               207,
#               208,
#               210,
#               211,
#               215,
#               218,
#               219,
#               220,
#               224,
#               225,
#               226,
#               228,
#               231,
#               235,
#               239,
#               246,
#               251,
#               253,
#               254],
#              'stylish': [1],
#              '410': [1, 71],
#              'full': [1,
#               22,
#               39,
#               42,
#               47,
#               48,
#               52,
#               53,
#               55,
#               69,
#               77,
#               85,
#               88,
#               91,
#               92,
#               114,
#               119,
#               122,
#               137,
#               138,
#               145,
#               150,
#               155,
#               164,
#               168,
#               170,
#               184,
#               188,
#               209,
#               213,
#               216,
#               217,
#               223,
#               230,
#               231,
#               232,
#               237,
#               239,
#               240,
#               250,
#               253,
#               255],
#              'garden': [1, 3, 63, 77, 111, 120, 127, 184, 217, 220],
#              'season': [1],
#              'park': [1,
#               4,
#               6,
#               11,
#               14,
#               16,
#               22,
#               28,
#               32,
#               36,
#               38,
#               39,
#               54,
#               55,
#               57,
#               58,
#               62,
#               63,
#               65,
#               80,
#               88,
#               96,
#               102,
#               110,
#               128,
#               131,
#               141,
#               145,
#               155,
#               165,
#               168,
#               186,
#               193,
#               199,
#               202,
#               207,
#               208,
#               214,
#               215,
#               220,
#               222,
#               227,
#               239,
#               243,
#               244,
#               247,
#               253,
#               258,
#               261],
#              'nw': [1],
#              'beauti': [1,
#               7,
#               11,
#               14,
#               21,
#               30,
#               34,
#               35,
#               65,
#               68,
#               98,
#               107,
#               108,
#               109,
#               117,
#               136,
#               138,
#               144,
#               145,
#               147,
#               148,
#               154,
#               187,
#               196,
#               198,
#               201,
#               207,
#               222,
#               237,
#               239,
#               242,
#               244,
#               257],
#              'town': [1, 25, 26, 56, 57, 76, 89, 96, 186, 192, 195, 199, 255],
#              'fulli': [1,
#               41,
#               63,
#               75,
#               77,
#               92,
#               109,
#               138,
#               142,
#               145,
#               151,
#               174,
#               185,
#               204,
#               209,
#               237,
#               239,
#               244,
#               255],
#              'top': [1,
#               63,
#               75,
#               84,
#               109,
#               133,
#               135,
#               140,
#               145,
#               151,
#               163,
#               170,
#               214,
#               253],
#              'neighborhood': [1,
#               3,
#               5,
#               14,
#               16,
#               18,
#               21,
#               23,
#               32,
#               33,
#               36,
#               51,
#               53,
#               55,
#               58,
#               65,
#               67,
#               71,
#               73,
#               86,
#               91,
#               102,
#               104,
#               105,
#               106,
#               114,
#               124,
#               138,
#               139,
#               142,
#               169,
#               177,
#               179,
#               185,
#               186,
#               197,
#               200,
#               212,
#               216,
#               222,
#               225,
#               227,
#               231,
#               236],
#              'sleep': [1,
#               20,
#               25,
#               38,
#               52,
#               68,
#               77,
#               99,
#               103,
#               104,
#               112,
#               117,
#               138,
#               163,
#               188,
#               193,
#               231,
#               232,
#               239,
#               245],
#              'hardwood': [1, 70, 109, 206, 253],
#              'driveway': [1, 55, 217, 218, 243, 258],
#              'remodel': [1, 37, 63, 147, 187, 230, 258],
#              'car': [1, 14, 20, 25, 57, 104, 142, 168, 199, 250],
#              'plan': [1, 18, 57, 197],
#              'street': [1,
#               4,
#               10,
#               24,
#               44,
#               54,
#               65,
#               102,
#               111,
#               130,
#               152,
#               167,
#               189,
#               195,
#               197,
#               204,
#               220,
#               222,
#               226,
#               228,
#               254],
#              'featur': [1, 42, 54, 57, 77, 109, 226, 230],
#              '281': [1, 71],
#              '3': [1,
#               13,
#               20,
#               21,
#               44,
#               55,
#               57,
#               61,
#               62,
#               66,
#               74,
#               76,
#               87,
#               91,
#               97,
#               103,
#               114,
#               117,
#               127,
#               129,
#               134,
#               138,
#               142,
#               146,
#               150,
#               151,
#               176,
#               192,
#               194,
#               195,
#               196,
#               197,
#               207,
#               223,
#               224,
#               229,
#               231,
#               235,
#               237,
#               239,
#               250,
#               252,
#               255,
#               256],
#              'prestigi': [1],
#              'upscal': [1],
#              'quiet': [1,
#               10,
#               12,
#               18,
#               38,
#               53,
#               55,
#               58,
#               63,
#               65,
#               85,
#               91,
#               95,
#               103,
#               104,
#               106,
#               108,
#               111,
#               123,
#               124,
#               132,
#               138,
#               147,
#               169,
#               173,
#               200,
#               211,
#               217,
#               219,
#               225,
#               234,
#               236,
#               241,
#               246,
#               251],
#              'hous': [1,
#               2,
#               7,
#               13,
#               15,
#               24,
#               35,
#               44,
#               46,
#               52,
#               56,
#               64,
#               68,
#               71,
#               79,
#               84,
#               85,
#               97,
#               98,
#               102,
#               104,
#               117,
#               118,
#               123,
#               130,
#               131,
#               138,
#               144,
#               170,
#               186,
#               189,
#               205,
#               207,
#               210,
#               220,
#               232,
#               235,
#               236,
#               251],
#              '2': [1,
#               10,
#               11,
#               13,
#               14,
#               18,
#               21,
#               25,
#               29,
#               38,
#               39,
#               43,
#               48,
#               51,
#               52,
#               55,
#               57,
#               62,
#               64,
#               77,
#               87,
#               96,
#               98,
#               109,
#               117,
#               118,
#               129,
#               134,
#               139,
#               142,
#               145,
#               150,
#               155,
#               164,
#               168,
#               172,
#               178,
#               185,
#               190,
#               194,
#               195,
#               207,
#               209,
#               210,
#               223,
#               225,
#               234,
#               249,
#               251,
#               254,
#               258,
#               260],
#              'home': [1,
#               3,
#               4,
#               6,
#               10,
#               11,
#               13,
#               14,
#               18,
#               21,
#               22,
#               25,
#               26,
#               30,
#               35,
#               38,
#               39,
#               41,
#               42,
#               43,
#               48,
#               51,
#               53,
#               55,
#               57,
#               63,
#               66,
#               68,
#               76,
#               82,
#               83,
#               86,
#               87,
#               97,
#               98,
#               99,
#               106,
#               111,
#               118,
#               125,
#               126,
#               129,
#               133,
#               134,
#               136,
#               142,
#               144,
#               145,
#               147,
#               150,
#               155,
#               158,
#               160,
#               163,
#               165,
#               168,
#               181,
#               184,
#               192,
#               195,
#               200,
#               201,
#               205,
#               207,
#               218,
#               219,
#               222,
#               224,
#               229,
#               230,
#               233,
#               236,
#               237,
#               239,
#               240,
#               243,
#               245,
#               246,
#               247,
#               249,
#               251,
#               252,
#               253,
#               262],
#              'decor': [1, 82, 108, 145, 178, 198, 223, 230, 237],
#              'tv': [1,
#               28,
#               30,
#               43,
#               52,
#               53,
#               57,
#               69,
#               76,
#               94,
#               108,
#               124,
#               151,
#               159,
#               169,
#               172,
#               175,
#               220,
#               223,
#               230,
#               236,
#               255],
#              'european': [1],
#              'height': [1, 239, 253],
#              'origin': [1, 4, 213],
#              'area': [1,
#               12,
#               13,
#               19,
#               30,
#               47,
#               55,
#               57,
#               58,
#               63,
#               67,
#               72,
#               74,
#               76,
#               86,
#               103,
#               106,
#               114,
#               125,
#               126,
#               132,
#               148,
#               152,
#               163,
#               171,
#               172,
#               175,
#               182,
#               188,
#               189,
#               195,
#               197,
#               198,
#               204,
#               205,
#               207,
#               212,
#               220,
#               229,
#               234,
#               237,
#               239,
#               240,
#               257,
#               258],
#              'alamo': [1],
#              'close': [1,
#               2,
#               5,
#               14,
#               17,
#               23,
#               32,
#               36,
#               40,
#               42,
#               49,
#               54,
#               56,
#               57,
#               63,
#               71,
#               73,
#               78,
#               80,
#               83,
#               88,
#               91,
#               95,
#               102,
#               105,
#               106,
#               107,
#               126,
#               127,
#               141,
#               142,
#               145,
#               147,
#               148,
#               152,
#               155,
#               157,
#               161,
#               165,
#               171,
#               172,
#               175,
#               177,
#               179,
#               182,
#               184,
#               187,
#               197,
#               202,
#               204,
#               215,
#               218,
#               219,
#               220,
#               224,
#               225,
#               227,
#               231,
#               232,
#               234,
#               245,
#               250,
#               254,
#               258,
#               262],
#              'conveni': [1,
#               12,
#               14,
#               18,
#               30,
#               44,
#               56,
#               59,
#               64,
#               70,
#               130,
#               144,
#               146,
#               151,
#               160,
#               186,
#               200,
#               236],
#              'independ': [1, 39, 145],
#              'loop': [1, 71, 96, 142],
#              'amaz': [1, 28, 51, 163, 169, 181],
#              'line': [1, 31, 127, 135, 163, 251, 254],
#              'open': [1,
#               18,
#               46,
#               63,
#               87,
#               102,
#               120,
#               163,
#               168,
#               177,
#               219,
#               224,
#               229],
#              'kitchen': [1,
#               10,
#               23,
#               42,
#               52,
#               57,
#               61,
#               63,
#               64,
#               71,
#               77,
#               78,
#               92,
#               109,
#               119,
#               122,
#               124,
#               138,
#               142,
#               145,
#               151,
#               152,
#               155,
#               168,
#               170,
#               172,
#               174,
#               179,
#               188,
#               210,
#               211,
#               216,
#               220,
#               230,
#               236,
#               237,
#               239,
#               240,
#               250,
#               255],
#              '4': [1,
#               18,
#               20,
#               25,
#               28,
#               51,
#               68,
#               72,
#               91,
#               97,
#               98,
#               118,
#               129,
#               146,
#               163,
#               167,
#               168,
#               176,
#               207,
#               209,
#               223,
#               229,
#               237,
#               239,
#               252],
#              'tree': [1, 43, 102, 123, 133, 174, 186, 251, 254, 261],
#              'inspir': [1],
#              'jacinto': [2],
#              'well': [2, 58, 102, 130, 232, 239, 250],
#              'river': [2,
#               25,
#               35,
#               36,
#               41,
#               72,
#               102,
#               107,
#               147,
#               154,
#               158,
#               201,
#               212],
#              'san': [2,
#               13,
#               25,
#               54,
#               66,
#               107,
#               125,
#               143,
#               146,
#               147,
#               171,
#               180,
#               196,
#               201,
#               246],
#              'visitor': [2, 151],
#              'island': [2, 122, 235],
#              "city'": [2],
#              "'river": [2],
#              'temporari': [2],
#              'extra': [2, 213, 221],
#              'maintain': [2],
#              'covet': [3],
#              'littl': [3, 68, 125, 145, 167, 236, 247, 250, 251],
#              'cute': [3, 16, 104, 206, 236, 249, 254],
#              'bryan': [3, 63],
#              'access': [3,
#               10,
#               38,
#               42,
#               48,
#               51,
#               58,
#               69,
#               71,
#               76,
#               85,
#               96,
#               107,
#               110,
#               129,
#               134,
#               136,
#               155,
#               159,
#               162,
#               167,
#               172,
#               175,
#               179,
#               186,
#               195,
#               214,
#               240,
#               244,
#               250,
#               261],
#              'situat': [3, 96, 154, 170, 196, 251],
#              'acr': [3, 6, 11, 34, 63, 108, 149, 161, 170, 208, 218, 251],
#              'minut': [4,
#               11,
#               13,
#               19,
#               28,
#               31,
#               32,
#               33,
#               44,
#               46,
#               48,
#               51,
#               53,
#               56,
#               62,
#               65,
#               71,
#               72,
#               79,
#               85,
#               86,
#               89,
#               98,
#               114,
#               117,
#               123,
#               124,
#               129,
#               134,
#               135,
#               145,
#               147,
#               148,
#               151,
#               160,
#               167,
#               170,
#               186,
#               196,
#               201,
#               204,
#               211,
#               225,
#               231,
#               238,
#               247,
#               250,
#               255,
#               261],
#              'built': [4, 53, 77, 98, 111, 168, 218],
#              'downtown': [4,
#               7,
#               14,
#               16,
#               24,
#               28,
#               31,
#               46,
#               51,
#               52,
#               53,
#               54,
#               56,
#               59,
#               66,
#               76,
#               79,
#               84,
#               89,
#               96,
#               108,
#               110,
#               111,
#               123,
#               124,
#               127,
#               129,
#               134,
#               139,
#               142,
#               143,
#               146,
#               152,
#               158,
#               162,
#               165,
#               180,
#               184,
#               185,
#               187,
#               195,
#               197,
#               199,
#               201,
#               204,
#               205,
#               206,
#               211,
#               212,
#               214,
#               218,
#               219,
#               220,
#               226,
#               228,
#               229,
#               235,
#               236,
#               243,
#               246,
#               253,
#               258,
#               259],
#              'outsid': [4, 19, 67, 144, 174, 253],
#              'drive': [4, 28, 31, 56, 85, 98, 124, 165, 170, 246],
#              'mile': [4,
#               6,
#               7,
#               24,
#               48,
#               51,
#               55,
#               59,
#               83,
#               87,
#               103,
#               108,
#               111,
#               129,
#               130,
#               134,
#               139,
#               142,
#               143,
#               146,
#               150,
#               151,
#               174,
#               180,
#               185,
#               186,
#               187,
#               197,
#               198,
#               200,
#               205,
#               207,
#               208,
#               214,
#               224,
#               229,
#               230,
#               234,
#               235,
#               250,
#               251,
#               253,
#               256,
#               258,
#               262],
#              'fort': [4, 11, 56, 131, 146, 152, 200, 211, 220, 255],
#              'rejuven': [4],
#              'gateway': [4],
#              'purchas': [4],
#              'worth': [4, 11, 56, 83, 126, 131, 152, 156, 205, 211, 220],
#              'across': [4, 24, 41, 44, 65, 130, 181],
#              'restor': [4, 151],
#              '5': [4,
#               11,
#               19,
#               21,
#               46,
#               53,
#               55,
#               56,
#               61,
#               71,
#               86,
#               117,
#               128,
#               129,
#               134,
#               146,
#               170,
#               197,
#               199,
#               204,
#               229,
#               253,
#               259,
#               260],
#              "1920'": [4, 139],
#              'recent': [4, 130, 139],
#              'offer': [4,
#               6,
#               12,
#               22,
#               54,
#               57,
#               70,
#               72,
#               73,
#               96,
#               120,
#               147,
#               150,
#               154,
#               162,
#               194,
#               218,
#               230,
#               237,
#               239],
#              'current': [4],
#              '1922': [4],
#              'happi': [4, 58, 220],
#              'charact': [4, 84],
#              'good': [5,
#               17,
#               23,
#               30,
#               32,
#               36,
#               58,
#               60,
#               71,
#               73,
#               78,
#               80,
#               94,
#               101,
#               102,
#               105,
#               141,
#               148,
#               155,
#               157,
#               161,
#               165,
#               171,
#               172,
#               174,
#               175,
#               183,
#               202,
#               214,
#               215,
#               225,
#               227,
#               231,
#               234,
#               242,
#               246],
#              'adventur': [5,
#               17,
#               32,
#               36,
#               51,
#               55,
#               60,
#               61,
#               71,
#               73,
#               80,
#               84,
#               94,
#               101,
#               102,
#               105,
#               107,
#               131,
#               136,
#               141,
#               148,
#               152,
#               155,
#               161,
#               171,
#               172,
#               174,
#               175,
#               183,
#               201,
#               202,
#               214,
#               215,
#               225,
#               227,
#               229,
#               231,
#               242,
#               246],
#              'solo': [5,
#               17,
#               32,
#               36,
#               51,
#               55,
#               60,
#               61,
#               71,
#               73,
#               80,
#               94,
#               101,
#               102,
#               105,
#               107,
#               136,
#               141,
#               148,
#               152,
#               155,
#               161,
#               171,
#               172,
#               174,
#               175,
#               183,
#               201,
#               202,
#               214,
#               215,
#               225,
#               227,
#               231,
#               242,
#               246],
#              'conro': [5, 98, 153, 177],
#              'famili': [5,
#               13,
#               17,
#               19,
#               22,
#               23,
#               26,
#               30,
#               32,
#               34,
#               38,
#               48,
#               51,
#               55,
#               56,
#               60,
#               61,
#               77,
#               78,
#               79,
#               80,
#               85,
#               87,
#               90,
#               94,
#               101,
#               102,
#               105,
#               107,
#               111,
#               119,
#               126,
#               138,
#               139,
#               141,
#               144,
#               146,
#               147,
#               155,
#               157,
#               161,
#               165,
#               172,
#               202,
#               207,
#               213,
#               214,
#               215,
#               224,
#               225,
#               231,
#               234,
#               241,
#               242],
#              'big': [5,
#               30,
#               38,
#               42,
#               43,
#               80,
#               101,
#               138,
#               161,
#               165,
#               174,
#               179,
#               186,
#               189,
#               208,
#               231,
#               257,
#               258,
#               261],
#              'travel': [5,
#               17,
#               23,
#               30,
#               32,
#               36,
#               51,
#               55,
#               60,
#               61,
#               73,
#               78,
#               80,
#               94,
#               100,
#               101,
#               107,
#               131,
#               136,
#               141,
#               148,
#               152,
#               155,
#               161,
#               165,
#               171,
#               172,
#               174,
#               175,
#               194,
#               201,
#               206,
#               214,
#               215,
#               225,
#               227,
#               229,
#               231,
#               234,
#               239,
#               242,
#               246,
#               251],
#              'space': [5,
#               14,
#               23,
#               24,
#               31,
#               32,
#               36,
#               38,
#               42,
#               54,
#               55,
#               57,
#               63,
#               68,
#               70,
#               73,
#               76,
#               80,
#               86,
#               102,
#               120,
#               124,
#               131,
#               142,
#               154,
#               155,
#               158,
#               161,
#               177,
#               181,
#               189,
#               201,
#               207,
#               223,
#               224,
#               231,
#               233,
#               234,
#               244],
#              'coupl': [5,
#               17,
#               23,
#               27,
#               30,
#               32,
#               36,
#               49,
#               51,
#               55,
#               60,
#               61,
#               73,
#               78,
#               79,
#               80,
#               94,
#               101,
#               102,
#               105,
#               107,
#               136,
#               141,
#               148,
#               152,
#               155,
#               157,
#               161,
#               165,
#               171,
#               172,
#               174,
#               175,
#               183,
#               197,
#               201,
#               202,
#               214,
#               215,
#               223,
#               225,
#               227,
#               231,
#               234,
#               242,
#               246],
#              'love': [5,
#               11,
#               23,
#               32,
#               35,
#               36,
#               46,
#               49,
#               51,
#               61,
#               64,
#               71,
#               73,
#               75,
#               78,
#               80,
#               95,
#               99,
#               102,
#               105,
#               107,
#               119,
#               136,
#               141,
#               148,
#               155,
#               161,
#               165,
#               171,
#               172,
#               175,
#               181,
#               183,
#               198,
#               202,
#               211,
#               214,
#               215,
#               224,
#               225,
#               227,
#               231,
#               232,
#               234,
#               236,
#               242,
#               246,
#               262],
#              'friendli': [5,
#               16,
#               17,
#               32,
#               56,
#               67,
#               83,
#               94,
#               95,
#               102,
#               105,
#               111,
#               125,
#               126,
#               139,
#               157,
#               161,
#               164,
#               165,
#               172,
#               192,
#               220,
#               224,
#               225,
#               231,
#               234,
#               242],
#              'kid': [5,
#               23,
#               30,
#               51,
#               60,
#               61,
#               78,
#               79,
#               80,
#               85,
#               101,
#               102,
#               104,
#               107,
#               134,
#               141,
#               155,
#               161,
#               164,
#               165,
#               202,
#               215,
#               225,
#               231,
#               234,
#               242],
#              'busi': [5,
#               17,
#               23,
#               26,
#               27,
#               30,
#               32,
#               36,
#               51,
#               55,
#               60,
#               61,
#               73,
#               78,
#               80,
#               85,
#               94,
#               101,
#               107,
#               131,
#               136,
#               141,
#               148,
#               152,
#               155,
#               161,
#               165,
#               171,
#               172,
#               174,
#               175,
#               201,
#               214,
#               215,
#               225,
#               227,
#               231,
#               234,
#               242,
#               246,
#               251,
#               258,
#               262],
#              'activ': [5,
#               17,
#               32,
#               55,
#               67,
#               105,
#               106,
#               136,
#               146,
#               150,
#               157,
#               161,
#               172,
#               224,
#               225,
#               231,
#               234,
#               238],
#              'lake': [5,
#               58,
#               61,
#               72,
#               97,
#               98,
#               100,
#               103,
#               136,
#               143,
#               151,
#               153,
#               177,
#               179,
#               180,
#               181,
#               182,
#               186,
#               194,
#               202,
#               204,
#               218,
#               219,
#               225,
#               226,
#               231,
#               233,
#               244,
#               247,
#               255,
#               261,
#               262],
#              'group': [5,
#               22,
#               30,
#               38,
#               61,
#               80,
#               87,
#               94,
#               101,
#               138,
#               147,
#               161,
#               165,
#               223,
#               231],
#              'place': [5,
#               12,
#               13,
#               14,
#               17,
#               22,
#               23,
#               26,
#               32,
#               36,
#               38,
#               40,
#               49,
#               52,
#               58,
#               59,
#               60,
#               61,
#               65,
#               71,
#               73,
#               76,
#               78,
#               80,
#               84,
#               94,
#               95,
#               101,
#               102,
#               105,
#               117,
#               124,
#               136,
#               141,
#               147,
#               148,
#               149,
#               150,
#               152,
#               155,
#               156,
#               157,
#               161,
#               165,
#               171,
#               172,
#               174,
#               175,
#               181,
#               183,
#               198,
#               202,
#               205,
#               212,
#               214,
#               215,
#               224,
#               225,
#               227,
#               229,
#               231,
#               234,
#               239,
#               242,
#               246,
#               257,
#               258,
#               262],
#              'nightlif': [5,
#               23,
#               32,
#               96,
#               105,
#               111,
#               152,
#               162,
#               172,
#               224,
#               227,
#               262],
#              'outdoor': [5,
#               23,
#               30,
#               32,
#               36,
#               42,
#               73,
#               76,
#               80,
#               106,
#               150,
#               161,
#               162,
#               210,
#               220,
#               223,
#               231,
#               234],
#              'less': [6, 19, 72, 111, 214, 230, 253],
#              'countri': [6,
#               14,
#               15,
#               36,
#               46,
#               90,
#               107,
#               135,
#               145,
#               150,
#               170,
#               171,
#               174,
#               196,
#               214,
#               230,
#               251,
#               261],
#              'need': [6,
#               39,
#               75,
#               77,
#               79,
#               100,
#               104,
#               118,
#               124,
#               142,
#               146,
#               189,
#               220,
#               229,
#               236],
#              '8': [6, 11, 18, 25, 46, 47, 67, 129, 138, 142, 211, 229],
#              'rustic': [6],
#              'experi': [6, 90, 144, 181, 189, 241],
#              'cota': [6],
#              'trailer': [6],
#              'one': [6,
#               41,
#               57,
#               64,
#               67,
#               68,
#               74,
#               88,
#               90,
#               92,
#               98,
#               118,
#               119,
#               127,
#               138,
#               153,
#               159,
#               175,
#               179,
#               182,
#               199,
#               201,
#               206,
#               208,
#               228,
#               230,
#               239,
#               257],
#              'retreat': [6, 72, 122, 144, 145, 194, 196, 239, 251],
#              'formula': [6],
#              'texa': [6,
#               11,
#               14,
#               15,
#               24,
#               25,
#               36,
#               42,
#               68,
#               95,
#               97,
#               107,
#               117,
#               118,
#               126,
#               129,
#               131,
#               142,
#               150,
#               154,
#               161,
#               174,
#               197,
#               198,
#               211,
#               225,
#               239,
#               247,
#               257],
#              'convert': [6, 24],
#              'amen': [6, 13, 53, 99, 209, 235],
#              'america': [6, 154, 196],
#              'southeast': [6],
#              'circuit': [6, 196],
#              'modular': [6],
#              '15': [6,
#               25,
#               31,
#               33,
#               53,
#               56,
#               62,
#               66,
#               71,
#               91,
#               124,
#               131,
#               134,
#               143,
#               146,
#               180,
#               186,
#               201,
#               212,
#               219,
#               224,
#               250,
#               260],
#              'austin': [6,
#               12,
#               16,
#               33,
#               59,
#               73,
#               84,
#               111,
#               129,
#               143,
#               146,
#               162,
#               169,
#               170,
#               180,
#               181,
#               184,
#               185,
#               187,
#               196,
#               218,
#               226,
#               256],
#              'size': [7,
#               22,
#               48,
#               52,
#               66,
#               70,
#               77,
#               92,
#               103,
#               109,
#               115,
#               122,
#               138,
#               146,
#               159,
#               169,
#               173,
#               175,
#               213,
#               218,
#               220,
#               231,
#               239,
#               240,
#               249,
#               259],
#              'pet': [7,
#               52,
#               56,
#               80,
#               83,
#               88,
#               101,
#               134,
#               136,
#               155,
#               174,
#               200,
#               215,
#               216,
#               242],
#              'suppli': [7, 188],
#              'tcu': [7],
#              'towel': [7, 52, 86, 109, 116, 120, 138, 239],
#              'tcc': [7],
#              'alway': [7, 249],
#              'clean': [7,
#               21,
#               38,
#               43,
#               87,
#               109,
# ...
#              'watch': [43, 193, 208, 255],
#              'per': [43, 83],
#              'pillow': [43, 115, 140],
#              'brick': [43],
#              '500': [43],
#              'zoo': [44, 62],
#              'cattl': [44],
#              'abilen': [44],
#              'lyle': [44],
#              'stylishli': [44],
#              'taylor': [44],
#              'counti': [44, 150],
#              'land': [44, 161, 251],
#              'expo': [44],
#              'shotwel': [44],
#              'updat': [44, 64, 130, 152, 209, 223, 239],
#              'move': [45, 187],
#              'valu': [45, 90],
#              'standard': [45],
#              'finish': [45, 168, 218, 233],
#              'prestig': [45],
#              'nois': [46],
#              'year': [46, 120, 161, 207],
#              'samuel': [46],
#              'ad': [46],
#              'district': [46,
#               54,
#               62,
#               76,
#               84,
#               96,
#               120,
#               139,
#               152,
#               186,
#               212,
#               220,
#               229,
#               236,
#               243,
#               253,
#               254],
#              'concept': [46, 163],
#              'triniti': [46],
#              'bikeshar': [46],
#              'west': [46, 139, 152, 199, 212, 225, 257],
#              'track': [46],
#              'ride': [46, 96, 150, 184, 185, 189, 193, 243],
#              '7th': [46, 139, 152, 205, 220],
#              'connect': [46, 210],
#              'ambient': [46, 113],
#              'magnolia': [46, 205],
#              'point': [46, 68],
#              'ave': [46, 199, 243],
#              'sleeper': [47, 52, 151, 249],
#              'king': [47, 48, 52, 122, 138, 146, 159, 213, 223, 230],
#              'descript': [47, 250, 254],
#              'maximum': [47, 239],
#              'allow': [48, 56, 90, 106, 154],
#              '21': [48, 134],
#              'pasadena': [48],
#              'suit': [48, 64, 66, 99, 146, 213, 233, 259],
#              'singl': [48, 56, 68, 197],
#              'nrg': [48, 53, 62, 65, 96, 108, 124, 212, 229, 234, 259],
#              'georg': [49, 134],
#              "apartment'": [49],
#              'person': [49, 76, 88, 124, 144, 210, 239],
#              'tidi': [49],
#              'mani': [49, 67, 102, 134, 144, 150, 198, 216, 262],
#              'eat': [49, 63],
#              'northgat': [49],
#              'librari': [49],
#              'reason': [49],
#              'kyle': [49, 80, 117],
#              'bush': [49, 134],
#              'morn': [50, 140, 244, 256],
#              'eleg': [50, 57, 115, 213, 253],
#              'orient': [51],
#              'creek': [51, 72, 89, 97, 100, 107, 123, 167, 220, 261],
#              'premium': [51, 57, 96, 216],
#              'rang': [51],
#              'watter': [51],
#              'parti': [51, 85, 161],
#              'outlet': [51, 57, 143, 180, 219],
#              'within': [51,
#               54,
#               62,
#               79,
#               110,
#               114,
#               129,
#               134,
#               153,
#               189,
#               197,
#               198,
#               199,
#               211,
#               216,
#               222,
#               256,
#               260,
#               262],
#              '121': [51, 106],
#              '75': [51, 106],
#              'stonebriar': [51],
#              '45': [51, 65, 96, 124, 143, 180],
#              'total': [52, 98, 230],
#              'coffeepot': [52],
#              'cookwar': [52],
#              'toaster': [52, 120, 124],
#              'bandera': [52, 107, 228],
#              'utensil': [52],
#              'electr': [52, 154, 230, 253],
#              'refrigeratior': [52],
#              'twin': [52, 76, 118, 138, 230, 231],
#              'smoke': [52, 56, 74, 88],
#              'heat': [52, 67, 127, 178, 239],
#              'stove': [52, 174, 188, 239],
#              'dish': [52, 92, 124],
#              'icemak': [52],
#              'fed': [52],
#              'linen': [52, 109, 138],
#              'ferral': [52],
#              'futon': [52, 231],
#              'plate': [52, 64],
#              'tx': [52, 57, 98, 129, 130, 146, 158, 159, 195, 235],
#              'ac': [52],
#              'emerg': [53],
#              'gym': [53, 172, 244],
#              'german': [53],
#              'treadmil': [53],
#              '2br': [53, 204, 245],
#              'limit': [53],
#              'inflat': [53],
#              '2016': [53, 185, 230, 239],
#              '1st': [53],
#              'hr': [53, 146, 195],
#              'store': [53,
#               75,
#               79,
#               114,
#               130,
#               131,
#               134,
#               138,
#               160,
#               165,
#               170,
#               214,
#               225,
#               234,
#               242,
#               255,
#               258],
#              'erg': [53],
#              'groceri': [53,
#               75,
#               79,
#               114,
#               131,
#               134,
#               138,
#               160,
#               165,
#               214,
#               234,
#               242,
#               255],
#              'shepherd': [53],
#              '70': [53],
#              'w': [53, 61, 69, 91, 96, 164, 221, 223, 253],
#              'machin': [53],
#              'stori': [53, 57, 87, 98, 123, 127, 131, 160, 187, 219, 232, 249],
#              'crate': [53],
#              'hemisfair': [54],
#              'convent': [54, 226, 260],
#              'intern': [54, 131, 134, 143, 180],
#              'southtown': [54],
#              'picnic': [54],
#              'alamodom': [54],
#              'bike': [54, 110, 111, 186, 193, 246, 253],
#              'rack': [54],
#              'public': [54, 84, 110, 134, 214, 262],
#              'array': [54],
#              'playground': [54, 220],
#              'basebal': [54],
#              'block': [55, 118, 140, 181, 182, 195, 207, 228, 238],
#              'often': [55, 102],
#              'us': [55, 71, 85, 104],
#              'except': [55, 97, 237],
#              'rv': [55],
#              'monday': [55, 220],
#              'medic': [55, 62, 64, 96, 110, 142, 182, 197, 212, 259],
#              'work': [55, 70, 125, 144, 220, 250],
#              'thursday': [55],
#              'ne': [55],
#              'kingwood': [55],
#              'third': [55],
#              'offic': [55],
#              'look': [56, 84, 98, 100, 132, 144, 201, 206, 228],
#              'long': [56, 131, 146, 259],
#              'environ': [56],
#              'allianc': [56],
#              'renter': [56],
#              'student': [56, 95, 131],
#              'profession': [56],
#              'i35': [56],
#              'sincer': [57],
#              'energi': [57, 88, 225],
#              'corridor': [57, 88, 225],
#              'dear': [57],
#              'tailor': [57],
#              'gorgeou': [57, 68, 145, 237],
#              'houston': [57,
#               62,
#               85,
#               91,
#               134,
#               146,
#               170,
#               197,
#               219,
#               225,
#               229,
#               235,
#               253],
#              'proxim': [57, 88, 202],
#              'hospit': [57, 129, 231],
#              'profit': [57],
#              'typhoon': [57, 225],
#              'bienvenido': [57],
#              'tub': [58,
#               77,
#               103,
#               106,
#               114,
#               120,
#               122,
#               172,
#               178,
#               187,
#               192,
#               223,
#               230,
#               250],
#              'colina': [58, 75, 87],
#              'complimentari': [58, 170],
#              'accompani': [58],
#              'background': [58],
#              'surround': [58, 123, 174, 186, 261],
#              'lit': [58],
#              'la': [58, 75, 86, 87, 88, 113, 198],
#              'newli': [58, 109, 111, 122, 168, 239, 245, 258],
#              '2min': [58],
#              'jet': [61, 114],
#              'slip': [61, 194],
#              'bring': [61],
#              'everi': [61, 102, 160, 209, 220],
#              'sunset': [61, 145, 148, 255],
#              'kayak': [61, 136, 188, 193],
#              'clear': [61, 72, 86],
#              '40': [61, 143, 180, 208],
#              "ski'": [61],
#              'spare': [62],
#              'rice': [62, 110, 212],
#              'nearest': [62],
#              'hermann': [62],
#              'toiletri': [62, 116],
#              "houston'": [62, 197, 253],
#              'borderlin': [63],
#              'culdasec': [63],
#              'counter': [63, 109, 163, 253],
#              'enough': [63],
#              'tanglewood': [63],
#              'either': [63],
#              'splashpad': [63],
#              'spaciou': [63,
#               70,
#               77,
#               111,
#               126,
#               146,
#               163,
#               168,
#               182,
#               185,
#               190,
#               219,
#               236],
#              'breakfast': [63, 159, 169, 170, 174, 210, 213],
#              'tile': [63, 77],
#              'quick': [63, 71, 84, 261],
#              'boast': [63, 239],
#              'colleg': [63],
#              'ware': [64],
#              'applianc': [64, 77, 109, 163, 209, 253],
#              'cook': [64, 77, 239],
#              'effect': [64],
#              'glass': [64],
#              'basic': [64, 165],
#              'silverwar': [64],
#              'afford': [64],
#              'unwind': [65, 72, 106, 150, 153, 245],
#              'ton': [65, 106, 114],
#              'pm': [67],
#              'game': [67, 86, 91, 106, 236, 262],
#              "area'": [67],
#              'saltwat': [67],
#              'healthi': [67],
#              'jog': [67, 220],
#              'jacuzzi': [67, 91],
#              'basketbal': [67, 220],
#              'regist': [67, 187],
#              'start': [67, 247],
#              'tenni': [67, 172, 193, 247],
#              'fill': [67, 120, 158, 189],
#              'lifestyl': [67],
#              'hole': [68, 134],
#              '4342': [68],
#              'blanco': [68, 72],
#              'concan': [68, 163],
#              '28': [68],
#              'level': [68],
#              'highest': [68],
#              'livabl': [68],
#              'chiffarob': [69],
#              'chest': [69],
#              'pictur': [69, 174],
#              'hanger': [69],
#              'drawer': [69],
#              '60': [69, 143, 180],
#              'shelv': [69],
#              'perk': [70],
#              'self': [70, 145],
#              'treehous': [70],
#              'lamin': [70],
#              '2nd': [70, 175, 247, 249],
#              "that'": [70, 140],
#              'actual': [70],
#              'traffic': [71, 250],
#              'ih': [71],
#              'bamc': [71],
#              'uthscsa': [71],
#              'anyon': [71],
#              'establish': [71, 102],
#              "potter'": [72],
#              'scent': [72],
#              'call': [72, 199, 249],
#              'oak': [72, 93, 120, 141, 212, 218],
#              'cedar': [72, 97, 100, 127, 199],
#              'hour': [72],
#              'among': [72],
#              'strateg': [72],
#              'growth': [72],
#              'cc': [72],
#              'word': [72, 257],
#              'decompress': [72],
#              'reinvigor': [72],
#              'name': [72],
#              'old': [72, 130, 207],
#              'wimberley': [72],
#              "what'": [72],
#              'import': [72],
#              'crystal': [72, 242],
#              'weekend': [72, 100, 144, 189, 229],
#              'spot': [72, 103, 181, 226, 246, 262],
#              'fredericksburg': [72],
#              'fellowship': [74],
#              'other': [74, 221],
#              'longer': [74, 144, 262],
#              'beverag': [74, 76],
#              'week': [74, 83],
#              'might': [75],
#              'condominium': [75, 119, 239],
#              'roll': [76, 231],
#              'money': [76],
#              'rate': [76, 228, 247],
#              'pc': [76],
#              'histor': [76, 89, 145, 182, 195, 211, 220, 222, 236, 262],
#              'known': [76],
#              'ensuit': [76, 116, 185],
#              'testament': [76],
#              'mckinney': [76, 199],
#              'delight': [76],
#              'magazin': [76],
#              'design': [76, 115, 239, 243],
#              'keurig': [76, 92, 120, 142],
#              'vibrant': [76, 197],
#              'squar': [76, 122, 207, 233, 251],
#              'foot': [77, 122, 188, 193, 207, 233, 251, 253],
#              'meal': [77, 239],
#              'expans': [77, 241],
#              'dramat': [77],
#              'fan': [77, 106],
#              'desk': [77, 114, 172],
#              'anybodi': [77],
#              'nine': [77, 232],
#              'trim': [77],
#              '1200': [77],
#              'delici': [77],
#              'would': [77, 220, 239],
#              'comput': [77],
#              'ceram': [77],
#              'execut': [77, 233],
#              'mold': [77],
#              'custom': [77, 134, 218],
#              'crown': [77],
#              'overs': [77, 103, 213],
#              'tamu': [78],
#              'multipl': [79, 106, 250, 253],
#              'hobbi': [79, 96, 108, 121],
#              'walmart': [79, 91, 244],
#              'furri': [80, 101, 136, 155, 174, 215, 242],
#              'femal': [81],
#              'fee': [83, 128, 134, 216, 221, 237],
#              'charg': [83],
#              'ranger': [83, 126],
#              'cowboy': [83, 228, 262],
#              '$60': [83],
#              'euless': [83],
#              'found': [84],
#              "lala'": [84],
#              'famou': [84, 150],
#              'swine': [84],
#              'pour': [84],
#              'aristocrat': [84],
#              'flyrit': [84],
#              'christma': [84, 161],
#              'barley': [84],
#              'due': [84, 88, 144],
#              'lick': [84],
#              'sever': [84, 130, 199, 207],
#              'bbq': [84, 130, 134, 165, 207, 239, 261],
#              'throw': [84],
#              'transit': [84],
#              'stone': [84, 186],
#              'notch': [84],
#              'brentwood': [84],
#              'pad': [84],
#              'burnet': [84],
#              'bufalina': [84],
#              "stubb'": [84],
#              "kingwood'": [85],
#              'cul': [85, 123],
#              'larger': [85],
#              'end': [85],
#              'de': [85, 113, 121, 123],
#              'hi': [85],
#              'run': [85, 154, 160],
#              'sac': [85, 123],
#              'greenbelt': [85, 214, 261],
#              'intercontinent': [85],
#              'tuck': [85],
#              'three': [85, 118, 138, 154, 200, 230, 232],
#              'cantera': [86, 198],
#              'soap': [86],
#              'mountain': [86],
#              'tournament': [87],
#              'byron': [87],
#              'townhous': [87, 96, 127, 176, 193],
#              'floorplan': [87],
#              'nelson': [87],
#              'valid': [88],
#              '99': [88, 103],
#              'driver': [88, 234],
#              'thank': [88, 98, 122],
#              'drug': [88],
#              'toll': [88],
#              'centerra': [88],
#              'i10': [88],
#              'urban': [89, 142],
#              'charm': [89, 145, 158, 185, 189, 217, 239, 251],
#              'await': [89],
#              'tctx': [89],
#              'meet': [89, 158, 201, 220],
#              'dock': [90, 188, 194, 241],
#              'float': [90],
#              'kind': [90],
#              'without': [90, 147, 196, 236],
#              'disturb': [90, 201],
#              'irreplac': [90],
#              'refresh': [90, 242],
#              'sceneri': [90],
#              'fun': [90],
#              'repres': [90],
#              'ramp': [90, 192],
#              'sun': [90, 106, 208, 239],
#              'swim': [90, 106, 193, 202, 239, 242],
#              'seclud': [90, 106, 123, 194],
#              'half': [91, 98, 168],
#              'restroom': [91],
#              'pan': [92],
#              '42': [92],
#              'studio': [92, 120, 124, 170, 181, 197, 216, 254, 256],
#              'pop': [92],
#              'cutleri': [92],
#              'lakesid': [93, 123],
#              'religion': [94],
#              ...})
