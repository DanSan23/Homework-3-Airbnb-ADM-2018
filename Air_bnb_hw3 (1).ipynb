# %%
import os,os.path
import csv
import nltk
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import wordpunct_tokenize
from nltk.tokenize import RegexpTokenizer
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import word_tokenize
from nltk.tokenize import regexp_tokenize

# %% [markdown]
# #  Create documents

# %%
# creating a .tsv document for each review
with open('Airbnb_Texas_Rentals.tsv', 'r', encoding = "utf8") as all_rev:
    csv_reader = csv.reader(all_rev)
    ind = -1
    for row in all_rev:
        ind += 1
        if ind == 0:
            continue
        # skipping the empty lines
        elif row == '\n':
            ind -= 1
            # we manipulate 'ind' in order to have files named doc_i where i = 1,2,3,..
        else:
            # we store the documents inside a new folder
            new_title = r'C:\Users\Daniele\fileAIR\doc_' + str(ind-1) + '.tsv'
            csv_writer = csv.writer(open(new_title, 'w', encoding = "utf8"), delimiter ='\t')
            # we skip the first column which is 
            row1 = row.split("\t")[1:]
            csv_writer.writerow(row1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-df87577a3d97> in <module>()
#      14             # we store the documents inside a new folder
#      15             new_title = r'C:\Users\Daniele\fileAIR\doc_' + str(ind-1) + '.tsv'
# ---> 16             csv_writer = csv.writer(open(new_title, 'w', encoding = "utf8"), delimiter ='\t')
#      17             # we skip the first column which is
#      18             row1 = row.split("\t")[1:]
#
# KeyboardInterrupt:

# %% [markdown]
# # Search Engine

# %%
# function to preprocess the files
def preprocess(something):
    something = something.lower()
    # removing '\n'
    something = something.replace('\\n', ' ')
    # removing punctuation
    tokenizer = regexp_tokenize(something, "[\w'\$]+")
    # filter the non stopwords
    filtered = [w for w in tokenizer if not w in stopwords.words('english')]
    ps = PorterStemmer()
    # removing the stem
    filtered = [ps.stem(word) for word in filtered]
    return filtered

# %%
len_file = len([x for x in os.scandir(r'C:\Users\Daniele\fileAIR')])
print (len_file)
# Out:
# 265

# %%
vocabulary_set = set()
docs_list = []

# %%
for i in range(0, len_file):
    with open(r'C:\Users\Daniele\fileAIR\doc_' + str(i) + '.tsv', 'r', encoding = 'utf8') as csvfile:
        file1 = csv.reader(csvfile, delimiter = '\t')
        columns = [i for i in file1]
        description = columns[0][4]
        description = preprocess(description)
        title = columns[0][7]
        title = preprocess(title)
        tit_desc = title + description
        vocabulary_set.update(tit_desc)
        docs_list.append(set(tit_desc))

# %%
vocabulary = {k:v for v, k in enumerate(vocabulary_set)}
vocabulary
# Out:
# {'spur': 0,
#  'turn': 1,
#  'termin': 2,
#  'seriou': 3,
#  'breez': 4,
#  'centerra': 5,
#  'colleg': 6,
#  'peac': 7,
#  'desir': 8,
#  'middl': 9,
#  'southern': 10,
#  'gig': 11,
#  'ignor': 12,
#  'es': 13,
#  'friend': 14,
#  'prepar': 15,
#  '23': 16,
#  'co': 17,
#  'christma': 18,
#  'alamo': 19,
#  'enjoy': 20,
#  'boutiqu': 21,
#  'roko': 22,
#  'empti': 23,
#  'acogedor': 24,
#  'littl': 25,
#  'car': 26,
#  'walden': 27,
#  'madden': 28,
#  'hike': 29,
#  'longer': 30,
#  'ambienc': 31,
#  'acreag': 32,
#  'strand': 33,
#  'updat': 34,
#  'restor': 35,
#  'everi': 36,
#  'sheet': 37,
#  '209': 38,
#  'wood': 39,
#  'mind': 40,
#  'tell': 41,
#  'para': 42,
#  'thread': 43,
#  'suppli': 44,
#  'sentenc': 45,
#  'cream': 46,
#  'hottub': 47,
#  'funni': 48,
#  'unlock': 49,
#  'airpot': 50,
#  'bth': 51,
#  '1953': 52,
#  'burnet': 53,
#  'guest': 54,
#  'histor': 55,
#  'suitabl': 56,
#  'favorit': 57,
#  'write': 58,
#  'sola': 59,
#  'vehicl': 60,
#  'discount': 61,
#  'mani': 62,
#  'except': 63,
#  'nasa': 64,
#  'golf': 65,
#  'surf': 66,
#  'emerald': 67,
#  '1br': 68,
#  'gateway': 69,
#  'vintag': 70,
#  'trip': 71,
#  '1940': 72,
#  "note'": 73,
#  'countri': 74,
#  'glass': 75,
#  'nest': 76,
#  'galveston': 77,
#  'assur': 78,
#  'soap': 79,
#  'zoo': 80,
#  'sing': 81,
#  'accommod': 82,
#  'ambient': 83,
#  'inflat': 84,
#  '10': 85,
#  'weekend': 86,
#  'vet': 87,
#  'system': 88,
#  '7': 89,
#  'counti': 90,
#  'pleasur': 91,
#  'romant': 92,
#  'goal': 93,
#  '45': 94,
#  'run': 95,
#  "there'": 96,
#  'kerrvil': 97,
#  'complet': 98,
#  'gourmet': 99,
#  'spade': 100,
#  'kick': 101,
#  'citi': 102,
#  'smoke': 103,
#  'review': 104,
#  'would': 105,
#  'man': 106,
#  'finish': 107,
#  'channel': 108,
#  'dog': 109,
#  'warm': 110,
#  'dark': 111,
#  'contain': 112,
#  'trendi': 113,
#  'estat': 114,
#  'netflix': 115,
#  'bathroom': 116,
#  'workout': 117,
#  'brenham': 118,
#  'linger': 119,
#  '17mi': 120,
#  'beltway': 121,
#  'tanglewood': 122,
#  'hous': 123,
#  'healthi': 124,
#  'bask': 125,
#  'mattress': 126,
#  'pleas': 127,
#  'picnic': 128,
#  'king': 129,
#  'get': 130,
#  'ocean': 131,
#  'buchanan': 132,
#  'soak': 133,
#  'collect': 134,
#  'triniti': 135,
#  'reveil': 136,
#  'rest': 137,
#  'beach': 138,
#  'fur': 139,
#  'connect': 140,
#  'villa': 141,
#  'marvel': 142,
#  'sxsw': 143,
#  'univ': 144,
#  'shot': 145,
#  'jw': 146,
#  'granburi': 147,
#  'piper': 148,
#  'plenti': 149,
#  'ford': 150,
#  'meadow': 151,
#  'hammock': 152,
#  'metro': 153,
#  'german': 154,
#  'padr': 155,
#  'kemah': 156,
#  'thanksgiv': 157,
#  'walmart': 158,
#  'area': 159,
#  'full': 160,
#  'store': 161,
#  'waller': 162,
#  'mud': 163,
#  'ski': 164,
#  'time': 165,
#  'beyond': 166,
#  'ga': 167,
#  'din': 168,
#  'bath': 169,
#  'moroccan': 170,
#  'tabl': 171,
#  "'j'": 172,
#  'unwind': 173,
#  'incred': 174,
#  '410': 175,
#  'midway': 176,
#  'everyon': 177,
#  'train': 178,
#  'sit': 179,
#  'rememb': 180,
#  'diamond': 181,
#  'stop': 182,
#  'ensuit': 183,
#  'shade': 184,
#  'playground': 185,
#  '19th': 186,
#  'bungalow': 187,
#  'outskirt': 188,
#  'perfectli': 189,
#  'ut': 190,
#  'patio': 191,
#  'vagabond': 192,
#  'alway': 193,
#  'monro': 194,
#  'boy': 195,
#  'way': 196,
#  'washer': 197,
#  'speed': 198,
#  'residenti': 199,
#  'por': 200,
#  '30am': 201,
#  'shop': 202,
#  'vine': 203,
#  'bank': 204,
#  '66': 205,
#  'wind': 206,
#  'harold': 207,
#  'spartanett': 208,
#  'exist': 209,
#  'scene': 210,
#  'hondo': 211,
#  'inn': 212,
#  'sunroom': 213,
#  'testament': 214,
#  'backyard': 215,
#  'nightlif': 216,
#  'se': 217,
#  'field': 218,
#  'bowl': 219,
#  'semi': 220,
#  'panoram': 221,
#  'ba': 222,
#  'fenc': 223,
#  'fall': 224,
#  'site': 225,
#  'much': 226,
#  'cook': 227,
#  'c': 228,
#  'hit': 229,
#  'proxim': 230,
#  'light': 231,
#  'featur': 232,
#  'bend': 233,
#  'concert': 234,
#  'sink': 235,
#  '100': 236,
#  'bridgeport': 237,
#  '640': 238,
#  'throughout': 239,
#  'center': 240,
#  'secur': 241,
#  'land': 242,
#  'high': 243,
#  'school': 244,
#  'chair': 245,
#  'divers': 246,
#  'staircas': 247,
#  'nautic': 248,
#  'convert': 249,
#  'theme': 250,
#  'baylor': 251,
#  'gazz': 252,
#  'hobbi': 253,
#  'st': 254,
#  'comal': 255,
#  'ground': 256,
#  'festiv': 257,
#  'antiqu': 258,
#  'glen': 259,
#  'bandera': 260,
#  'great': 261,
#  'start': 262,
#  'min': 263,
#  'enough': 264,
#  'second': 265,
#  'safeti': 266,
#  'encuentra': 267,
#  'upon': 268,
#  'chicken': 269,
#  'plan': 270,
#  'dalla': 271,
#  'topper': 272,
#  'five': 273,
#  'companion': 274,
#  'morn': 275,
#  'apart': 276,
#  'lap': 277,
#  'lead': 278,
#  'unseen': 279,
#  "jodie'": 280,
#  'easi': 281,
#  'oper': 282,
#  'basebal': 283,
#  'truli': 284,
#  'furnitur': 285,
#  'roll': 286,
#  'worker': 287,
#  'jazz': 288,
#  '07': 289,
#  'east': 290,
#  'culdasec': 291,
#  'arlington': 292,
#  'attend': 293,
#  'leagu': 294,
#  'outstand': 295,
#  'dwtn': 296,
#  'westburi': 297,
#  'effect': 298,
#  'cat': 299,
#  'rainey': 300,
#  'south': 301,
#  'neighboorhood': 302,
#  'couch': 303,
#  'porch': 304,
#  'shampoo': 305,
#  "kya'": 306,
#  'servic': 307,
#  'bdr': 308,
#  'machin': 309,
#  'hardwood': 310,
#  'overs': 311,
#  '$270': 312,
#  'techo': 313,
#  'worth': 314,
#  'locat': 315,
#  'creek': 316,
#  'built': 317,
#  'station': 318,
#  'boardwalk': 319,
#  '2b': 320,
#  'six': 321,
#  'applianc': 322,
#  'drug': 323,
#  'corridor': 324,
#  'paradis': 325,
#  'week': 326,
#  'thursday': 327,
#  'know': 328,
#  'n': 329,
#  'dallasmi': 330,
#  'brand': 331,
#  'pad': 332,
#  'del': 333,
#  'cota': 334,
#  'guitar': 335,
#  'wisteria': 336,
#  'fairi': 337,
#  'hole': 338,
#  'borrow': 339,
#  'true': 340,
#  'nice': 341,
#  'fellowship': 342,
#  'secret': 343,
#  'cart': 344,
#  'concept': 345,
#  'scent': 346,
#  'environ': 347,
#  'kingwood': 348,
#  'dine': 349,
#  'gulf': 350,
#  'air': 351,
#  'two': 352,
#  'twu': 353,
#  'mold': 354,
#  'person': 355,
#  'parti': 356,
#  'whether': 357,
#  'regular': 358,
#  'quick': 359,
#  'across': 360,
#  'complex': 361,
#  'dip': 362,
#  'kitchen': 363,
#  'antonio': 364,
#  'within': 365,
#  'hangout': 366,
#  'stillhous': 367,
#  'lakefront': 368,
#  'kimbrough': 369,
#  'experi': 370,
#  'near': 371,
#  "1920'": 372,
#  'studi': 373,
#  'side': 374,
#  'soul': 375,
#  'dfw': 376,
#  'anytim': 377,
#  '6100': 378,
#  'riverwalk': 379,
#  'amethyst': 380,
#  'pop': 381,
#  'origin': 382,
#  'wide': 383,
#  'fork': 384,
#  'irreplac': 385,
#  'tube': 386,
#  'recommend': 387,
#  'track': 388,
#  'dryer': 389,
#  'modular': 390,
#  'coffe': 391,
#  'spartan': 392,
#  '35': 393,
#  'swine': 394,
#  'plumb': 395,
#  "can't": 396,
#  'meal': 397,
#  'known': 398,
#  'email': 399,
#  'boat': 400,
#  'phillip': 401,
#  'expos': 402,
#  'muy': 403,
#  'thai': 404,
#  'bu': 405,
#  'disappoint': 406,
#  'lux': 407,
#  'cozi': 408,
#  'weather': 409,
#  'bedroom': 410,
#  'basic': 411,
#  'immens': 412,
#  'background': 413,
#  'mexia': 414,
#  'tempurped': 415,
#  'cotton': 416,
#  'décor': 417,
#  '1316': 418,
#  'bantam': 419,
#  'tour': 420,
#  'manor': 421,
#  'southeast': 422,
#  'goe': 423,
#  'hijo': 424,
#  'noextra': 425,
#  '4555': 426,
#  'rug': 427,
#  'kirbi': 428,
#  'life': 429,
#  'artisan': 430,
#  'rooftop': 431,
#  'ceil': 432,
#  "stubb'": 433,
#  'tv': 434,
#  'stair': 435,
#  'loveseat': 436,
#  'eateri': 437,
#  'j': 438,
#  'line': 439,
#  'pharmaci': 440,
#  'avenu': 441,
#  'blanco': 442,
#  '1400': 443,
#  'year': 444,
#  'covet': 445,
#  'lavend': 446,
#  '400': 447,
#  '50': 448,
#  'beachfront': 449,
#  'excel': 450,
#  'minuto': 451,
#  'insid': 452,
#  'balconi': 453,
#  "'countri": 454,
#  'relax': 455,
#  'ok': 456,
#  'adventur': 457,
#  'pick': 458,
#  'contemporari': 459,
#  'swanki': 460,
#  '6pm': 461,
#  'un': 462,
#  '3160': 463,
#  'least': 464,
#  'loung': 465,
#  'cute': 466,
#  'yet': 467,
#  'surround': 468,
#  'baytown': 469,
#  'reinvigor': 470,
#  'rub': 471,
#  'hau': 472,
#  'colina': 473,
#  'state': 474,
#  'lugar': 475,
#  'crash': 476,
#  'hostil': 477,
#  'outlet': 478,
#  'en': 479,
#  'pecan': 480,
#  'steam': 481,
#  'hidden': 482,
#  'wake': 483,
#  'research': 484,
#  'bigger': 485,
#  '29': 486,
#  'count': 487,
#  'fan': 488,
#  'w': 489,
#  'frequent': 490,
#  'base': 491,
#  'room': 492,
#  'commun': 493,
#  'lp': 494,
#  'mirror': 495,
#  'luxuri': 496,
#  'rv': 497,
#  'traffic': 498,
#  'boast': 499,
#  'wi': 500,
#  'safest': 501,
#  'anybodi': 502,
#  'op': 503,
#  'dble': 504,
#  'oreo': 505,
#  'bishop': 506,
#  'wish': 507,
#  'pong': 508,
#  'i35': 509,
#  'religion': 510,
#  'chute': 511,
#  'pasadena': 512,
#  '$75': 513,
#  'schlitterbaun': 514,
#  'femal': 515,
#  'camper': 516,
#  'roku': 517,
#  'licens': 518,
#  'spread': 519,
#  'microwav': 520,
#  'bbq': 521,
#  'rock': 522,
#  'fabeuless': 523,
#  'greenway': 524,
#  'jacinto': 525,
#  'aesthet': 526,
#  'debido': 527,
#  'shelv': 528,
#  'forward': 529,
#  'come': 530,
#  'repres': 531,
#  'marbella': 532,
#  'bq': 533,
#  '15min': 534,
#  'reserv': 535,
#  'north': 536,
#  'stun': 537,
#  'sol': 538,
#  'atx': 539,
#  'la': 540,
#  'cottag': 541,
#  'rang': 542,
#  'hideaway': 543,
#  'exactli': 544,
#  'cul': 545,
#  'erg': 546,
#  'bike': 547,
#  'half': 548,
#  'onto': 549,
#  'tile': 550,
#  'quarter': 551,
#  'protext': 552,
#  'make': 553,
#  '300': 554,
#  'attent': 555,
#  '2rm': 556,
#  'stori': 557,
#  'yucca': 558,
#  '2bath': 559,
#  'hum': 560,
#  'other': 561,
#  'elum': 562,
#  'steel': 563,
#  'stain': 564,
#  'throw': 565,
#  'pic': 566,
#  'salt': 567,
#  'design': 568,
#  'growth': 569,
#  'explor': 570,
#  'transport': 571,
#  'disc': 572,
#  'featherb': 573,
#  'rail': 574,
#  'mountain': 575,
#  '10min': 576,
#  'futon': 577,
#  'bunkhous': 578,
#  'villag': 579,
#  'among': 580,
#  'home': 581,
#  'nation': 582,
#  'denton': 583,
#  'sunset': 584,
#  'kayak': 585,
#  'hint': 586,
#  'solo': 587,
#  'angel': 588,
#  'far': 589,
#  'provid': 590,
#  'victorian': 591,
#  'art': 592,
#  'today': 593,
#  'super': 594,
#  'log': 595,
#  'ninja': 596,
#  'chines': 597,
#  'border': 598,
#  'stylishli': 599,
#  'toward': 600,
#  'escap': 601,
#  'public': 602,
#  'sand': 603,
#  'peopl': 604,
#  'read': 605,
#  "y'all": 606,
#  'password': 607,
#  'q': 608,
#  'walk': 609,
#  'right': 610,
#  'hook': 611,
#  'close': 612,
#  'creat': 613,
#  'eleg': 614,
#  'hour': 615,
#  'courtyard': 616,
#  'famili': 617,
#  'lamin': 618,
#  'eye': 619,
#  'robert': 620,
#  'lakeview': 621,
#  'phone': 622,
#  'winstar': 623,
#  'point': 624,
#  'landscap': 625,
#  'drop': 626,
#  'interior': 627,
#  'might': 628,
#  'stone': 629,
#  'plate': 630,
#  '4k': 631,
#  'bayview': 632,
#  'hey': 633,
#  'dessert': 634,
#  '2300': 635,
#  'mini': 636,
#  'alexa': 637,
#  'babysit': 638,
#  'found': 639,
#  'exot': 640,
#  'afford': 641,
#  'donkey': 642,
#  'spaciou': 643,
#  'gorgeou': 644,
#  'plano': 645,
#  '12x12': 646,
#  'april2017': 647,
#  'kati': 648,
#  'sleep': 649,
#  'wade': 650,
#  'expo': 651,
#  'request': 652,
#  'tarrytown': 653,
#  'shave': 654,
#  'orient': 655,
#  'hair': 656,
#  'intercontinent': 657,
#  'cattl': 658,
#  'bird': 659,
#  'stadium': 660,
#  'condo': 661,
#  'tien': 662,
#  'nightstand': 663,
#  'inspir': 664,
#  'outdoor': 665,
#  'pot': 666,
#  'costco': 667,
#  'lqqk': 668,
#  'metal': 669,
#  'holiday': 670,
#  'venu': 671,
#  "everything'": 672,
#  'heb': 673,
#  'spare': 674,
#  'help': 675,
#  'nw': 676,
#  'texan': 677,
#  'deer': 678,
#  'sac': 679,
#  'henc': 680,
#  'ad': 681,
#  'salado': 682,
#  'slide': 683,
#  'acl': 684,
#  'bamc': 685,
#  'tx': 686,
#  'nativ': 687,
#  'dock': 688,
#  'sceneri': 689,
#  'often': 690,
#  'loop': 691,
#  'domain': 692,
#  'less': 693,
#  'thing': 694,
#  'legal': 695,
#  'medicin': 696,
#  'corpu': 697,
#  'massag': 698,
#  'cookwar': 699,
#  'meet': 700,
#  '11th': 701,
#  'smu': 702,
#  'rate': 703,
#  '15th': 704,
#  'tollway': 705,
#  'tranquilidad': 706,
#  'airlin': 707,
#  'eustac': 708,
#  'austin': 709,
#  'fun': 710,
#  'privaci': 711,
#  'stud': 712,
#  'motel': 713,
#  'gem': 714,
#  'attract': 715,
#  'inquiri': 716,
#  'awesom': 717,
#  'arboretum': 718,
#  'ultim': 719,
#  'actual': 720,
#  'rockin': 721,
#  'essenti': 722,
#  'upscal': 723,
#  'mall': 724,
#  'aloha': 725,
#  'back': 726,
#  'complianc': 727,
#  'nobl': 728,
#  'lower': 729,
#  'want': 730,
#  'clara': 731,
#  'imposs': 732,
#  'templ': 733,
#  'bay': 734,
#  'regularli': 735,
#  'see': 736,
#  'find': 737,
#  "we'r": 738,
#  'rice': 739,
#  'chest': 740,
#  'need': 741,
#  'roast': 742,
#  'schlitterbahn': 743,
#  'spectacular': 744,
#  'centr': 745,
#  'ladder': 746,
#  'bliss': 747,
#  'klyde': 748,
#  'dahl': 749,
#  '4br': 750,
#  'seen': 751,
#  'end': 752,
#  'freezer': 753,
#  'local': 754,
#  'longhorn': 755,
#  'sunni': 756,
#  '2016': 757,
#  'trundl': 758,
#  'entri': 759,
#  'owner': 760,
#  'bell': 761,
#  'awar': 762,
#  'separ': 763,
#  'along': 764,
#  'townhous': 765,
#  'red': 766,
#  'restaur': 767,
#  'convent': 768,
#  'seren': 769,
#  "joe'": 770,
#  'maison': 771,
#  'await': 772,
#  'drawer': 773,
#  'earth': 774,
#  'support': 775,
#  'corner': 776,
#  'stereo': 777,
#  'shadi': 778,
#  'sun': 779,
#  'fullsiz': 780,
#  'honor': 781,
#  "city'": 782,
#  'keep': 783,
#  'upstair': 784,
#  'cano': 785,
#  'per': 786,
#  '15': 787,
#  'distanc': 788,
#  'escape': 789,
#  'sf': 790,
#  'e': 791,
#  '12': 792,
#  'testimoni': 793,
#  'pallapa': 794,
#  'third': 795,
#  "ski'": 796,
#  'bienvenido': 797,
#  'pedernal': 798,
#  'md': 799,
#  'via': 800,
#  '99': 801,
#  'carpet': 802,
#  'hot': 803,
#  "retreat'": 804,
#  'wall': 805,
#  'current': 806,
#  'crate': 807,
#  'call': 808,
#  'wolf': 809,
#  'leav': 810,
#  'due': 811,
#  'playset': 812,
#  'circuit': 813,
#  'rental': 814,
#  'plaza': 815,
#  'texoma': 816,
#  "chic'": 817,
#  'ciudad': 818,
#  'neibourhood': 819,
#  'camp': 820,
#  'sky': 821,
#  'pm': 822,
#  'carriag': 823,
#  '121': 824,
#  'mi': 825,
#  'highway': 826,
#  'carport': 827,
#  'hi': 828,
#  'regist': 829,
#  '750': 830,
#  'cpchem': 831,
#  'tropic': 832,
#  'cargo': 833,
#  'habitat': 834,
#  'popular': 835,
#  'pan': 836,
#  'cove': 837,
#  'seven': 838,
#  'tcc': 839,
#  'ntsu': 840,
#  'hr': 841,
#  'portion': 842,
#  'shotwel': 843,
#  'strateg': 844,
#  'eastex': 845,
#  "area'": 846,
#  'conro': 847,
#  'lakeshor': 848,
#  '150': 849,
#  'galor': 850,
#  'retail': 851,
#  'approxim': 852,
#  'bayfront': 853,
#  'ranch': 854,
#  'continent': 855,
#  'railyard': 856,
#  'path': 857,
#  'cow': 858,
#  'coast': 859,
#  'builder': 860,
#  "'em": 861,
#  'valley': 862,
#  'christi': 863,
#  'round': 864,
#  'wraparound': 865,
#  'kitchenett': 866,
#  '18': 867,
#  '1st': 868,
#  'vibe': 869,
#  'ask': 870,
#  'tuck': 871,
#  'decor': 872,
#  'washington': 873,
#  'directli': 874,
#  'ton': 875,
#  'moodi': 876,
#  'mile': 877,
#  'tenni': 878,
#  "fisherman'": 879,
#  'lewisvil': 880,
#  'livabl': 881,
#  'hotel': 882,
#  'keurig': 883,
#  'fridg': 884,
#  'safari': 885,
#  'pure': 886,
#  'name': 887,
#  'kroger': 888,
#  'belt': 889,
#  'cover': 890,
#  'volleybal': 891,
#  'splashpad': 892,
#  'lackland': 893,
#  '37': 894,
#  'ship': 895,
#  'floorplan': 896,
#  'occup': 897,
#  'murphi': 898,
#  'revamp': 899,
#  'loft': 900,
#  'look': 901,
#  'adult': 902,
#  'made': 903,
#  'everyth': 904,
#  'organ': 905,
#  'kingsvil': 906,
#  '40': 907,
#  'common': 908,
#  'lone': 909,
#  'bring': 910,
#  'hauler': 911,
#  'garland': 912,
#  'cedar': 913,
#  'american': 914,
#  'studio': 915,
#  'qti': 916,
#  'seaworld': 917,
#  'suburb': 918,
#  'chico': 919,
#  'refug': 920,
#  'fasten': 921,
#  'li': 922,
#  'bed': 923,
#  'wander': 924,
#  'note': 925,
#  'nrg': 926,
#  'mine': 927,
#  'fool': 928,
#  'fit': 929,
#  'byron': 930,
#  'sqft': 931,
#  'queen': 932,
#  'easili': 933,
#  'island': 934,
#  'bound': 935,
#  'afb': 936,
#  'duplex': 937,
#  'fi': 938,
#  'summon': 939,
#  'tamu': 940,
#  'waterloo': 941,
#  'boern': 942,
#  'sugarland': 943,
#  'student': 944,
#  'baybrook': 945,
#  'anyon': 946,
#  'rustic': 947,
#  'suit': 948,
#  'que': 949,
#  'instant': 950,
#  'special': 951,
#  'waterfront': 952,
#  'th': 953,
#  'old': 954,
#  '30': 955,
#  'cation': 956,
#  'retir': 957,
#  'monday': 958,
#  'sanctuari': 959,
#  'bd': 960,
#  'join': 961,
#  'exxon': 962,
#  'southbound': 963,
#  'atmospher': 964,
#  'queenb': 965,
#  'bottl': 966,
#  'add': 967,
#  'section': 968,
#  'nearest': 969,
#  'getaway': 970,
#  'temporari': 971,
#  'stove': 972,
#  'tool': 973,
#  'fairway': 974,
#  'jet': 975,
#  'oasi': 976,
#  'board': 977,
#  'trial': 978,
#  'deal': 979,
#  'racquet': 980,
#  'nois': 981,
#  '4342': 982,
#  'unit': 983,
#  '70': 984,
#  'mill': 985,
#  '59': 986,
#  'trail': 987,
#  'sincer': 988,
#  'kyle': 989,
#  'thank': 990,
#  'lo': 991,
#  'toy': 992,
#  'seabrook': 993,
#  'attach': 994,
#  'fireplac': 995,
#  '4bd': 996,
#  'rack': 997,
#  'api': 998,
#  'doubl': 999,
#  ...}

# %%
# save vocabulary to the file
voc_file = open(r'C:\Users\Daniele\vocabulary.txt', 'w', encoding = "utf8")
for term in vocabulary:
    voc_file.write('{0}\t{1}\n'.format(term, vocabulary[term]))

# %%
# we use defaultdict because it gives no key error
from collections import defaultdict 
#we need t sort this value
inv_indx = defaultdict(set)
for idx, text in enumerate(docs_list):
    for word in text:
        id_word = vocabulary[word]
        inv_indx[id_word].add(idx)

# %%
# to have a list as the value inside the dict
for key in inv_indx:
    value = inv_indx[key]
    inv_indx[key] = list(value)

# %%
#inv_indx
# Out:
# defaultdict(set,
#             {534: [0,
#               1,
#               3,
#               259,
#               134,
#               7,
#               264,
#               10,
#               140,
#               13,
#               18,
#               21,
#               152,
#               26,
#               159,
#               163,
#               39,
#               170,
#               175,
#               179,
#               53,
#               57,
#               185,
#               188,
#               190,
#               64,
#               68,
#               200,
#               211,
#               86,
#               88,
#               217,
#               91,
#               220,
#               97,
#               230,
#               109,
#               240,
#               116,
#               118,
#               251,
#               124],
#              1000: [0,
#               1,
#               129,
#               131,
#               260,
#               6,
#               134,
#               262,
#               11,
#               143,
#               146,
#               147,
#               148,
#               155,
#               160,
#               40,
#               44,
#               175,
#               51,
#               180,
#               53,
#               54,
#               185,
#               66,
#               71,
#               200,
#               75,
#               79,
#               83,
#               211,
#               85,
#               214,
#               87,
#               91,
#               94,
#               96,
#               113,
#               246,
#               121],
#              1914: [0,
#               262,
#               13,
#               144,
#               146,
#               147,
#               22,
#               26,
#               156,
#               29,
#               30,
#               160,
#               39,
#               170,
#               46,
#               175,
#               55,
#               57,
#               187,
#               197,
#               71,
#               201,
#               74,
#               75,
#               205,
#               85,
#               100,
#               229,
#               103,
#               104,
#               109,
#               239],
#              1568: [0, 249, 92, 47, 239, 210, 213, 57, 122, 28],
#              1538: [0,
#               4,
#               196,
#               70,
#               199,
#               104,
#               200,
#               250,
#               236,
#               50,
#               146,
#               222,
#               22,
#               150,
#               58,
#               125,
#               94],
#              763: [0,
#               129,
#               131,
#               134,
#               6,
#               7,
#               14,
#               25,
#               31,
#               38,
#               39,
#               43,
#               179,
#               58,
#               188,
#               76,
#               79,
#               85,
#               220,
#               103,
#               106,
#               110,
#               120],
#              1970: [0, 54],
#              769: [0, 233, 76, 237, 48],
#              1379: [0, 26, 27],
#              1207: [0, 134, 85, 53, 55],
#              1973: [0, 264, 170, 47, 175, 210, 52, 53, 85, 63],
#              1893: [0,
#               1,
#               3,
#               7,
#               8,
#               10,
#               15,
#               16,
#               18,
#               20,
#               21,
#               23,
#               25,
#               33,
#               44,
#               47,
#               48,
#               52,
#               55,
#               57,
#               58,
#               64,
#               66,
#               68,
#               69,
#               70,
#               74,
#               75,
#               76,
#               80,
#               85,
#               91,
#               97,
#               98,
#               109,
#               114,
#               118,
#               119,
#               126,
#               129,
#               134,
#               138,
#               142,
#               145,
#               150,
#               151,
#               153,
#               159,
#               160,
#               163,
#               164,
#               168,
#               169,
#               172,
#               173,
#               175,
#               176,
#               178,
#               179,
#               182,
#               184,
#               187,
#               190,
#               194,
#               195,
#               200,
#               206,
#               209,
#               211,
#               213,
#               220,
#               223,
#               231,
#               232,
#               233,
#               235,
#               237,
#               239,
#               240,
#               249,
#               251,
#               252,
#               253,
#               258,
#               259,
#               264],
#              1046: [0, 74, 64],
#              1383: [0,
#               259,
#               262,
#               7,
#               138,
#               151,
#               155,
#               28,
#               169,
#               175,
#               52,
#               53,
#               70,
#               200,
#               209,
#               210,
#               92,
#               220,
#               223,
#               99,
#               230,
#               103,
#               232,
#               108,
#               109,
#               240,
#               115,
#               116,
#               118,
#               249],
#              418: [0,
#               1,
#               2,
#               3,
#               130,
#               131,
#               258,
#               7,
#               264,
#               137,
#               138,
#               11,
#               140,
#               13,
#               20,
#               21,
#               148,
#               151,
#               152,
#               26,
#               27,
#               31,
#               159,
#               33,
#               36,
#               39,
#               168,
#               169,
#               43,
#               171,
#               45,
#               172,
#               173,
#               175,
#               178,
#               52,
#               53,
#               183,
#               56,
#               57,
#               184,
#               185,
#               60,
#               62,
#               63,
#               64,
#               67,
#               69,
#               71,
#               201,
#               76,
#               77,
#               206,
#               80,
#               209,
#               83,
#               211,
#               86,
#               88,
#               91,
#               219,
#               220,
#               94,
#               95,
#               221,
#               97,
#               224,
#               100,
#               104,
#               105,
#               233,
#               110,
#               239,
#               241,
#               114,
#               115,
#               116,
#               118,
#               119,
#               246,
#               249,
#               250,
#               127],
#              1579: [0, 108, 92, 254],
#              84: [0,
#               1,
#               129,
#               130,
#               257,
#               258,
#               134,
#               260,
#               10,
#               11,
#               139,
#               13,
#               14,
#               15,
#               16,
#               142,
#               18,
#               143,
#               145,
#               21,
#               150,
#               25,
#               155,
#               29,
#               164,
#               38,
#               39,
#               168,
#               43,
#               172,
#               47,
#               48,
#               178,
#               51,
#               52,
#               55,
#               57,
#               185,
#               62,
#               190,
#               64,
#               194,
#               195,
#               70,
#               73,
#               77,
#               207,
#               80,
#               209,
#               210,
#               87,
#               91,
#               223,
#               96,
#               224,
#               98,
#               225,
#               104,
#               232,
#               234,
#               235,
#               109,
#               117,
#               118,
#               249,
#               250,
#               251,
#               254,
#               255],
#              56: [0,
#               1,
#               264,
#               18,
#               163,
#               168,
#               170,
#               175,
#               53,
#               182,
#               70,
#               75,
#               206,
#               210,
#               218,
#               96,
#               226,
#               109,
#               114,
#               118,
#               253,
#               127],
#              272: [0,
#               256,
#               3,
#               131,
#               132,
#               259,
#               7,
#               264,
#               9,
#               152,
#               26,
#               27,
#               159,
#               160,
#               34,
#               36,
#               39,
#               169,
#               170,
#               172,
#               45,
#               174,
#               175,
#               178,
#               179,
#               181,
#               55,
#               56,
#               184,
#               58,
#               185,
#               60,
#               64,
#               65,
#               66,
#               67,
#               192,
#               69,
#               194,
#               71,
#               200,
#               201,
#               74,
#               75,
#               76,
#               80,
#               208,
#               83,
#               84,
#               85,
#               212,
#               216,
#               217,
#               90,
#               92,
#               220,
#               105,
#               106,
#               233,
#               108,
#               237,
#               110,
#               240,
#               114,
#               243,
#               254,
#               250,
#               251,
#               252,
#               126],
#              1360: [0, 83],
#              2023: [0,
#               259,
#               264,
#               144,
#               145,
#               146,
#               151,
#               160,
#               38,
#               167,
#               40,
#               169,
#               43,
#               172,
#               54,
#               58,
#               187,
#               64,
#               67,
#               68,
#               209,
#               210,
#               213,
#               220,
#               97,
#               99,
#               233,
#               240,
#               254],
#              179: [0, 54],
#              1162: [0],
#              869: [0,
#               259,
#               7,
#               137,
#               138,
#               145,
#               21,
#               23,
#               24,
#               25,
#               26,
#               152,
#               28,
#               29,
#               155,
#               159,
#               32,
#               164,
#               169,
#               42,
#               43,
#               173,
#               47,
#               48,
#               175,
#               52,
#               53,
#               180,
#               183,
#               57,
#               188,
#               62,
#               69,
#               70,
#               71,
#               200,
#               73,
#               201,
#               76,
#               77,
#               209,
#               210,
#               213,
#               217,
#               92,
#               220,
#               99,
#               230,
#               103,
#               104,
#               105,
#               106,
#               231,
#               108,
#               109,
#               232,
#               237,
#               239,
#               240,
#               115,
#               116,
#               122,
#               127],
#              757: [0, 219, 117],
#              1838: [1],
#              434: [1, 253, 239],
#              758: [1,
#               130,
#               12,
#               14,
#               144,
#               18,
#               19,
#               146,
#               151,
#               30,
#               160,
#               44,
#               56,
#               186,
#               59,
#               64,
#               70,
#               200,
#               84,
#               226,
#               236],
#              566: [1, 133, 102, 261, 43, 174, 251, 186, 123, 254],
#              249: [1,
#               255,
#               41,
#               138,
#               75,
#               204,
#               77,
#               109,
#               142,
#               174,
#               145,
#               209,
#               237,
#               239,
#               244,
#               151,
#               185,
#               92,
#               30,
#               63],
#              1887: [1, 199, 104, 168, 14, 142, 20, 57, 250, 25],
#              568: [1,
#               163,
#               133,
#               135,
#               170,
#               75,
#               140,
#               109,
#               145,
#               84,
#               214,
#               151,
#               253,
#               63],
#              1202: [1, 76, 239, 115, 243],
#              975: [1,
#               151,
#               28,
#               30,
#               159,
#               39,
#               169,
#               43,
#               172,
#               175,
#               52,
#               53,
#               57,
#               69,
#               76,
#               220,
#               94,
#               223,
#               230,
#               108,
#               236,
#               124,
#               255],
#              1915: [1,
#               129,
#               18,
#               146,
#               20,
#               25,
#               28,
#               158,
#               163,
#               165,
#               167,
#               168,
#               176,
#               51,
#               68,
#               72,
#               207,
#               209,
#               216,
#               91,
#               223,
#               97,
#               98,
#               229,
#               237,
#               239,
#               118,
#               252],
#              12: [1, 18, 197, 57],
#              1009: [1,
#               137,
#               138,
#               145,
#               22,
#               150,
#               155,
#               164,
#               39,
#               168,
#               42,
#               170,
#               47,
#               48,
#               52,
#               53,
#               180,
#               55,
#               184,
#               188,
#               69,
#               77,
#               209,
#               85,
#               213,
#               88,
#               216,
#               217,
#               91,
#               92,
#               223,
#               230,
#               231,
#               232,
#               250,
#               237,
#               239,
#               240,
#               114,
#               119,
#               122,
#               253,
#               255],
#              1919: [1, 71],
#              1284: [89,
#               1,
#               96,
#               192,
#               195,
#               255,
#               261,
#               199,
#               186,
#               264,
#               76,
#               56,
#               25,
#               26,
#               57],
#              1408: [1,
#               2,
#               3,
#               258,
#               5,
#               261,
#               262,
#               263,
#               264,
#               141,
#               14,
#               142,
#               17,
#               145,
#               147,
#               148,
#               23,
#               152,
#               155,
#               157,
#               32,
#               161,
#               36,
#               165,
#               40,
#               42,
#               171,
#               172,
#               175,
#               49,
#               177,
#               179,
#               54,
#               182,
#               56,
#               57,
#               184,
#               187,
#               63,
#               69,
#               197,
#               71,
#               73,
#               202,
#               204,
#               78,
#               80,
#               83,
#               215,
#               88,
#               218,
#               91,
#               219,
#               220,
#               95,
#               224,
#               225,
#               227,
#               102,
#               231,
#               232,
#               105,
#               106,
#               107,
#               234,
#               250,
#               245,
#               254,
#               122,
#               126,
#               127],
#              1410: [1,
#               264,
#               10,
#               138,
#               142,
#               145,
#               23,
#               151,
#               152,
#               155,
#               168,
#               42,
#               170,
#               172,
#               174,
#               179,
#               52,
#               57,
#               188,
#               61,
#               63,
#               64,
#               71,
#               77,
#               78,
#               210,
#               211,
#               216,
#               92,
#               220,
#               230,
#               250,
#               236,
#               109,
#               237,
#               239,
#               240,
#               119,
#               122,
#               124,
#               255],
#              708: [256,
#               1,
#               129,
#               255,
#               134,
#               138,
#               13,
#               142,
#               143,
#               146,
#               20,
#               21,
#               150,
#               151,
#               159,
#               44,
#               176,
#               55,
#               57,
#               61,
#               62,
#               192,
#               66,
#               194,
#               195,
#               196,
#               197,
#               74,
#               76,
#               207,
#               80,
#               87,
#               91,
#               223,
#               224,
#               97,
#               229,
#               103,
#               231,
#               234,
#               235,
#               237,
#               239,
#               114,
#               117,
#               250,
#               252,
#               127],
#              1825: [1],
#              576: [1, 258, 243, 55, 217, 218],
#              1144: [128,
#               1,
#               258,
#               131,
#               4,
#               261,
#               6,
#               11,
#               141,
#               14,
#               16,
#               145,
#               22,
#               155,
#               28,
#               32,
#               36,
#               165,
#               38,
#               39,
#               168,
#               54,
#               55,
#               57,
#               58,
#               186,
#               62,
#               63,
#               65,
#               193,
#               199,
#               202,
#               207,
#               80,
#               208,
#               214,
#               215,
#               88,
#               220,
#               222,
#               96,
#               227,
#               102,
#               110,
#               239,
#               243,
#               244,
#               247,
#               253],
#              516: [1, 145, 39],
#              579: [1,
#               138,
#               20,
#               25,
#               158,
#               163,
#               38,
#               52,
#               188,
#               193,
#               68,
#               77,
#               99,
#               103,
#               104,
#               231,
#               232,
#               239,
#               112,
#               242,
#               117,
#               245],
#              1117: [1, 133, 202, 46, 14, 144, 178, 19, 147, 181, 218],
#              1614: [1],
#              1323: [1,
#               2,
#               130,
#               131,
#               7,
#               138,
#               13,
#               15,
#               144,
#               145,
#               146,
#               20,
#               24,
#               35,
#               163,
#               170,
#               44,
#               46,
#               52,
#               56,
#               186,
#               189,
#               64,
#               195,
#               68,
#               71,
#               203,
#               205,
#               79,
#               207,
#               210,
#               84,
#               85,
#               215,
#               90,
#               220,
#               97,
#               98,
#               102,
#               104,
#               232,
#               235,
#               236,
#               251,
#               244,
#               117,
#               118,
#               247,
#               120,
#               123],
#              1514: [1,
#               130,
#               4,
#               10,
#               24,
#               152,
#               167,
#               44,
#               54,
#               189,
#               65,
#               195,
#               197,
#               204,
#               213,
#               220,
#               222,
#               226,
#               228,
#               102,
#               111,
#               254],
#              1832: [1],
#              1089: [1],
#              493: [1, 70, 109, 206, 253],
#              1547: [1],
#              494: [96, 1, 142, 71],
#              1186: [1,
#               257,
#               7,
#               136,
#               264,
#               138,
#               11,
#               13,
#               14,
#               144,
#               145,
#               147,
#               148,
#               21,
#               153,
#               154,
#               30,
#               34,
#               35,
#               51,
#               187,
#               65,
#               68,
#               196,
#               198,
#               201,
#               76,
#               207,
#               222,
#               98,
#               107,
#               108,
#               109,
#               237,
#               239,
#               242,
#               244,
#               117,
#               250],
#              1683: [1, 258, 37, 230, 147, 186, 187, 63],
#              1520: [1,
#               10,
#               11,
#               15,
#               18,
#               19,
#               24,
#               28,
#               30,
#               36,
#               39,
#               41,
#               44,
#               54,
#               56,
#               57,
#               58,
#               63,
#               68,
#               70,
#               71,
#               72,
#               78,
#               79,
#               80,
#               84,
#               90,
#               91,
#               95,
#               97,
#               98,
#               104,
#               106,
#               107,
#               109,
#               114,
#               117,
#               124,
#               127,
#               129,
#               130,
#               131,
#               134,
#               141,
#               142,
#               144,
#               145,
#               147,
#               150,
#               155,
#               158,
#               160,
#               162,
#               167,
#               169,
#               172,
#               188,
#               189,
#               192,
#               196,
#               197,
#               198,
#               199,
#               200,
#               201,
#               204,
#               207,
#               208,
#               210,
#               211,
#               215,
#               218,
#               219,
#               220,
#               224,
#               225,
#               226,
#               228,
#               231,
#               235,
#               239,
#               246,
#               251,
#               253,
#               254],
#              496: [224, 1, 163, 229, 102, 168, 46, 177, 18, 87, 120, 219, 63],
#              1093: [1, 4, 213],
#              1420: [1,
#               3,
#               5,
#               7,
#               138,
#               139,
#               14,
#               142,
#               16,
#               18,
#               21,
#               23,
#               32,
#               33,
#               36,
#               169,
#               177,
#               51,
#               179,
#               53,
#               55,
#               185,
#               58,
#               186,
#               65,
#               67,
#               197,
#               71,
#               200,
#               73,
#               212,
#               86,
#               216,
#               91,
#               219,
#               220,
#               222,
#               225,
#               227,
#               102,
#               231,
#               104,
#               105,
#               106,
#               236,
#               114,
#               124],
#              1031: [1, 34, 163, 169, 51, 181, 28],
#              28: [1, 226, 230, 42, 77, 109, 54, 57],
#              1524: [1, 3, 77, 111, 220, 120, 217, 127, 184, 63],
#              1874: [1, 163, 135, 251, 31, 254, 127],
#              306: [1,
#               257,
#               258,
#               132,
#               264,
#               12,
#               13,
#               19,
#               148,
#               152,
#               30,
#               163,
#               171,
#               172,
#               47,
#               175,
#               182,
#               55,
#               57,
#               58,
#               188,
#               189,
#               63,
#               67,
#               195,
#               197,
#               198,
#               72,
#               74,
#               76,
#               204,
#               205,
#               207,
#               212,
#               86,
#               220,
#               229,
#               103,
#               105,
#               106,
#               234,
#               237,
#               239,
#               240,
#               114,
#               125,
#               126],
#              176: [1],
#              396: [1, 198, 230, 108, 237, 145, 178, 82, 223],
#              555: [1],
#              1526: [1,
#               132,
#               7,
#               10,
#               11,
#               12,
#               138,
#               18,
#               147,
#               148,
#               38,
#               169,
#               173,
#               180,
#               53,
#               55,
#               58,
#               63,
#               65,
#               200,
#               211,
#               85,
#               217,
#               91,
#               219,
#               220,
#               95,
#               225,
#               103,
#               104,
#               106,
#               234,
#               108,
#               236,
#               111,
#               251,
#               241,
#               246,
#               123,
#               124,
#               126],
#              1834: [1,
#               3,
#               4,
#               5,
#               6,
#               10,
#               11,
#               13,
#               14,
#               18,
#               21,
#               22,
#               25,
#               26,
#               30,
#               35,
#               38,
#               39,
#               41,
#               42,
#               43,
#               44,
#               48,
#               51,
#               53,
#               55,
#               57,
#               63,
#               65,
#               66,
#               68,
#               69,
#               76,
#               79,
#               80,
#               82,
#               83,
#               85,
#               86,
#               87,
#               91,
#               92,
#               97,
#               98,
#               99,
#               101,
#               106,
#               111,
#               113,
#               118,
#               125,
#               126,
#               129,
#               133,
#               134,
#               136,
#               138,
#               142,
#               143,
#               144,
#               145,
#               147,
#               150,
#               155,
#               158,
#               160,
#               163,
#               165,
#               168,
#               172,
#               177,
#               181,
#               184,
#               192,
#               195,
#               200,
#               201,
#               205,
#               207,
#               214,
#               218,
#               219,
#               222,
#               223,
#               224,
#               225,
#               227,
#               229,
#               230,
#               231,
#               232,
#               233,
#               234,
#               236,
#               237,
#               238,
#               239,
#               240,
#               243,
#               245,
#               246,
#               247,
#               249,
#               251,
#               252,
#               253,
#               262,
#               264],
#              562: [1, 71],
#              1419: [2, 146],
#              848: [256,
#               33,
#               2,
#               226,
#               263,
#               40,
#               232,
#               235,
#               187,
#               174,
#               19,
#               214,
#               247,
#               155,
#               125],
#              883: [2],
#              543: [2,
#               66,
#               196,
#               201,
#               107,
#               171,
#               13,
#               143,
#               146,
#               147,
#               180,
#               54,
#               246,
#               25,
#               125],
#              661: [221, 2, 213],
#              666: [2, 151],
#              1195: [2, 130, 102, 232, 250, 239, 58],
#              1250: [2, 235, 122],
#              61: [2, 35, 36, 102, 72, 41, 201, 107, 147, 212, 25, 154, 158],
#              344: [2],
#              1759: [2],
#              47: [2],
#              791: [2,
#               131,
#               138,
#               16,
#               152,
#               32,
#               160,
#               46,
#               174,
#               177,
#               51,
#               54,
#               186,
#               75,
#               206,
#               207,
#               83,
#               85,
#               106,
#               236,
#               247,
#               124,
#               255],
#              1603: [3],
#              405: [3, 78, 145, 118, 24],
#              54: [96, 3, 196, 170, 154, 251],
#              1248: [3, 63],
#              1861: [3, 104, 236, 206, 16, 87, 249, 254],
#              1673: [3, 68, 167, 236, 145, 247, 250, 251, 125],
#              1301: [224,
#               161,
#               34,
#               3,
#               6,
#               233,
#               170,
#               11,
#               108,
#               208,
#               149,
#               218,
#               251,
#               63],
#              1487: [129,
#               3,
#               261,
#               134,
#               136,
#               10,
#               155,
#               159,
#               162,
#               38,
#               167,
#               42,
#               172,
#               175,
#               48,
#               51,
#               179,
#               58,
#               186,
#               195,
#               69,
#               71,
#               76,
#               85,
#               214,
#               96,
#               107,
#               110,
#               240,
#               244,
#               250],
#              732: [4],
#              42: [128,
#               129,
#               259,
#               4,
#               260,
#               134,
#               11,
#               15,
#               146,
#               19,
#               21,
#               170,
#               46,
#               53,
#               55,
#               56,
#               61,
#               197,
#               71,
#               199,
#               204,
#               86,
#               224,
#               229,
#               106,
#               117,
#               246,
#               253],
#              760: [256,
#               129,
#               130,
#               258,
#               4,
#               6,
#               7,
#               134,
#               262,
#               263,
#               139,
#               142,
#               143,
#               146,
#               150,
#               151,
#               24,
#               174,
#               48,
#               51,
#               180,
#               55,
#               185,
#               186,
#               59,
#               187,
#               197,
#               198,
#               200,
#               205,
#               207,
#               208,
#               83,
#               214,
#               87,
#               224,
#               229,
#               230,
#               103,
#               232,
#               234,
#               235,
#               108,
#               109,
#               111,
#               246,
#               250,
#               251,
#               253],
#              1631: [98, 4, 168, 77, 111, 53, 218],
#              667: [98, 4, 165, 170, 124, 85, 246, 56, 28, 31],
#              407: [4,
#               6,
#               263,
#               12,
#               147,
#               22,
#               150,
#               154,
#               162,
#               54,
#               57,
#               194,
#               70,
#               72,
#               73,
#               218,
#               96,
#               230,
#               237,
#               239,
#               120],
#              1609: [65, 130, 4, 41, 44, 181, 24],
#              1315: [130, 139, 4],
#              352: [258, 163, 4, 106, 14, 206, 16, 145, 249, 63],
#              1765: [139, 4, 46],
#              1857: [129,
#               258,
#               259,
#               4,
#               134,
#               7,
#               263,
#               139,
#               14,
#               142,
#               16,
#               143,
#               146,
#               24,
#               152,
#               28,
#               29,
#               158,
#               31,
#               162,
#               165,
#               46,
#               51,
#               52,
#               53,
#               54,
#               180,
#               56,
#               184,
#               185,
#               59,
#               186,
#               187,
#               66,
#               195,
#               197,
#               199,
#               201,
#               76,
#               204,
#               205,
#               79,
#               206,
#               211,
#               84,
#               212,
#               214,
#               89,
#               218,
#               219,
#               220,
#               96,
#               226,
#               228,
#               229,
#               232,
#               235,
#               108,
#               236,
#               110,
#               111,
#               238,
#               113,
#               243,
#               246,
#               123,
#               124,
#               253,
#               127],
#              1860: [4],
#              271: [58, 220, 4, 214],
#              694: [4],
#              1560: [4],
#              1746: [67, 4, 174, 144, 19, 253],
#              309: [131, 4, 200, 11, 82, 146, 211, 56, 220, 152, 255],
#              94: [131, 4, 11, 205, 82, 83, 211, 220, 56, 156, 152, 126],
#              499: [4, 151],
#              1128: [4, 84],
#              1458: [129,
#               4,
#               261,
#               134,
#               135,
#               136,
#               264,
#               11,
#               13,
#               145,
#               19,
#               147,
#               148,
#               151,
#               28,
#               31,
#               32,
#               33,
#               160,
#               165,
#               167,
#               170,
#               44,
#               46,
#               48,
#               51,
#               53,
#               56,
#               186,
#               62,
#               65,
#               196,
#               71,
#               72,
#               201,
#               204,
#               79,
#               211,
#               85,
#               86,
#               89,
#               225,
#               98,
#               231,
#               238,
#               114,
#               117,
#               247,
#               250,
#               123,
#               124,
#               255],
#              1363: [4, 22],
#              2: [34, 5, 198, 234, 11, 142, 21],
#              505: [261,
#               5,
#               6,
#               135,
#               14,
#               15,
#               145,
#               150,
#               36,
#               165,
#               170,
#               171,
#               46,
#               174,
#               196,
#               72,
#               214,
#               90,
#               230,
#               107,
#               251],
#              1135: [68, 5, 77, 237, 145, 147, 57],
#              1754: [5,
#               261,
#               262,
#               136,
#               143,
#               19,
#               151,
#               153,
#               177,
#               179,
#               180,
#               181,
#               182,
#               186,
#               58,
#               61,
#               192,
#               194,
#               72,
#               202,
#               204,
#               90,
#               218,
#               219,
#               97,
#               98,
#               225,
#               100,
#               226,
#               103,
#               231,
#               233,
#               241,
#               244,
#               247,
#               255],
#              1201: [129,
#               5,
#               262,
#               136,
#               11,
#               141,
#               145,
#               148,
#               23,
#               155,
#               32,
#               161,
#               35,
#               36,
#               165,
#               171,
#               172,
#               45,
#               46,
#               175,
#               49,
#               51,
#               181,
#               183,
#               57,
#               61,
#               64,
#               198,
#               71,
#               73,
#               202,
#               75,
#               78,
#               80,
#               211,
#               214,
#               215,
#               95,
#               224,
#               225,
#               99,
#               227,
#               102,
#               231,
#               232,
#               105,
#               234,
#               107,
#               236,
#               242,
#               246,
#               119],
#              1239: [5,
#               7,
#               139,
#               16,
#               17,
#               157,
#               32,
#               161,
#               164,
#               165,
#               172,
#               56,
#               192,
#               67,
#               83,
#               220,
#               94,
#               95,
#               224,
#               225,
#               102,
#               231,
#               105,
#               234,
#               111,
#               242,
#               125,
#               126],
#              1885: [32,
#               96,
#               162,
#               224,
#               227,
#               5,
#               262,
#               264,
#               105,
#               172,
#               111,
#               23,
#               152],
#              904: [32,
#               161,
#               162,
#               36,
#               5,
#               231,
#               73,
#               42,
#               106,
#               76,
#               234,
#               80,
#               210,
#               150,
#               23,
#               220,
#               30,
#               223],
#              906: [161,
#               257,
#               258,
#               5,
#               38,
#               101,
#               165,
#               231,
#               42,
#               43,
#               138,
#               261,
#               174,
#               80,
#               208,
#               179,
#               186,
#               189,
#               30],
#              1430: [161,
#               5,
#               38,
#               101,
#               165,
#               231,
#               138,
#               80,
#               147,
#               22,
#               87,
#               94,
#               61,
#               30,
#               223],
#              944: [5,
#               136,
#               264,
#               141,
#               17,
#               148,
#               23,
#               152,
#               27,
#               155,
#               157,
#               30,
#               32,
#               161,
#               36,
#               165,
#               171,
#               172,
#               174,
#               175,
#               49,
#               51,
#               55,
#               183,
#               60,
#               61,
#               197,
#               73,
#               201,
#               202,
#               78,
#               79,
#               80,
#               214,
#               215,
#               94,
#               223,
#               225,
#               227,
#               101,
#               102,
#               231,
#               105,
#               234,
#               107,
#               242,
#               246,
#               253],
#              1637: [32,
#               161,
#               224,
#               67,
#               225,
#               5,
#               231,
#               136,
#               105,
#               106,
#               234,
#               172,
#               238,
#               17,
#               146,
#               150,
#               55,
#               157],
#              642: [5,
#               134,
#               141,
#               23,
#               155,
#               30,
#               161,
#               164,
#               165,
#               51,
#               60,
#               61,
#               202,
#               78,
#               79,
#               80,
#               85,
#               215,
#               225,
#               101,
#               102,
#               231,
#               104,
#               234,
#               107,
#               242],
#              222: [153, 98, 177, 5],
#              918: [257,
#               258,
#               5,
#               262,
#               263,
#               136,
#               264,
#               12,
#               13,
#               14,
#               141,
#               17,
#               147,
#               148,
#               149,
#               22,
#               23,
#               150,
#               152,
#               26,
#               155,
#               156,
#               157,
#               32,
#               161,
#               36,
#               165,
#               38,
#               40,
#               171,
#               172,
#               174,
#               175,
#               49,
#               52,
#               181,
#               183,
#               58,
#               59,
#               60,
#               61,
#               65,
#               198,
#               71,
#               73,
#               202,
#               76,
#               205,
#               78,
#               80,
#               84,
#               212,
#               214,
#               215,
#               94,
#               95,
#               224,
#               225,
#               227,
#               101,
#               102,
#               229,
#               231,
#               105,
#               234,
#               239,
#               242,
#               117,
#               246,
#               124],
#              1085: [131,
#               5,
#               136,
#               141,
#               17,
#               148,
#               152,
#               155,
#               32,
#               161,
#               36,
#               171,
#               172,
#               174,
#               175,
#               51,
#               55,
#               183,
#               60,
#               61,
#               71,
#               73,
#               201,
#               202,
#               80,
#               84,
#               214,
#               215,
#               94,
#               225,
#               227,
#               101,
#               102,
#               229,
#               231,
#               105,
#               107,
#               242,
#               246],
#              1516: [5,
#               141,
#               17,
#               148,
#               23,
#               155,
#               157,
#               30,
#               32,
#               161,
#               36,
#               165,
#               171,
#               172,
#               174,
#               175,
#               179,
#               183,
#               58,
#               60,
#               71,
#               73,
#               202,
#               78,
#               80,
#               214,
#               215,
#               94,
#               225,
#               227,
#               101,
#               102,
#               231,
#               105,
#               234,
#               242,
#               246],
#              1154: [5,
#               138,
#               139,
#               13,
#               141,
#               144,
#               17,
#               146,
#               19,
#               147,
#               22,
#               23,
#               26,
#               155,
#               157,
#               30,
#               32,
#               161,
#               34,
#               165,
#               38,
#               172,
#               48,
#               51,
#               55,
#               56,
#               60,
#               61,
#               66,
#               69,
#               202,
#               77,
#               78,
#               79,
#               80,
#               207,
#               85,
#               213,
#               87,
#               214,
#               215,
#               90,
#               94,
#               224,
#               225,
#               101,
#               102,
#               231,
#               105,
#               234,
#               107,
#               111,
#               241,
#               242,
#               119,
#               126],
#              1058: [131,
#               5,
#               14,
#               142,
#               23,
#               24,
#               154,
#               155,
#               158,
#               31,
#               32,
#               161,
#               36,
#               38,
#               42,
#               177,
#               181,
#               54,
#               55,
#               57,
#               189,
#               63,
#               68,
#               70,
#               73,
#               201,
#               76,
#               207,
#               80,
#               86,
#               223,
#               224,
#               102,
#               231,
#               233,
#               234,
#               244,
#               120,
#               124],
#              1808: [5,
#               136,
#               264,
#               141,
#               17,
#               148,
#               152,
#               155,
#               32,
#               161,
#               36,
#               171,
#               172,
#               174,
#               175,
#               51,
#               55,
#               183,
#               60,
#               61,
#               71,
#               73,
#               201,
#               202,
#               80,
#               214,
#               215,
#               94,
#               225,
#               227,
#               101,
#               102,
#               231,
#               105,
#               107,
#               242,
#               246],
#              1741: [258,
#               131,
#               5,
#               262,
#               136,
#               264,
#               141,
#               17,
#               148,
#               23,
#               152,
#               26,
#               27,
#               155,
#               30,
#               32,
#               161,
#               36,
#               165,
#               171,
#               172,
#               174,
#               175,
#               51,
#               55,
#               186,
#               60,
#               61,
#               73,
#               201,
#               78,
#               80,
#               85,
#               214,
#               215,
#               94,
#               225,
#               227,
#               101,
#               231,
#               234,
#               107,
#               242,
#               246,
#               251,
#               253],
#              1523: [131,
#               5,
#               136,
#               264,
#               141,
#               17,
#               148,
#               23,
#               152,
#               155,
#               30,
#               32,
#               161,
#               36,
#               165,
#               171,
#               172,
#               174,
#               175,
#               51,
#               55,
#               60,
#               61,
# ...
#              1947: [187, 39],
#              611: [257, 98, 229, 39, 104],
#              447: [70, 39],
#              1210: [39],
#              1345: [39],
#              821: [264, 134, 39],
#              1113: [96,
#               160,
#               258,
#               164,
#               69,
#               39,
#               106,
#               187,
#               237,
#               53,
#               245,
#               221,
#               253,
#               91,
#               61,
#               223],
#              2005: [64, 39],
#              383: [39],
#              1954: [207, 39],
#              549: [39],
#              1484: [39],
#              1325: [39],
#              1352: [39],
#              689: [226, 197, 262, 39, 205],
#              1515: [196, 70, 39, 88, 220],
#              1390: [39],
#              391: [39],
#              1491: [39],
#              1096: [250, 39],
#              1332: [245, 39],
#              1159: [194, 229, 39, 231, 232, 108, 174, 146, 220],
#              1426: [64, 39],
#              563: [163, 199, 167, 39, 202, 237, 114, 220],
#              782: [67,
#               196,
#               229,
#               102,
#               39,
#               259,
#               106,
#               138,
#               237,
#               239,
#               83,
#               117,
#               124,
#               61],
#              635: [40, 81],
#              468: [66, 104, 41, 239, 115, 86, 55, 220],
#              662: [41, 119],
#              1967: [258, 67, 41, 234, 239, 154],
#              1237: [41],
#              703: [64,
#               255,
#               41,
#               138,
#               75,
#               45,
#               77,
#               109,
#               209,
#               210,
#               244,
#               55,
#               58,
#               92,
#               63],
#              49: [41, 158],
#              979: [41, 204, 207, 209, 119, 247],
#              70: [41],
#              1998: [41, 259, 52, 209],
#              263: [65, 196, 41, 115, 245, 63],
#              450: [97, 259, 41, 202, 109, 237, 179, 249, 220],
#              1356: [41],
#              1224: [41, 122, 102],
#              1632: [130, 261, 42, 52, 150, 223],
#              1338: [42],
#              411: [198, 42, 50, 115, 213, 57, 253],
#              1206: [42, 45, 48, 151, 186],
#              1179: [42],
#              802: [229, 71, 42, 120, 220],
#              366: [42],
#              1265: [200, 42, 170, 108, 109, 48, 145, 210, 115, 151],
#              316: [83, 43],
#              1839: [104, 169, 43, 230],
#              1306: [43],
#              1543: [43],
#              1795: [43],
#              1082: [208, 193, 43, 255],
#              1351: [115, 43, 140],
#              1493: [43],
#              1198: [44],
#              810: [44],
#              787: [44],
#              1006: [44],
#              1727: [161, 251, 44],
#              1676: [64, 130, 44, 239, 209, 152, 223],
#              1181: [44],
#              928: [44, 150],
#              835: [44],
#              594: [44],
#              1559: [44, 62],
#              899: [44, 182],
#              1782: [44],
#              768: [90, 45],
#              489: [168, 233, 218, 45],
#              247: [187, 45],
#              1843: [45],
#              900: [45],
#              209: [46],
#              127: [243, 46, 199],
#              733: [46],
#              1943: [46],
#              1636: [113, 46],
#              345: [96, 193, 46, 243, 150, 184, 185, 189],
#              819: [258, 228, 139, 206, 46, 207, 185],
#              1853: [68, 46],
#              648: [46],
#              164: [46],
#              987: [120, 161, 46, 207],
#              148: [139, 205, 46, 152, 220],
#              1261: [46],
#              1102: [163, 46],
#              993: [96,
#               229,
#               139,
#               76,
#               236,
#               46,
#               243,
#               84,
#               212,
#               54,
#               254,
#               120,
#               253,
#               186,
#               220,
#               152,
#               62],
#              624: [225, 257, 199, 139, 46, 212, 152],
#              1876: [205, 46],
#              1126: [46],
#              1302: [210, 46],
#              1601: [250, 254, 47],
#              1437: [239, 47],
#              1219: [129, 98, 130, 195, 235, 47, 146, 52, 57, 158, 159],
#              1495: [151, 249, 52, 47],
#              217: [48, 134],
#              1847: [68, 197, 134, 171, 48, 56],
#              414: [48],
#              1145: [64,
#               66,
#               67,
#               99,
#               228,
#               259,
#               233,
#               48,
#               81,
#               146,
#               212,
#               213,
#               184,
#               59],
#              1083: [96, 65, 259, 229, 234, 108, 48, 212, 53, 121, 124, 62],
#              1530: [154, 263, 106, 48, 56, 90],
#              1429: [49],
#              607: [49],
#              133: [49],
#              911: [49, 134],
#              104: [80, 49, 196, 117],
#              1288: [49],
#              851: [76, 239, 144, 49, 210, 88, 124],
#              1048: [67, 134, 102, 198, 262, 144, 49, 150, 216],
#              1578: [49],
#              1802: [49, 63],
#              270: [49, 91, 134],
#              424: [49],
#              91: [49],
#              1600: [256, 50, 140, 244],
#              1366: [96, 57, 51, 216],
#              1167: [224, 130, 165, 110, 51],
#              439: [143, 51, 180, 57, 219],
#              812: [96, 65, 143, 51, 180, 124],
#              1756: [51],
#              1241: [51],
#              1403: [106, 51],
#              65: [51],
#              1917: [106, 51],
#              292: [256,
#               129,
#               260,
#               197,
#               134,
#               198,
#               199,
#               262,
#               110,
#               79,
#               114,
#               51,
#               211,
#               222,
#               54,
#               216,
#               153,
#               189,
#               62],
#              145: [51],
#              1546: [161, 51, 85],
#              388: [51],
#              1690: [56, 74, 88, 52],
#              602: [52],
#              1273: [120, 124, 52],
#              1597: [52],
#              1337: [52],
#              440: [64, 52],
#              569: [98, 52, 230],
#              1071: [52],
#              1604: [138, 52, 109],
#              1382: [52],
#              1952: [52, 231],
#              1810: [107, 52, 228],
#              1216: [52],
#              1615: [124, 52, 92],
#              833: [52],
#              1156: [188, 52, 174, 239],
#              1900: [52],
#              394: [230, 231, 138, 76, 52, 118],
#              120: [67, 239, 178, 52, 127],
#              369: [52],
#              1988: [154, 52, 253, 230],
#              1233: [146, 195, 53],
#              99: [53],
#              188: [185, 53, 230, 239],
#              250: [160,
#               225,
#               130,
#               131,
#               258,
#               165,
#               134,
#               138,
#               75,
#               170,
#               234,
#               79,
#               114,
#               242,
#               53,
#               214,
#               255],
#              544: [53],
#              1346: [53],
#              53: [53],
#              1212: [244, 172, 53],
#              1440: [53],
#              266: [53],
#              1769: [53],
#              1933: [53],
#              1223: [160,
#               98,
#               131,
#               249,
#               134,
#               232,
#               123,
#               187,
#               219,
#               53,
#               87,
#               57,
#               91,
#               127],
#              174: [53],
#              588: [53],
#              1983: [53],
#              1037: [160,
#               131,
#               165,
#               134,
#               264,
#               138,
#               75,
#               234,
#               79,
#               114,
#               242,
#               53,
#               214,
#               255],
#              1400: [245, 204, 53],
#              1532: [54],
#              1720: [54],
#              218: [220, 54],
#              1671: [193, 70, 110, 111, 54, 246, 186, 253],
#              110: [131, 134, 143, 180, 54],
#              1217: [226, 260, 54],
#              552: [54],
#              1263: [54],
#              456: [54],
#              88: [134, 262, 110, 84, 214, 54],
#              1122: [54],
#              753: [54],
#              1883: [220, 55],
#              762: [102, 55],
#              380: [64, 96, 259, 197, 110, 142, 212, 182, 55, 62],
#              913: [106, 55],
#              1971: [55],
#              446: [55],
#              73: [195, 228, 140, 238, 207, 181, 182, 118, 55],
#              711: [55],
#              1826: [70, 144, 55, 250, 220, 125],
#              953: [55],
#              297: [55],
#              751: [97, 237, 55],
#              1742: [55],
#              935: [55],
#              600: [104, 85, 71, 55],
#              632: [98, 100, 132, 228, 201, 206, 144, 84, 56],
#              317: [56, 247],
#              2006: [56],
#              650: [56],
#              1354: [56],
#              2012: [56, 259, 146, 131],
#              1188: [56, 131, 95],
#              894: [56],
#              1268: [57],
#              1764: [88, 57, 225],
#              1577: [57],
#              1439: [88, 57, 225],
#              582: [57, 129, 231],
#              519: [57],
#              521: [88, 57, 202],
#              1618: [121,
#               225,
#               197,
#               134,
#               229,
#               170,
#               235,
#               219,
#               146,
#               85,
#               57,
#               91,
#               124,
#               253,
#               62],
#              586: [57, 225],
#              657: [57, 194, 193, 87],
#              837: [57],
#              1687: [57],
#              1498: [57],
#              1906: [57],
#              1909: [58],
#              665: [58, 261, 174, 186, 123],
#              1823: [58],
#              1698: [58],
#              196: [170, 58],
#              619: [198, 75, 171, 113, 86, 87, 88, 58],
#              927: [58, 75, 87],
#              29: [58],
#              1194: [192,
#               122,
#               103,
#               230,
#               106,
#               250,
#               172,
#               77,
#               114,
#               178,
#               120,
#               58,
#               187,
#               223],
#              122: [258, 122, 168, 109, 111, 239, 210, 245, 58],
#              1923: [59],
#              1641: [59],
#              210: [160, 102, 209, 220, 61],
#              1760: [72, 61, 86],
#              14: [136, 193, 188, 61],
#              1386: [194, 61],
#              1326: [208, 180, 61, 143],
#              1898: [61],
#              1296: [145, 148, 61, 255],
#              1097: [61],
#              155: [114, 61],
#              402: [62],
#              1475: [62],
#              1019: [253, 197, 62],
#              1023: [116, 62],
#              832: [64, 62],
#              958: [110, 212, 62],
#              462: [212, 62],
#              1062: [62],
#              469: [253, 163, 109, 63],
#              1788: [163,
#               70,
#               168,
#               264,
#               138,
#               236,
#               77,
#               111,
#               146,
#               148,
#               182,
#               183,
#               214,
#               185,
#               219,
#               190,
#               126,
#               63],
#              605: [63],
#              790: [63],
#              513: [63],
#              1575: [77, 63],
#              1674: [63],
#              1116: [63],
#              1257: [63],
#              1767: [169, 170, 174, 210, 213, 63, 159],
#              1772: [239, 63],
#              392: [84, 261, 71, 63],
#              1551: [63],
#              128: [64],
#              541: [64, 165],
#              1607: [64],
#              1707: [64],
#              457: [64, 179, 77, 239],
#              1299: [64],
#              1300: [64, 163, 109, 77, 209, 253],
#              1065: [65, 106, 114],
#              866: [65, 72, 106, 245, 150, 153],
#              435: [67, 220],
#              1564: [67],
#              941: [178, 91, 67],
#              130: [193, 67, 172, 247],
#              1667: [67, 262, 106, 236, 117, 86, 91],
#              1576: [67],
#              1114: [120, 67, 189, 158],
#              82: [67],
#              1929: [67, 198],
#              1865: [67],
#              115: [67, 247],
#              358: [67, 220],
#              1549: [67],
#              564: [67, 187],
#              1305: [68],
#              976: [68, 134],
#              19: [68],
#              1388: [163, 68],
#              1486: [72, 68],
#              1358: [68],
#              360: [68],
#              1456: [68],
#              1467: [69],
#              1136: [69],
#              1994: [69],
#              1376: [69],
#              1078: [69],
#              492: [69],
#              1739: [69],
#              1770: [69, 174],
#              304: [180, 69, 143],
#              870: [106, 69],
#              1234: [249, 247, 70, 175],
#              903: [140, 70],
#              1319: [70],
#              1644: [162, 196, 70, 135, 169, 217],
#              546: [70],
#              559: [70],
#              239: [70],
#              966: [145, 70],
#              1501: [71],
#              880: [250, 71],
#              1072: [71],
#              772: [71],
#              612: [71],
#              522: [102, 71],
#              629: [71],
#              1533: [72],
#              535: [72],
#              1815: [72],
#              1913: [97, 100, 199, 72, 127],
#              216: [72, 257],
#              67: [72, 141, 212, 120, 218, 93],
#              1890: [72],
#              1111: [164, 100, 229, 72, 144, 155, 189],
#              1541: [72, 130, 207],
#              983: [72],
#              1811: [72],
#              892: [72, 242],
#              1932: [72],
#              622: [72, 257],
#              1805: [72],
#              990: [72],
#              692: [72],
#              1552: [72],
#              1033: [72, 249, 199],
#              236: [72],
#              1161: [72],
#              996: [226, 262, 103, 72, 181, 246],
#              1460: [72],
#              432: [72],
#              645: [73],
#              185: [73],
#              528: [74, 221],
#              111: [74, 83],
#              1617: [144, 74, 262],
#              123: [74],
#              1907: [74, 76],
#              617: [239, 75, 119],
#              1937: [75],
#              1817: [76],
#              1140: [132, 76],
#              882: [76],
#              816: [116, 185, 76, 183],
#              946: [76],
#              947: [233, 76, 207, 122, 251],
#              256: [76],
#              483: [76],
#              1830: [76, 231],
#              1030: [76],
#              425: [76, 228, 247],
#              178: [76, 197],
#              1362: [76],
#              557: [120, 76, 142, 92],
#              596: [76, 199],
#              3: [77],
#              282: [77],
#              441: [77],
#              161: [77],
#              1141: [77],
#              1343: [193, 233, 77, 207, 122, 251, 188, 253],
#              981: [144, 98, 77, 174],
#              1211: [106, 77],
#              684: [77],
#              1928: [77],
#              1678: [77],
#              988: [77],
#              1054: [232, 77],
#              1262: [220, 77, 239],
#              1327: [77, 239],
#              361: [233, 77],
#              1957: [77],
#              426: [213, 77, 103],
#              397: [77],
#              1157: [114, 172, 77],
#              237: [77],
#              728: [218, 77, 134],
#              184: [241, 77],
#              1733: [78],
#              376: [78],
#              750: [78],
#              1371: [91, 244, 79],
#              1790: [96, 121, 108, 79],
#              1415: [79],
#              55: [106, 250, 253, 79],
#              1969: [101, 136, 174, 80, 242, 215, 155],
#              902: [81],
#              962: [81],
#              1534: [83, 126],
#              1432: [128, 134, 237, 83, 216, 221],
#              1665: [83],
#              10: [83],
#              822: [83],
#              718: [83, 228, 262],
#              999: [84, 150],
#              1: [84],
#              1335: [84],
#              1269: [84],
#              1719: [84],
#              ...})

# %%
# save inv_indx to the .txt file
inv_file = open(r'C:\Users\Daniele\inverted_indx.txt', 'w', encoding = "utf8")
for id_term in inv_indx:
    docks = inv_indx[id_term]
    d = '\t'.join(map(str, docks))
    inv_file.write('{0}\t{1}\n'.format(id_term, d))

# %%
query = str(input())
# Out:
# a beautiful house with garden and beach

# %%
def SearchEngine(query, vocab, inv_indx):
    doc_list = []
    li = preprocess(query)
    pos_list = []
    for item in li:
        if item not in vocabulary:
            print('No documents found')
            break
        pos_id = vocabulary[item]
        pos_list.append(pos_id)
    result_list = []
    for term_id in pos_list:
        result_list.append(inv_indx[term_id])
    return result_list

# %%
def findTheSomething(res_list):
    test = {k:1 for k in res_list[0]}
    for sublist_ind in range(1, len(res_list)):
        for k in res_list[sublist_ind]:
            try:
                test[k] += 1
            except:
                test[k] = 1
    return [doc_id for doc_id in test if test[doc_id]==3]

# %%
pos = SearchEngine(query, vocabulary, inv_indx)

# %%
doc = findTheSomething(pos)
doc
# Out:
# [1, 35, 207]

# %%
g=[]
for i in doc:
    g.append(pd.read_csv(r'C:\Users\Daniele\fileAIR\doc_'+str(i)+'.tsv',sep='\t'))
g1=[[j for j in i] for i in g]
cols = ['1', '2', 'City', '4','Description','6','7','Title','Url']
df1 = pd.DataFrame(g1,columns=cols)[['Title','Description','City','Url']]
df1
# Out:
#                                                Title  \
# 0  Unique Location! Alamo Heights - Designer Insp...
# 1                                       Monroe Manor
# 2            MarBella House Near the Galveston Beach
#
#                                          Description         City  \
# 0  Stylish, fully remodeled home in upscale NW – ...  San Antonio
# 1  Come relax on the water in our beautiful beach...      Houston
# 2  Location Location Location - Large 3 bdrm hous...    Galveston
#
#                                                  Url
# 0  https://www.airbnb.com/rooms/17481455?location...
# 1  https://www.airbnb.com/rooms/19273801?location...
# 2  https://www.airbnb.com/rooms/7459305?location=...
